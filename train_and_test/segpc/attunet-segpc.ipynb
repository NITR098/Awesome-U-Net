# %% [markdown]
# # AttUNet - SegPC2021
# ---

# %% [markdown]
# ## Import packages & functions

# %%
from __future__ import print_function, division


import os
import sys
sys.path.append('../..')
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import copy
import json
import importlib
import glob
import pandas as pd
from skimage import io, transform
import matplotlib.pyplot as plt
from matplotlib.image import imread
import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchmetrics
from torch.optim import Adam, SGD
from losses import DiceLoss, DiceLossWithLogtis
from torch.nn import BCELoss, CrossEntropyLoss

from utils import (
    show_sbs,
    load_config,
    _print,
)

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# plt.ion()   # interactive mode

# %% [markdown]
# ## Set the seed

# %%
torch.manual_seed(0)
np.random.seed(0)
torch.cuda.manual_seed(0)
import random
random.seed(0)

# %% [markdown]
# ## Load the config

# %%
CONFIG_NAME = "segpc/segpc2021_attunet.yaml"
CONFIG_FILE_PATH = os.path.join("./configs", CONFIG_NAME)

# %%
config = load_config(CONFIG_FILE_PATH)
_print("Config:", "info_underline")
print(json.dumps(config, indent=2))
print(20*"~-", "\n")
# Out:
# Config:
# {
#   "run": {
#     "mode": "train",
#     "device": "gpu"
#   },
#   "transforms": "none",
#   "dataset": {
#     "class_name": "SegPC2021Dataset",
#     "input_size": 224,
#     "scale": 2.5,
#     "data_dir": "/path/to/datasets/segpc/np",
#     "dataset_dir": "/path/to/datasets/segpc/TCIA_SegPC_dataset",
#     "number_classes": 2
#   },
#   "data_loader": {
#     "train": {
#       "batch_size": 16,
#       "shuffle": true,
#       "num_workers": 4,
#       "pin_memory": true
#     },
#     "validation": {
#       "batch_size": 16,
#       "shuffle": false,
#       "num_workers": 4,
#       "pin_memory": true
#     },
#     "test": {
#       "batch_size": 16,
#       "shuffle": false,
#       "num_workers": 4,
#       "pin_memory": false
#     }
#   },
#   "training": {
#     "optimizer": {
#       "name": "Adam",
#       "params": {
#         "lr": 0.0001
#       }
#     },
#     "criterion": {
#       "name": "DiceLoss",
#       "params": {}
#     },
#     "scheduler": {
#       "factor": 0.5,
#       "patience": 10
#     },
#     "epochs": 100
#   },
#   "model": {
#     "save_dir": "../saved_models/segpc2021_attunet",
#     "load_weights": false,
#     "name": "AttU_Net",
#     "params": {
#       "img_ch": 4,
#       "output_ch": 2
#     }
#   }
# }
# ~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-

# %% [markdown]
# ## Dataset and Dataloader

# %%
from datasets.segpc import SegPC2021Dataset
from torch.utils.data import DataLoader, Subset
from torchvision import transforms

# %%
# ----------------- transform ------------------
# transform for image
img_transform = transforms.Compose([
    transforms.ToTensor()
])
# transform for mask
msk_transform = transforms.Compose([
    transforms.ToTensor()
])
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<


# ----------------- dataset --------------------
# preparing training dataset
tr_dataset = SegPC2021Dataset(
    mode="tr",
    input_size=config['dataset']['input_size'],
    scale=config['dataset']['scale'],
    data_dir=config['dataset']['data_dir'], 
    dataset_dir=config['dataset']['dataset_dir'],
    one_hot=True,
    force_rebuild=False,
    img_transform=img_transform,
    msk_transform=msk_transform
)
# preparing training dataset
vl_dataset = SegPC2021Dataset(
    mode="vl",
    input_size=config['dataset']['input_size'],
    scale=config['dataset']['scale'],
    data_dir=config['dataset']['data_dir'], 
    dataset_dir=config['dataset']['dataset_dir'],
    one_hot=True,
    force_rebuild=False,
    img_transform=img_transform,
    msk_transform=msk_transform
)
# preparing training dataset
te_dataset = SegPC2021Dataset(
    mode="te",
    input_size=config['dataset']['input_size'],
    scale=config['dataset']['scale'],
    data_dir=config['dataset']['data_dir'], 
    dataset_dir=config['dataset']['dataset_dir'],
    one_hot=True,
    force_rebuild=False,
    img_transform=img_transform,
    msk_transform=msk_transform
)


def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(0)

# prepare train dataloader
tr_dataloader = DataLoader(tr_dataset, worker_init_fn=seed_worker, generator=g, **config['data_loader']['train'])

# prepare validation dataloader
vl_dataloader = DataLoader(vl_dataset, worker_init_fn=seed_worker, generator=g, **config['data_loader']['validation'])

# prepare test dataloader
te_dataloader = DataLoader(te_dataset, worker_init_fn=seed_worker, generator=g, **config['data_loader']['test'])



print(f"Length of trainig_dataset:\t{len(tr_dataset)}")
print(f"Length of validation_dataset:\t{len(vl_dataset)}")
print(f"Length of test_dataset:\t\t{len(te_dataset)}")

# -------------- test -----------------
# test and visualize the input data
for batch in tr_dataloader:
    img = batch['image']
    msk = batch['mask']
    print("Training")
    show_sbs(img[0,:-1,:,:], msk[0,1])
    break
    
for batch in vl_dataloader:
    img = batch['image']
    msk = batch['mask']
    print("Validation")
    show_sbs(img[0,:-1,:,:], msk[0,1])
    break
    
for batch in te_dataloader:
    img = batch['image']
    msk = batch['mask']
    print("Test")
    show_sbs(img[0,:-1,:,:], msk[0,1])
    break
# Out:
# loading X_tr...
# loading Y_tr...
# finished.
# loading X_vl...
# loading Y_vl...
# finished.
# loading X_te...
# loading Y_te...
# finished.
# Length of trainig_dataset:	1316
# Length of validation_dataset:	527
# Length of test_dataset:		790
# Training
# Validation
# Test

# %% [markdown]
# ### Device

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Torch device: {device}")
# Out:
# Torch device: cuda

# %% [markdown]
# ## Metrics

# %%
metrics = torchmetrics.MetricCollection(
    [
        torchmetrics.F1Score(),
        torchmetrics.Accuracy(),
        torchmetrics.Dice(),
        torchmetrics.Precision(),
        torchmetrics.Specificity(),
        torchmetrics.Recall(),
        # IoU
        torchmetrics.JaccardIndex(2)
    ],
    prefix='train_metrics/'
)

# train_metrics
train_metrics = metrics.clone(prefix='train_metrics/').to(device)

# valid_metrics
valid_metrics = metrics.clone(prefix='valid_metrics/').to(device)

# test_metrics
test_metrics = metrics.clone(prefix='test_metrics/').to(device)

# %%
def make_serializeable_metrics(computed_metrics):
    res = {}
    for k, v in computed_metrics.items():
        res[k] = float(v.cpu().detach().numpy())
    return res

# %% [markdown]
# ## Define validate function

# %%
def validate(model, criterion, vl_dataloader):
    model.eval()
    with torch.no_grad():
        
        evaluator = valid_metrics.clone().to(device)
        
        losses = []
        cnt = 0.
        for batch, batch_data in enumerate(vl_dataloader):
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            cnt += msks.shape[0]
            
            imgs = imgs.to(device)
            msks = msks.to(device)
            
            preds = model(imgs)
            loss = criterion(preds, msks)
            losses.append(loss.item())
            
            # we should remove nucs
            not_nucs = torch.where(imgs[:,-1,:,:]>0, 0, 1)
            preds_en = torch.argmax(preds, 1, keepdim=False).float() * not_nucs
            msks_en = torch.argmax(msks, 1, keepdim=False) * not_nucs
            
            # evaluate by metrics
            evaluator.update(preds_en, msks_en.int())
        
#             _cml = f"curr_mean-loss:{np.sum(losses)/cnt:0.5f}"
#             _bl = f"batch-loss:{losses[-1]/msks.shape[0]:0.5f}"
#             iterator.set_description(f"Validation) batch:{batch+1:04d} -> {_cml}, {_bl}")
        
        # print the final results
        loss = np.sum(losses)/cnt
        metrics = evaluator.compute()
    
    return evaluator, loss

# %% [markdown]
# ## Define train function

# %%
def train(
    model, 
    device, 
    tr_dataloader,
    vl_dataloader,
    config,
    
    criterion,
    optimizer,
    scheduler,
    
    save_dir='./',
    save_file_id=None,
):
    tr_prms = config['training']
    EPOCHS = tr_prms['epochs']
    
    torch.cuda.empty_cache()
    model = model.to(device)
    
    evaluator = train_metrics.clone().to(device)

    epochs_info = []
    best_model = None
    best_result = {}
    best_vl_loss = np.Inf
    for epoch in range(EPOCHS):
        model.train()
        
        evaluator.reset()
        tr_iterator = tqdm(enumerate(tr_dataloader))
        tr_losses = []
        cnt = 0
        for batch, batch_data in tr_iterator:
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            imgs = imgs.to(device)
            msks = msks.to(device)

            optimizer.zero_grad()
            preds = model(imgs)
            loss = criterion(preds, msks)
            loss.backward()
            optimizer.step()
            
            # we should remove nucs
            not_nucs = torch.where(imgs[:,-1,:,:]>0, 0, 1)
            preds_en = torch.argmax(preds, 1, keepdim=False).float() * not_nucs
            msks_en = torch.argmax(msks, 1, keepdim=False) * not_nucs
            
            # evaluate by metrics
            evaluator.update(preds_en, msks_en.int())
            
            cnt += imgs.shape[0]
            tr_losses.append(loss.item())
            
            # write details for each training batch
            _cml = f"curr_mean-loss:{np.sum(tr_losses)/cnt:0.5f}"
            _bl = f"mean_batch-loss:{tr_losses[-1]/imgs.shape[0]:0.5f}"
            tr_iterator.set_description(f"Training) ep:{epoch:03d}, batch:{batch+1:04d} -> {_cml}, {_bl}")
        
        tr_loss = np.sum(tr_losses)/cnt
        
        # validate model
        vl_metrics, vl_loss = validate(model, criterion, vl_dataloader)
        if vl_loss < best_vl_loss:
            # find a better model
            best_model = model
            best_vl_loss = vl_loss
            best_result = {
                'tr_loss': tr_loss,
                'vl_loss': vl_loss,
                'tr_metrics': make_serializeable_metrics(evaluator.compute()),
                'vl_metrics': make_serializeable_metrics(vl_metrics.compute())
            }
        
        # write the final results
        epoch_info = {
            'tr_loss': tr_loss,
            'vl_loss': vl_loss,
            'tr_metrics': make_serializeable_metrics(evaluator.compute()),
            'vl_metrics': make_serializeable_metrics(vl_metrics.compute())
        }
        epochs_info.append(epoch_info)
#         epoch_tqdm.set_description(f"Epoch:{epoch+1}/{EPOCHS} -> tr_loss:{tr_loss}, vl_loss:{vl_loss}")
        evaluator.reset()
    
        scheduler.step(vl_loss)
  
    # save final results
    res = {
        'id': save_file_id,
        'config': config,
        'epochs_info': epochs_info,
        'best_result': best_result
    }
    fn = f"{save_file_id+'_' if save_file_id else ''}result.json"
    fp = os.path.join(config['model']['save_dir'],fn)
    with open(fp, "w") as write_file:
        json.dump(res, write_file, indent=4)

    # save model's state_dict
    fn = "last_model_state_dict.pt"
    fp = os.path.join(config['model']['save_dir'],fn)
    torch.save(model.state_dict(), fp)
    
    # save the best model's state_dict
    fn = "best_model_state_dict.pt"
    fp = os.path.join(config['model']['save_dir'], fn)
    torch.save(best_model.state_dict(), fp)
    
    return best_model, model, res

# %% [markdown]
# ## Define test function

# %%
def test(model, te_dataloader):
    model.eval()
    with torch.no_grad():
        evaluator = test_metrics.clone().to(device)
        for batch_data in tqdm(te_dataloader):
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            imgs = imgs.to(device)
            msks = msks.to(device)
            
            preds = model(imgs)
            
            # we should remove nucs
            not_nucs = torch.where(imgs[:,-1,:,:]>0, 0, 1)
            preds_en = torch.argmax(preds, 1, keepdim=False).float() * not_nucs
            msks_en = torch.argmax(msks, 1, keepdim=False) * not_nucs
            
            # evaluate by metrics
            evaluator.update(preds_en, msks_en.int())
    return evaluator

# %% [markdown]
# ## Load and prepare model

# %%
from models.attunet import AttU_Net as Net


model = Net(**config['model']['params'])
torch.cuda.empty_cache()
model = model.to(device)
print("Number of parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))

os.makedirs(config['model']['save_dir'], exist_ok=True)
model_path = f"{config['model']['save_dir']}/model_state_dict.pt"

if config['model']['load_weights']:
    model.load_state_dict(torch.load(model_path))
    print("Loaded pre-trained weights...")
    
    
# criterion_dice = DiceLoss()
criterion_dice = DiceLossWithLogtis()
# criterion_ce  = BCELoss()
criterion_ce  = CrossEntropyLoss()


def criterion(preds, masks):
    c_dice = criterion_dice(preds, masks)
    c_ce = criterion_ce(preds, masks)
    return 0.5*c_dice + 0.5*c_ce

tr_prms = config['training']
optimizer = globals()[tr_prms['optimizer']['name']](model.parameters(), **tr_prms['optimizer']['params'])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', **tr_prms['scheduler'])
# Out:
# Number of parameters: 34879214

# %% [markdown]
# ## Start traning

# %%
best_model, model, res = train(
    model, 
    device, 
    tr_dataloader,
    vl_dataloader,
    config,
    
    criterion,
    optimizer,
    scheduler,

    save_dir = config['model']['save_dir'],
    save_file_id = None,
)
# Out:
# Training) ep:000, batch:0083 -> curr_mean-loss:0.01382, mean_batch-loss:0.03938: : 83it [00:26,  3.17it/s]
# Training) ep:001, batch:0083 -> curr_mean-loss:0.00921, mean_batch-loss:0.03561: : 83it [00:20,  4.03it/s]
# Training) ep:002, batch:0083 -> curr_mean-loss:0.00731, mean_batch-loss:0.01984: : 83it [00:20,  4.08it/s]
# Training) ep:003, batch:0083 -> curr_mean-loss:0.00582, mean_batch-loss:0.01582: : 83it [00:20,  4.08it/s]
# Training) ep:004, batch:0083 -> curr_mean-loss:0.00502, mean_batch-loss:0.01977: : 83it [00:20,  4.08it/s]
# Training) ep:005, batch:0083 -> curr_mean-loss:0.00426, mean_batch-loss:0.02096: : 83it [00:20,  4.08it/s]
# Training) ep:006, batch:0083 -> curr_mean-loss:0.00384, mean_batch-loss:0.01139: : 83it [00:20,  4.08it/s]
# Training) ep:007, batch:0083 -> curr_mean-loss:0.00349, mean_batch-loss:0.01267: : 83it [00:20,  4.08it/s]
# Training) ep:008, batch:0083 -> curr_mean-loss:0.00335, mean_batch-loss:0.01140: : 83it [00:20,  4.08it/s]
# Training) ep:009, batch:0083 -> curr_mean-loss:0.00297, mean_batch-loss:0.01679: : 83it [00:20,  4.09it/s]
# Training) ep:010, batch:0083 -> curr_mean-loss:0.00286, mean_batch-loss:0.00688: : 83it [00:20,  4.08it/s]
# Training) ep:011, batch:0083 -> curr_mean-loss:0.00253, mean_batch-loss:0.00778: : 83it [00:20,  4.09it/s]
# Training) ep:012, batch:0083 -> curr_mean-loss:0.00245, mean_batch-loss:0.00774: : 83it [00:20,  4.08it/s]
# Training) ep:013, batch:0083 -> curr_mean-loss:0.00245, mean_batch-loss:0.00721: : 83it [00:25,  3.28it/s]
# Training) ep:014, batch:0083 -> curr_mean-loss:0.00234, mean_batch-loss:0.00666: : 83it [00:40,  2.03it/s]
# Training) ep:015, batch:0083 -> curr_mean-loss:0.00221, mean_batch-loss:0.00852: : 83it [00:40,  2.03it/s]
# Training) ep:016, batch:0083 -> curr_mean-loss:0.00206, mean_batch-loss:0.00868: : 83it [00:40,  2.03it/s]
# Training) ep:017, batch:0083 -> curr_mean-loss:0.00204, mean_batch-loss:0.00819: : 83it [00:40,  2.03it/s]
# Training) ep:018, batch:0083 -> curr_mean-loss:0.00208, mean_batch-loss:0.00606: : 83it [00:40,  2.03it/s]
# Training) ep:019, batch:0083 -> curr_mean-loss:0.00186, mean_batch-loss:0.00615: : 83it [00:40,  2.03it/s]
# Training) ep:020, batch:0083 -> curr_mean-loss:0.00181, mean_batch-loss:0.00568: : 83it [00:41,  2.01it/s]
# Training) ep:021, batch:0083 -> curr_mean-loss:0.00205, mean_batch-loss:0.01033: : 83it [00:41,  2.01it/s]
# Training) ep:022, batch:0083 -> curr_mean-loss:0.00182, mean_batch-loss:0.00951: : 83it [00:41,  2.01it/s]
# Training) ep:023, batch:0083 -> curr_mean-loss:0.00174, mean_batch-loss:0.00558: : 83it [00:40,  2.03it/s]
# Training) ep:024, batch:0083 -> curr_mean-loss:0.00159, mean_batch-loss:0.00730: : 83it [00:40,  2.03it/s]
# Training) ep:025, batch:0083 -> curr_mean-loss:0.00152, mean_batch-loss:0.00478: : 83it [00:40,  2.03it/s]
# Training) ep:026, batch:0083 -> curr_mean-loss:0.00146, mean_batch-loss:0.00785: : 83it [00:40,  2.03it/s]
# Training) ep:027, batch:0083 -> curr_mean-loss:0.00137, mean_batch-loss:0.00464: : 83it [00:40,  2.04it/s]
# Training) ep:028, batch:0083 -> curr_mean-loss:0.00140, mean_batch-loss:0.00445: : 83it [00:40,  2.03it/s]
# Training) ep:029, batch:0083 -> curr_mean-loss:0.00133, mean_batch-loss:0.00725: : 83it [00:40,  2.03it/s]
# Training) ep:030, batch:0083 -> curr_mean-loss:0.00143, mean_batch-loss:0.00491: : 83it [00:40,  2.03it/s]
# Training) ep:031, batch:0083 -> curr_mean-loss:0.00185, mean_batch-loss:0.00448: : 83it [00:40,  2.03it/s]
# Training) ep:032, batch:0083 -> curr_mean-loss:0.00169, mean_batch-loss:0.00747: : 83it [00:41,  2.01it/s]
# Training) ep:033, batch:0083 -> curr_mean-loss:0.00164, mean_batch-loss:0.01299: : 83it [00:41,  2.02it/s]
# Training) ep:034, batch:0083 -> curr_mean-loss:0.00146, mean_batch-loss:0.00671: : 83it [00:41,  2.01it/s]
# Training) ep:035, batch:0083 -> curr_mean-loss:0.00128, mean_batch-loss:0.00807: : 83it [00:40,  2.03it/s]
# Training) ep:036, batch:0083 -> curr_mean-loss:0.00126, mean_batch-loss:0.00448: : 83it [00:40,  2.04it/s]
# Training) ep:037, batch:0083 -> curr_mean-loss:0.00120, mean_batch-loss:0.00403: : 83it [00:40,  2.03it/s]
# Training) ep:038, batch:0083 -> curr_mean-loss:0.00116, mean_batch-loss:0.00578: : 83it [00:40,  2.03it/s]
# Training) ep:039, batch:0083 -> curr_mean-loss:0.00118, mean_batch-loss:0.01048: : 83it [00:40,  2.04it/s]
# Training) ep:040, batch:0083 -> curr_mean-loss:0.00119, mean_batch-loss:0.00406: : 83it [00:40,  2.03it/s]
# Training) ep:041, batch:0083 -> curr_mean-loss:0.00110, mean_batch-loss:0.00503: : 83it [00:40,  2.03it/s]
# Training) ep:042, batch:0083 -> curr_mean-loss:0.00110, mean_batch-loss:0.00605: : 83it [00:40,  2.03it/s]
# Training) ep:043, batch:0083 -> curr_mean-loss:0.00137, mean_batch-loss:0.00385: : 83it [00:40,  2.03it/s]
# Training) ep:044, batch:0083 -> curr_mean-loss:0.00142, mean_batch-loss:0.00553: : 83it [00:41,  2.01it/s]
# Training) ep:045, batch:0083 -> curr_mean-loss:0.00125, mean_batch-loss:0.00563: : 83it [00:41,  2.02it/s]
# Training) ep:046, batch:0083 -> curr_mean-loss:0.00108, mean_batch-loss:0.00423: : 83it [00:41,  2.01it/s]
# Training) ep:047, batch:0083 -> curr_mean-loss:0.00102, mean_batch-loss:0.00357: : 83it [00:40,  2.03it/s]
# Training) ep:048, batch:0083 -> curr_mean-loss:0.00099, mean_batch-loss:0.00281: : 83it [00:40,  2.03it/s]
# Training) ep:049, batch:0083 -> curr_mean-loss:0.00098, mean_batch-loss:0.00483: : 83it [00:40,  2.03it/s]
# Training) ep:050, batch:0083 -> curr_mean-loss:0.00096, mean_batch-loss:0.00376: : 83it [00:40,  2.03it/s]
# Training) ep:051, batch:0083 -> curr_mean-loss:0.00094, mean_batch-loss:0.00400: : 83it [00:40,  2.04it/s]
# Training) ep:052, batch:0083 -> curr_mean-loss:0.00092, mean_batch-loss:0.00401: : 83it [00:40,  2.03it/s]
# Training) ep:053, batch:0083 -> curr_mean-loss:0.00090, mean_batch-loss:0.00349: : 83it [00:40,  2.03it/s]
# Training) ep:054, batch:0083 -> curr_mean-loss:0.00088, mean_batch-loss:0.00378: : 83it [00:40,  2.03it/s]
# Training) ep:055, batch:0083 -> curr_mean-loss:0.00086, mean_batch-loss:0.00343: : 83it [00:40,  2.03it/s]
# Training) ep:056, batch:0083 -> curr_mean-loss:0.00086, mean_batch-loss:0.00302: : 83it [00:41,  2.00it/s]
# Training) ep:057, batch:0083 -> curr_mean-loss:0.00083, mean_batch-loss:0.00347: : 83it [00:41,  2.01it/s]
# Training) ep:058, batch:0083 -> curr_mean-loss:0.00079, mean_batch-loss:0.00296: : 83it [00:41,  2.02it/s]
# Training) ep:059, batch:0083 -> curr_mean-loss:0.00077, mean_batch-loss:0.00294: : 83it [00:40,  2.03it/s]
# Training) ep:060, batch:0083 -> curr_mean-loss:0.00075, mean_batch-loss:0.00298: : 83it [00:40,  2.03it/s]
# Training) ep:061, batch:0083 -> curr_mean-loss:0.00074, mean_batch-loss:0.00298: : 83it [00:40,  2.03it/s]
# Training) ep:062, batch:0083 -> curr_mean-loss:0.00072, mean_batch-loss:0.00260: : 83it [00:40,  2.03it/s]
# Training) ep:063, batch:0083 -> curr_mean-loss:0.00071, mean_batch-loss:0.00258: : 83it [00:40,  2.03it/s]
# Training) ep:064, batch:0083 -> curr_mean-loss:0.00070, mean_batch-loss:0.00262: : 83it [00:40,  2.03it/s]
# Training) ep:065, batch:0083 -> curr_mean-loss:0.00068, mean_batch-loss:0.00210: : 83it [00:40,  2.03it/s]
# Training) ep:066, batch:0083 -> curr_mean-loss:0.00069, mean_batch-loss:0.00381: : 83it [00:40,  2.03it/s]
# Training) ep:067, batch:0083 -> curr_mean-loss:0.00067, mean_batch-loss:0.00257: : 83it [00:40,  2.04it/s]
# Training) ep:068, batch:0083 -> curr_mean-loss:0.00066, mean_batch-loss:0.00283: : 83it [00:41,  2.00it/s]
# Training) ep:069, batch:0083 -> curr_mean-loss:0.00063, mean_batch-loss:0.00338: : 83it [00:41,  2.01it/s]
# Training) ep:070, batch:0083 -> curr_mean-loss:0.00061, mean_batch-loss:0.00225: : 83it [00:41,  2.01it/s]
# Training) ep:071, batch:0083 -> curr_mean-loss:0.00060, mean_batch-loss:0.00364: : 83it [00:40,  2.02it/s]
# Training) ep:072, batch:0083 -> curr_mean-loss:0.00060, mean_batch-loss:0.00231: : 83it [00:40,  2.03it/s]
# Training) ep:073, batch:0083 -> curr_mean-loss:0.00058, mean_batch-loss:0.00271: : 83it [00:40,  2.03it/s]
# Training) ep:074, batch:0083 -> curr_mean-loss:0.00058, mean_batch-loss:0.00251: : 83it [00:40,  2.03it/s]
# Training) ep:075, batch:0083 -> curr_mean-loss:0.00057, mean_batch-loss:0.00330: : 83it [00:40,  2.03it/s]
# Training) ep:076, batch:0083 -> curr_mean-loss:0.00056, mean_batch-loss:0.00222: : 83it [00:40,  2.03it/s]
# Training) ep:077, batch:0083 -> curr_mean-loss:0.00055, mean_batch-loss:0.00261: : 83it [00:40,  2.04it/s]
# Training) ep:078, batch:0083 -> curr_mean-loss:0.00055, mean_batch-loss:0.00239: : 83it [00:40,  2.03it/s]
# Training) ep:079, batch:0083 -> curr_mean-loss:0.00054, mean_batch-loss:0.00238: : 83it [00:41,  2.02it/s]
# Training) ep:080, batch:0083 -> curr_mean-loss:0.00052, mean_batch-loss:0.00232: : 83it [00:41,  2.00it/s]
# Training) ep:081, batch:0083 -> curr_mean-loss:0.00052, mean_batch-loss:0.00201: : 83it [00:41,  2.01it/s]
# Training) ep:082, batch:0083 -> curr_mean-loss:0.00051, mean_batch-loss:0.00207: : 83it [00:40,  2.03it/s]
# Training) ep:083, batch:0083 -> curr_mean-loss:0.00051, mean_batch-loss:0.00243: : 83it [00:40,  2.03it/s]
# Training) ep:084, batch:0083 -> curr_mean-loss:0.00050, mean_batch-loss:0.00209: : 83it [00:40,  2.03it/s]
# Training) ep:085, batch:0083 -> curr_mean-loss:0.00050, mean_batch-loss:0.00262: : 83it [00:40,  2.03it/s]
# Training) ep:086, batch:0083 -> curr_mean-loss:0.00050, mean_batch-loss:0.00209: : 83it [00:40,  2.03it/s]
# Training) ep:087, batch:0083 -> curr_mean-loss:0.00049, mean_batch-loss:0.00254: : 83it [00:40,  2.03it/s]
# Training) ep:088, batch:0083 -> curr_mean-loss:0.00049, mean_batch-loss:0.00217: : 83it [00:40,  2.03it/s]
# Training) ep:089, batch:0083 -> curr_mean-loss:0.00048, mean_batch-loss:0.00208: : 83it [00:40,  2.03it/s]
# Training) ep:090, batch:0083 -> curr_mean-loss:0.00048, mean_batch-loss:0.00199: : 83it [00:40,  2.04it/s]
# Training) ep:091, batch:0083 -> curr_mean-loss:0.00047, mean_batch-loss:0.00194: : 83it [00:41,  2.01it/s]
# Training) ep:092, batch:0083 -> curr_mean-loss:0.00047, mean_batch-loss:0.00187: : 83it [00:41,  2.00it/s]
# Training) ep:093, batch:0083 -> curr_mean-loss:0.00047, mean_batch-loss:0.00226: : 83it [00:41,  2.01it/s]
# Training) ep:094, batch:0083 -> curr_mean-loss:0.00046, mean_batch-loss:0.00230: : 83it [00:40,  2.04it/s]
# Training) ep:095, batch:0083 -> curr_mean-loss:0.00046, mean_batch-loss:0.00230: : 83it [00:40,  2.03it/s]
# Training) ep:096, batch:0083 -> curr_mean-loss:0.00046, mean_batch-loss:0.00154: : 83it [00:40,  2.03it/s]
# Training) ep:097, batch:0083 -> curr_mean-loss:0.00046, mean_batch-loss:0.00196: : 83it [00:40,  2.03it/s]
# Training) ep:098, batch:0083 -> curr_mean-loss:0.00045, mean_batch-loss:0.00211: : 83it [00:40,  2.03it/s]
# Training) ep:099, batch:0083 -> curr_mean-loss:0.00045, mean_batch-loss:0.00209: : 83it [00:40,  2.03it/s]

# %%
te_metrics = test(best_model, te_dataloader)
te_metrics.compute()
# Out:
# 100%|██████████| 50/50 [00:08<00:00,  5.75it/s]
# {'test_metrics/F1Score': tensor(0.9158, device='cuda:0'),
#  'test_metrics/Accuracy': tensor(0.9854, device='cuda:0'),
#  'test_metrics/Dice': tensor(0.9158, device='cuda:0'),
#  'test_metrics/Precision': tensor(0.9360, device='cuda:0'),
#  'test_metrics/Recall': tensor(0.8964, device='cuda:0'),
#  'test_metrics/JaccardIndex': tensor(0.9144, device='cuda:0')}

# %%
f"{config['model']['save_dir']}"
# Out:
# '../saved_models/segpc2021_attunet'

# %% [markdown]
# # Test the best inferred model
# ----

# %% [markdown]
# ## Load the best model

# %%
best_model = Net(**config['model']['params'])
torch.cuda.empty_cache()
best_model = best_model.to(device)

fn = "best_model_state_dict.pt"
os.makedirs(config['model']['save_dir'], exist_ok=True)
model_path = f"{config['model']['save_dir']}/{fn}"

best_model.load_state_dict(torch.load(model_path))
print("Loaded best model weights...")
# Out:
# Loaded best model weights...

# %% [markdown]
# ## Evaluation

# %%
te_metrics = test(best_model, te_dataloader)
te_metrics.compute()
# Out:
# 100%|██████████| 50/50 [00:08<00:00,  6.22it/s]
# {'test_metrics/F1Score': tensor(0.9158, device='cuda:0'),
#  'test_metrics/Accuracy': tensor(0.9854, device='cuda:0'),
#  'test_metrics/Dice': tensor(0.9158, device='cuda:0'),
#  'test_metrics/Precision': tensor(0.9360, device='cuda:0'),
#  'test_metrics/Recall': tensor(0.8964, device='cuda:0'),
#  'test_metrics/Specificity': tensor(0.9940, device='cuda:0'),
#  'test_metrics/JaccardIndex': tensor(0.9144, device='cuda:0')}

# %% [markdown]
# ## Plot graphs

# %%
result_file_path = f"{config['model']['save_dir']}/result.json"
with open(result_file_path, 'r') as f:
    results = json.loads(''.join(f.readlines()))
epochs_info = results['epochs_info']

tr_losses = [d['tr_loss'] for d in epochs_info]
vl_losses = [d['vl_loss'] for d in epochs_info]
tr_dice = [d['tr_metrics']['train_metrics/Dice'] for d in epochs_info]
vl_dice = [d['vl_metrics']['valid_metrics/Dice'] for d in epochs_info]
tr_js = [d['tr_metrics']['train_metrics/JaccardIndex'] for d in epochs_info]
vl_js = [d['vl_metrics']['valid_metrics/JaccardIndex'] for d in epochs_info]
tr_acc = [d['tr_metrics']['train_metrics/Accuracy'] for d in epochs_info]
vl_acc = [d['vl_metrics']['valid_metrics/Accuracy'] for d in epochs_info]


_, axs = plt.subplots(1, 4, figsize=[16,3])

axs[0].set_title("Loss")
axs[0].plot(tr_losses, 'r-', label="train loss")
axs[0].plot(vl_losses, 'b-', label="validatiton loss")
axs[0].legend()

axs[1].set_title("Dice score")
axs[1].plot(tr_dice, 'r-', label="train dice")
axs[1].plot(vl_dice, 'b-', label="validation dice")
axs[1].legend()

axs[2].set_title("Jaccard Similarity")
axs[2].plot(tr_js, 'r-', label="train JaccardIndex")
axs[2].plot(vl_js, 'b-', label="validatiton JaccardIndex")
axs[2].legend()

axs[3].set_title("Accuracy")
axs[3].plot(tr_acc, 'r-', label="train Accuracy")
axs[3].plot(vl_acc, 'b-', label="validation Accuracy")
axs[3].legend()

plt.show()

# %%
epochs_info

# %% [markdown]
# ## Save images

# %%
from PIL import Image


save_imgs_dir = f"{config['model']['save_dir']}/visualized"

if not os.path.isdir(save_imgs_dir):
    os.mkdir(save_imgs_dir)

with torch.no_grad():
    for batch in tqdm(te_dataloader):
        imgs = batch['image']
        msks = batch['mask']
        ids = batch['id']
        
        preds = best_model(imgs.to(device))
        
        txm = imgs.cpu().numpy()
        tbm = torch.argmax(msks, 1).cpu().numpy()
        tpm = torch.argmax(preds, 1).cpu().numpy()
        tid = ids.cpu().numpy()
        
        for idx in range(len(tbm)):
            img = np.moveaxis(txm[idx, :3], 0, -1)*255.
            nuc = np.uint8(txm[idx, -1]*255.)
            gt = np.uint8(tbm[idx]*255.)
            gt_3ch = np.stack([gt-nuc, nuc*0, nuc], -1)
            pred = np.where(tpm[idx]>0.5, 255, 0)
            pred_3ch = np.stack([pred-nuc, nuc*0, nuc], -1)
            
            img = np.ascontiguousarray(img, dtype=np.uint8)
            gt_3ch = np.ascontiguousarray(gt_3ch, dtype=np.uint8)
            pred_3ch = np.ascontiguousarray(pred_3ch, dtype=np.uint8)
            
            fid = tid[idx]
            Image.fromarray(img).save(f"{save_imgs_dir}/{fid}_img.png")
            Image.fromarray(gt_3ch).save(f"{save_imgs_dir}/{fid}_gt.png")
            Image.fromarray(pred_3ch).save(f"{save_imgs_dir}/{fid}_pred.png")
# Out:
# 100%|██████████| 50/50 [00:09<00:00,  5.07it/s]

# %%
f"{config['model']['save_dir']}/visualized"
# Out:
# '../saved_models/segpc2021_attunet/visualized'
