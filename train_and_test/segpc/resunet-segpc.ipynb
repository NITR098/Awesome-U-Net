# %% [markdown]
# # Residual UNet - SegPC2021
# ---

# %% [markdown]
# ## Import packages & functions

# %%
from __future__ import print_function, division


import os
import sys
sys.path.append('../..')
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import copy
import json
import importlib
import glob
import pandas as pd
from skimage import io, transform
import matplotlib.pyplot as plt
from matplotlib.image import imread
import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchmetrics
from torch.optim import Adam, SGD
from losses import DiceLoss, DiceLossWithLogtis
from torch.nn import BCELoss, CrossEntropyLoss

from utils import (
    show_sbs,
    load_config,
    _print,
)

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# plt.ion()   # interactive mode

# %% [markdown]
# ## Set the seed

# %%
torch.manual_seed(0)
np.random.seed(0)
torch.cuda.manual_seed(0)
import random
random.seed(0)

# %% [markdown]
# ## Load the config

# %%
CONFIG_NAME = "segpc/segpc2021_resunet.yaml"
CONFIG_FILE_PATH = os.path.join("./configs", CONFIG_NAME)

# %%
config = load_config(CONFIG_FILE_PATH)
_print("Config:", "info_underline")
print(json.dumps(config, indent=2))
print(20*"~-", "\n")
# Out:
# Config:
# {
#   "run": {
#     "mode": "train",
#     "device": "gpu"
#   },
#   "transforms": "none",
#   "dataset": {
#     "class_name": "SegPC2021Dataset",
#     "input_size": 224,
#     "scale": 2.5,
#     "data_dir": "/path/to/datasets/segpc/np",
#     "dataset_dir": "/path/to/datasets/segpc/TCIA_SegPC_dataset",
#     "number_classes": 2
#   },
#   "data_loader": {
#     "train": {
#       "batch_size": 16,
#       "shuffle": true,
#       "num_workers": 4,
#       "pin_memory": true
#     },
#     "validation": {
#       "batch_size": 16,
#       "shuffle": false,
#       "num_workers": 4,
#       "pin_memory": true
#     },
#     "test": {
#       "batch_size": 16,
#       "shuffle": false,
#       "num_workers": 4,
#       "pin_memory": false
#     }
#   },
#   "training": {
#     "optimizer": {
#       "name": "Adam",
#       "params": {
#         "lr": 0.0001
#       }
#     },
#     "criterion": {
#       "name": "DiceLoss",
#       "params": {}
#     },
#     "scheduler": {
#       "factor": 0.5,
#       "patience": 10
#     },
#     "epochs": 100
#   },
#   "model": {
#     "save_dir": "../saved_models/segpc2021_resunet",
#     "load_weights": false,
#     "name": "ResUnet",
#     "params": {
#       "in_ch": 4,
#       "out_ch": 2
#     }
#   }
# }
# ~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-

# %% [markdown]
# ## Dataset and Dataloader

# %%
from datasets.segpc import SegPC2021Dataset
from torch.utils.data import DataLoader, Subset
from torchvision import transforms

# %%
# ----------------- transform ------------------
# transform for image
img_transform = transforms.Compose([
    transforms.ToTensor()
])
# transform for mask
msk_transform = transforms.Compose([
    transforms.ToTensor()
])
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<


# ----------------- dataset --------------------
# preparing training dataset
tr_dataset = SegPC2021Dataset(
    mode="tr",
    input_size=config['dataset']['input_size'],
    scale=config['dataset']['scale'],
    data_dir=config['dataset']['data_dir'], 
    dataset_dir=config['dataset']['dataset_dir'],
    one_hot=True,
    force_rebuild=False,
    img_transform=img_transform,
    msk_transform=msk_transform
)
# preparing training dataset
vl_dataset = SegPC2021Dataset(
    mode="vl",
    input_size=config['dataset']['input_size'],
    scale=config['dataset']['scale'],
    data_dir=config['dataset']['data_dir'], 
    dataset_dir=config['dataset']['dataset_dir'],
    one_hot=True,
    force_rebuild=False,
    img_transform=img_transform,
    msk_transform=msk_transform
)
# preparing training dataset
te_dataset = SegPC2021Dataset(
    mode="te",
    input_size=config['dataset']['input_size'],
    scale=config['dataset']['scale'],
    data_dir=config['dataset']['data_dir'], 
    dataset_dir=config['dataset']['dataset_dir'],
    one_hot=True,
    force_rebuild=False,
    img_transform=img_transform,
    msk_transform=msk_transform
)


def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(0)

# prepare train dataloader
tr_dataloader = DataLoader(tr_dataset, worker_init_fn=seed_worker, generator=g, **config['data_loader']['train'])

# prepare validation dataloader
vl_dataloader = DataLoader(vl_dataset, worker_init_fn=seed_worker, generator=g, **config['data_loader']['validation'])

# prepare test dataloader
te_dataloader = DataLoader(te_dataset, worker_init_fn=seed_worker, generator=g, **config['data_loader']['test'])



print(f"Length of trainig_dataset:\t{len(tr_dataset)}")
print(f"Length of validation_dataset:\t{len(vl_dataset)}")
print(f"Length of test_dataset:\t\t{len(te_dataset)}")

# -------------- test -----------------
# test and visualize the input data
for batch in tr_dataloader:
    img = batch['image']
    msk = batch['mask']
    print("Training")
    show_sbs(img[0,:-1,:,:], msk[0,1])
    break
    
for batch in vl_dataloader:
    img = batch['image']
    msk = batch['mask']
    print("Validation")
    show_sbs(img[0,:-1,:,:], msk[0,1])
    break
    
for batch in te_dataloader:
    img = batch['image']
    msk = batch['mask']
    print("Test")
    show_sbs(img[0,:-1,:,:], msk[0,1])
    break
# Out:
# loading X_tr...
# loading Y_tr...
# finished.
# loading X_vl...
# loading Y_vl...
# finished.
# loading X_te...
# loading Y_te...
# finished.
# Length of trainig_dataset:	1316
# Length of validation_dataset:	527
# Length of test_dataset:		790
# Training
# Validation
# Test

# %% [markdown]
# ### Device

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Torch device: {device}")
# Out:
# Torch device: cuda

# %% [markdown]
# ## Metrics

# %%
metrics = torchmetrics.MetricCollection(
    [
        torchmetrics.F1Score(),
        torchmetrics.Accuracy(),
        torchmetrics.Dice(),
        torchmetrics.Precision(),
        torchmetrics.Specificity(),
        torchmetrics.Recall(),
        # IoU
        torchmetrics.JaccardIndex(2)
    ],
    prefix='train_metrics/'
)

# train_metrics
train_metrics = metrics.clone(prefix='train_metrics/').to(device)

# valid_metrics
valid_metrics = metrics.clone(prefix='valid_metrics/').to(device)

# test_metrics
test_metrics = metrics.clone(prefix='test_metrics/').to(device)

# %%
def make_serializeable_metrics(computed_metrics):
    res = {}
    for k, v in computed_metrics.items():
        res[k] = float(v.cpu().detach().numpy())
    return res

# %% [markdown]
# ## Define validate function

# %%
def validate(model, criterion, vl_dataloader):
    model.eval()
    with torch.no_grad():
        
        evaluator = valid_metrics.clone().to(device)
        
        losses = []
        cnt = 0.
        for batch, batch_data in enumerate(vl_dataloader):
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            cnt += msks.shape[0]
            
            imgs = imgs.to(device)
            msks = msks.to(device)
            
            preds = model(imgs)
            loss = criterion(preds, msks)
            losses.append(loss.item())
            
            # we should remove nucs
            not_nucs = torch.where(imgs[:,-1,:,:]>0, 0, 1)
            preds_en = torch.argmax(preds, 1, keepdim=False).float() * not_nucs
            msks_en = torch.argmax(msks, 1, keepdim=False) * not_nucs
            
            # evaluate by metrics
            evaluator.update(preds_en, msks_en.int())
        
#             _cml = f"curr_mean-loss:{np.sum(losses)/cnt:0.5f}"
#             _bl = f"batch-loss:{losses[-1]/msks.shape[0]:0.5f}"
#             iterator.set_description(f"Validation) batch:{batch+1:04d} -> {_cml}, {_bl}")
        
        # print the final results
        loss = np.sum(losses)/cnt
        metrics = evaluator.compute()
    
    return evaluator, loss

# %% [markdown]
# ## Define train function

# %%
def train(
    model, 
    device, 
    tr_dataloader,
    vl_dataloader,
    config,
    
    criterion,
    optimizer,
    scheduler,
    
    save_dir='./',
    save_file_id=None,
):
    tr_prms = config['training']
    EPOCHS = tr_prms['epochs']
    
    torch.cuda.empty_cache()
    model = model.to(device)
    
    evaluator = train_metrics.clone().to(device)

    epochs_info = []
    best_model = None
    best_result = {}
    best_vl_loss = np.Inf
    for epoch in range(EPOCHS):
        model.train()
        
        evaluator.reset()
        tr_iterator = tqdm(enumerate(tr_dataloader))
        tr_losses = []
        cnt = 0
        for batch, batch_data in tr_iterator:
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            imgs = imgs.to(device)
            msks = msks.to(device)

            optimizer.zero_grad()
            preds = model(imgs)
            loss = criterion(preds, msks)
            loss.backward()
            optimizer.step()
            
            # we should remove nucs
            not_nucs = torch.where(imgs[:,-1,:,:]>0, 0, 1)
            preds_en = torch.argmax(preds, 1, keepdim=False).float() * not_nucs
            msks_en = torch.argmax(msks, 1, keepdim=False) * not_nucs
            
            # evaluate by metrics
            evaluator.update(preds_en, msks_en.int())
            
            cnt += imgs.shape[0]
            tr_losses.append(loss.item())
            
            # write details for each training batch
            _cml = f"curr_mean-loss:{np.sum(tr_losses)/cnt:0.5f}"
            _bl = f"mean_batch-loss:{tr_losses[-1]/imgs.shape[0]:0.5f}"
            tr_iterator.set_description(f"Training) ep:{epoch:03d}, batch:{batch+1:04d} -> {_cml}, {_bl}")
        
        tr_loss = np.sum(tr_losses)/cnt
        
        # validate model
        vl_metrics, vl_loss = validate(model, criterion, vl_dataloader)
        if vl_loss < best_vl_loss:
            # find a better model
            best_model = model
            best_vl_loss = vl_loss
            best_result = {
                'tr_loss': tr_loss,
                'vl_loss': vl_loss,
                'tr_metrics': make_serializeable_metrics(evaluator.compute()),
                'vl_metrics': make_serializeable_metrics(vl_metrics.compute())
            }
        
        # write the final results
        epoch_info = {
            'tr_loss': tr_loss,
            'vl_loss': vl_loss,
            'tr_metrics': make_serializeable_metrics(evaluator.compute()),
            'vl_metrics': make_serializeable_metrics(vl_metrics.compute())
        }
        epochs_info.append(epoch_info)
#         epoch_tqdm.set_description(f"Epoch:{epoch+1}/{EPOCHS} -> tr_loss:{tr_loss}, vl_loss:{vl_loss}")
        evaluator.reset()
    
        scheduler.step(vl_loss)
  
    # save final results
    res = {
        'id': save_file_id,
        'config': config,
        'epochs_info': epochs_info,
        'best_result': best_result
    }
    fn = f"{save_file_id+'_' if save_file_id else ''}result.json"
    fp = os.path.join(config['model']['save_dir'],fn)
    with open(fp, "w") as write_file:
        json.dump(res, write_file, indent=4)

    # save model's state_dict
    fn = "last_model_state_dict.pt"
    fp = os.path.join(config['model']['save_dir'],fn)
    torch.save(model.state_dict(), fp)
    
    # save the best model's state_dict
    fn = "best_model_state_dict.pt"
    fp = os.path.join(config['model']['save_dir'], fn)
    torch.save(best_model.state_dict(), fp)
    
    return best_model, model, res

# %% [markdown]
# ## Define test function

# %%
def test(model, te_dataloader):
    model.eval()
    with torch.no_grad():
        evaluator = test_metrics.clone().to(device)
        for batch_data in tqdm(te_dataloader):
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            imgs = imgs.to(device)
            msks = msks.to(device)
            
            preds = model(imgs)
            
            # we should remove nucs
            not_nucs = torch.where(imgs[:,-1,:,:]>0, 0, 1)
            preds_en = torch.argmax(preds, 1, keepdim=False).float() * not_nucs
            msks_en = torch.argmax(msks, 1, keepdim=False) * not_nucs
            
            # evaluate by metrics
            evaluator.update(preds_en, msks_en.int())
    return evaluator

# %% [markdown]
# ## Load and prepare model

# %%
from models._resunet.res_unet import ResUnet as Net


model = Net(**config['model']['params'])
torch.cuda.empty_cache()
model = model.to(device)
print("Number of parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))

os.makedirs(config['model']['save_dir'], exist_ok=True)
model_path = f"{config['model']['save_dir']}/model_state_dict.pt"

if config['model']['load_weights']:
    model.load_state_dict(torch.load(model_path))
    print("Loaded pre-trained weights...")
    
    
# criterion_dice = DiceLoss()
criterion_dice = DiceLossWithLogtis()
# criterion_ce  = BCELoss()
criterion_ce  = CrossEntropyLoss()


def criterion(preds, masks):
    c_dice = criterion_dice(preds, masks)
    c_ce = criterion_ce(preds, masks)
    return 0.5*c_dice + 0.5*c_ce

tr_prms = config['training']
optimizer = globals()[tr_prms['optimizer']['name']](model.parameters(), **tr_prms['optimizer']['params'])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', **tr_prms['scheduler'])
# Out:
# Number of parameters: 13044226

# %% [markdown]
# ## Start traning

# %%
best_model, model, res = train(
    model, 
    device, 
    tr_dataloader,
    vl_dataloader,
    config,
    
    criterion,
    optimizer,
    scheduler,

    save_dir = config['model']['save_dir'],
    save_file_id = None,
)
# Out:
# Training) ep:000, batch:0083 -> curr_mean-loss:0.01038, mean_batch-loss:0.01805: : 83it [00:47,  1.75it/s]
# Training) ep:001, batch:0083 -> curr_mean-loss:0.00696, mean_batch-loss:0.03906: : 83it [00:46,  1.77it/s]
# Training) ep:002, batch:0083 -> curr_mean-loss:0.00621, mean_batch-loss:0.01634: : 83it [00:44,  1.85it/s]
# Training) ep:003, batch:0083 -> curr_mean-loss:0.00569, mean_batch-loss:0.01168: : 83it [00:46,  1.80it/s]
# Training) ep:004, batch:0083 -> curr_mean-loss:0.00536, mean_batch-loss:0.01721: : 83it [00:45,  1.82it/s]
# Training) ep:005, batch:0083 -> curr_mean-loss:0.00524, mean_batch-loss:0.02691: : 83it [00:45,  1.84it/s]
# Training) ep:006, batch:0083 -> curr_mean-loss:0.00486, mean_batch-loss:0.01407: : 83it [00:46,  1.77it/s]
# Training) ep:007, batch:0083 -> curr_mean-loss:0.00449, mean_batch-loss:0.01508: : 83it [00:43,  1.90it/s]
# Training) ep:008, batch:0083 -> curr_mean-loss:0.00436, mean_batch-loss:0.01502: : 83it [00:46,  1.77it/s]
# Training) ep:009, batch:0083 -> curr_mean-loss:0.00417, mean_batch-loss:0.01574: : 83it [00:43,  1.91it/s]
# Training) ep:010, batch:0083 -> curr_mean-loss:0.00399, mean_batch-loss:0.01112: : 83it [00:46,  1.77it/s]
# Training) ep:011, batch:0083 -> curr_mean-loss:0.00375, mean_batch-loss:0.00909: : 83it [00:43,  1.91it/s]
# Training) ep:012, batch:0083 -> curr_mean-loss:0.00364, mean_batch-loss:0.01329: : 83it [00:46,  1.77it/s]
# Training) ep:013, batch:0083 -> curr_mean-loss:0.00347, mean_batch-loss:0.00884: : 83it [00:43,  1.91it/s]
# Training) ep:014, batch:0083 -> curr_mean-loss:0.00336, mean_batch-loss:0.00707: : 83it [00:46,  1.77it/s]
# Training) ep:015, batch:0083 -> curr_mean-loss:0.00326, mean_batch-loss:0.01328: : 83it [00:43,  1.91it/s]
# Training) ep:016, batch:0083 -> curr_mean-loss:0.00306, mean_batch-loss:0.01035: : 83it [00:46,  1.77it/s]
# Training) ep:017, batch:0083 -> curr_mean-loss:0.00289, mean_batch-loss:0.00894: : 83it [00:43,  1.92it/s]
# Training) ep:018, batch:0083 -> curr_mean-loss:0.00285, mean_batch-loss:0.00871: : 83it [00:46,  1.77it/s]
# Training) ep:019, batch:0083 -> curr_mean-loss:0.00255, mean_batch-loss:0.01104: : 83it [00:43,  1.92it/s]
# Training) ep:020, batch:0083 -> curr_mean-loss:0.00239, mean_batch-loss:0.00513: : 83it [00:46,  1.77it/s]
# Training) ep:021, batch:0083 -> curr_mean-loss:0.00217, mean_batch-loss:0.00736: : 83it [00:45,  1.84it/s]
# Training) ep:022, batch:0083 -> curr_mean-loss:0.00201, mean_batch-loss:0.01174: : 83it [00:46,  1.80it/s]
# Training) ep:023, batch:0083 -> curr_mean-loss:0.00195, mean_batch-loss:0.00475: : 83it [00:45,  1.82it/s]
# Training) ep:024, batch:0083 -> curr_mean-loss:0.00187, mean_batch-loss:0.00835: : 83it [00:45,  1.84it/s]
# Training) ep:025, batch:0083 -> curr_mean-loss:0.00170, mean_batch-loss:0.00582: : 83it [00:46,  1.77it/s]
# Training) ep:026, batch:0083 -> curr_mean-loss:0.00160, mean_batch-loss:0.01010: : 83it [00:43,  1.90it/s]
# Training) ep:027, batch:0083 -> curr_mean-loss:0.00152, mean_batch-loss:0.00481: : 83it [00:46,  1.78it/s]
# Training) ep:028, batch:0083 -> curr_mean-loss:0.00141, mean_batch-loss:0.00430: : 83it [00:43,  1.91it/s]
# Training) ep:029, batch:0083 -> curr_mean-loss:0.00137, mean_batch-loss:0.00563: : 83it [00:46,  1.77it/s]
# Training) ep:030, batch:0083 -> curr_mean-loss:0.00136, mean_batch-loss:0.00697: : 83it [00:43,  1.92it/s]
# Training) ep:031, batch:0083 -> curr_mean-loss:0.00116, mean_batch-loss:0.00358: : 83it [00:46,  1.77it/s]
# Training) ep:032, batch:0083 -> curr_mean-loss:0.00100, mean_batch-loss:0.00479: : 83it [00:43,  1.91it/s]
# Training) ep:033, batch:0083 -> curr_mean-loss:0.00097, mean_batch-loss:0.00638: : 83it [00:46,  1.77it/s]
# Training) ep:034, batch:0083 -> curr_mean-loss:0.00091, mean_batch-loss:0.00450: : 83it [00:43,  1.91it/s]
# Training) ep:035, batch:0083 -> curr_mean-loss:0.00090, mean_batch-loss:0.00464: : 83it [00:46,  1.77it/s]
# Training) ep:036, batch:0083 -> curr_mean-loss:0.00087, mean_batch-loss:0.00366: : 83it [00:43,  1.92it/s]
# Training) ep:037, batch:0083 -> curr_mean-loss:0.00083, mean_batch-loss:0.00333: : 83it [00:46,  1.77it/s]
# Training) ep:038, batch:0083 -> curr_mean-loss:0.00078, mean_batch-loss:0.00360: : 83it [00:43,  1.89it/s]
# Training) ep:039, batch:0083 -> curr_mean-loss:0.00081, mean_batch-loss:0.00471: : 83it [00:46,  1.77it/s]
# Training) ep:040, batch:0083 -> curr_mean-loss:0.00081, mean_batch-loss:0.00335: : 83it [00:45,  1.84it/s]
# Training) ep:041, batch:0083 -> curr_mean-loss:0.00073, mean_batch-loss:0.00320: : 83it [00:45,  1.83it/s]
# Training) ep:042, batch:0083 -> curr_mean-loss:0.00067, mean_batch-loss:0.00384: : 83it [00:46,  1.79it/s]
# Training) ep:043, batch:0083 -> curr_mean-loss:0.00065, mean_batch-loss:0.00235: : 83it [00:45,  1.84it/s]
# Training) ep:044, batch:0083 -> curr_mean-loss:0.00062, mean_batch-loss:0.00268: : 83it [00:46,  1.77it/s]
# Training) ep:045, batch:0083 -> curr_mean-loss:0.00061, mean_batch-loss:0.00372: : 83it [00:43,  1.91it/s]
# Training) ep:046, batch:0083 -> curr_mean-loss:0.00061, mean_batch-loss:0.00254: : 83it [00:46,  1.77it/s]
# Training) ep:047, batch:0083 -> curr_mean-loss:0.00058, mean_batch-loss:0.00205: : 83it [00:43,  1.92it/s]
# Training) ep:048, batch:0083 -> curr_mean-loss:0.00056, mean_batch-loss:0.00205: : 83it [00:46,  1.77it/s]
# Training) ep:049, batch:0083 -> curr_mean-loss:0.00054, mean_batch-loss:0.00270: : 83it [00:43,  1.91it/s]
# Training) ep:050, batch:0083 -> curr_mean-loss:0.00054, mean_batch-loss:0.00220: : 83it [00:46,  1.77it/s]
# Training) ep:051, batch:0083 -> curr_mean-loss:0.00053, mean_batch-loss:0.00246: : 83it [00:43,  1.91it/s]
# Training) ep:052, batch:0083 -> curr_mean-loss:0.00050, mean_batch-loss:0.00198: : 83it [00:46,  1.77it/s]
# Training) ep:053, batch:0083 -> curr_mean-loss:0.00047, mean_batch-loss:0.00198: : 83it [00:43,  1.91it/s]
# Training) ep:054, batch:0083 -> curr_mean-loss:0.00045, mean_batch-loss:0.00240: : 83it [00:46,  1.77it/s]
# Training) ep:055, batch:0083 -> curr_mean-loss:0.00044, mean_batch-loss:0.00213: : 83it [00:43,  1.92it/s]
# Training) ep:056, batch:0083 -> curr_mean-loss:0.00043, mean_batch-loss:0.00190: : 83it [00:46,  1.77it/s]
# Training) ep:057, batch:0083 -> curr_mean-loss:0.00042, mean_batch-loss:0.00174: : 83it [00:43,  1.89it/s]
# Training) ep:058, batch:0083 -> curr_mean-loss:0.00042, mean_batch-loss:0.00195: : 83it [00:46,  1.77it/s]
# Training) ep:059, batch:0083 -> curr_mean-loss:0.00041, mean_batch-loss:0.00165: : 83it [00:45,  1.84it/s]
# Training) ep:060, batch:0083 -> curr_mean-loss:0.00041, mean_batch-loss:0.00200: : 83it [00:45,  1.83it/s]
# Training) ep:061, batch:0083 -> curr_mean-loss:0.00040, mean_batch-loss:0.00170: : 83it [00:46,  1.79it/s]
# Training) ep:062, batch:0083 -> curr_mean-loss:0.00039, mean_batch-loss:0.00175: : 83it [00:45,  1.84it/s]
# Training) ep:063, batch:0083 -> curr_mean-loss:0.00038, mean_batch-loss:0.00187: : 83it [00:46,  1.77it/s]
# Training) ep:064, batch:0083 -> curr_mean-loss:0.00036, mean_batch-loss:0.00151: : 83it [00:43,  1.91it/s]
# Training) ep:065, batch:0083 -> curr_mean-loss:0.00036, mean_batch-loss:0.00133: : 83it [00:46,  1.77it/s]
# Training) ep:066, batch:0083 -> curr_mean-loss:0.00036, mean_batch-loss:0.00381: : 83it [00:43,  1.91it/s]
# Training) ep:067, batch:0083 -> curr_mean-loss:0.00036, mean_batch-loss:0.00197: : 83it [00:46,  1.77it/s]
# Training) ep:068, batch:0083 -> curr_mean-loss:0.00035, mean_batch-loss:0.00151: : 83it [00:43,  1.92it/s]
# Training) ep:069, batch:0083 -> curr_mean-loss:0.00034, mean_batch-loss:0.00158: : 83it [00:46,  1.77it/s]
# Training) ep:070, batch:0083 -> curr_mean-loss:0.00034, mean_batch-loss:0.00152: : 83it [00:43,  1.92it/s]
# Training) ep:071, batch:0083 -> curr_mean-loss:0.00033, mean_batch-loss:0.00151: : 83it [00:46,  1.77it/s]
# Training) ep:072, batch:0083 -> curr_mean-loss:0.00033, mean_batch-loss:0.00143: : 83it [00:40,  2.04it/s]
# Training) ep:073, batch:0083 -> curr_mean-loss:0.00033, mean_batch-loss:0.00192: : 83it [00:46,  1.80it/s]
# Training) ep:074, batch:0083 -> curr_mean-loss:0.00033, mean_batch-loss:0.00154: : 83it [00:41,  2.02it/s]
# Training) ep:075, batch:0083 -> curr_mean-loss:0.00032, mean_batch-loss:0.00428: : 83it [00:46,  1.78it/s]
# Training) ep:076, batch:0083 -> curr_mean-loss:0.00032, mean_batch-loss:0.00133: : 83it [00:43,  1.92it/s]
# Training) ep:077, batch:0083 -> curr_mean-loss:0.00031, mean_batch-loss:0.00140: : 83it [00:46,  1.77it/s]
# Training) ep:078, batch:0083 -> curr_mean-loss:0.00031, mean_batch-loss:0.00184: : 83it [00:43,  1.92it/s]
# Training) ep:079, batch:0083 -> curr_mean-loss:0.00030, mean_batch-loss:0.00149: : 83it [00:46,  1.77it/s]
# Training) ep:080, batch:0083 -> curr_mean-loss:0.00031, mean_batch-loss:0.00177: : 83it [00:43,  1.91it/s]
# Training) ep:081, batch:0083 -> curr_mean-loss:0.00030, mean_batch-loss:0.00120: : 83it [00:46,  1.77it/s]
# Training) ep:082, batch:0083 -> curr_mean-loss:0.00029, mean_batch-loss:0.00125: : 83it [00:44,  1.85it/s]
# Training) ep:083, batch:0083 -> curr_mean-loss:0.00030, mean_batch-loss:0.00183: : 83it [00:45,  1.81it/s]
# Training) ep:084, batch:0083 -> curr_mean-loss:0.00029, mean_batch-loss:0.00131: : 83it [00:45,  1.82it/s]
# Training) ep:085, batch:0083 -> curr_mean-loss:0.00029, mean_batch-loss:0.00210: : 83it [00:45,  1.84it/s]
# Training) ep:086, batch:0083 -> curr_mean-loss:0.00030, mean_batch-loss:0.00212: : 83it [00:46,  1.77it/s]
# Training) ep:087, batch:0083 -> curr_mean-loss:0.00029, mean_batch-loss:0.00151: : 83it [00:43,  1.91it/s]
# Training) ep:088, batch:0083 -> curr_mean-loss:0.00028, mean_batch-loss:0.00130: : 83it [00:46,  1.77it/s]
# Training) ep:089, batch:0083 -> curr_mean-loss:0.00029, mean_batch-loss:0.00139: : 83it [00:43,  1.92it/s]
# Training) ep:090, batch:0083 -> curr_mean-loss:0.00029, mean_batch-loss:0.00135: : 83it [00:46,  1.77it/s]
# Training) ep:091, batch:0083 -> curr_mean-loss:0.00028, mean_batch-loss:0.00153: : 83it [00:43,  1.92it/s]
# Training) ep:092, batch:0083 -> curr_mean-loss:0.00028, mean_batch-loss:0.00109: : 83it [00:46,  1.77it/s]
# Training) ep:093, batch:0083 -> curr_mean-loss:0.00028, mean_batch-loss:0.00155: : 83it [00:42,  1.93it/s]
# Training) ep:094, batch:0083 -> curr_mean-loss:0.00028, mean_batch-loss:0.00143: : 83it [00:46,  1.77it/s]
# Training) ep:095, batch:0083 -> curr_mean-loss:0.00028, mean_batch-loss:0.00197: : 83it [00:43,  1.92it/s]
# Training) ep:096, batch:0083 -> curr_mean-loss:0.00028, mean_batch-loss:0.00088: : 83it [00:46,  1.77it/s]
# Training) ep:097, batch:0083 -> curr_mean-loss:0.00027, mean_batch-loss:0.00124: : 83it [00:43,  1.92it/s]
# Training) ep:098, batch:0083 -> curr_mean-loss:0.00027, mean_batch-loss:0.00173: : 83it [00:46,  1.77it/s]
# Training) ep:099, batch:0083 -> curr_mean-loss:0.00027, mean_batch-loss:0.00116: : 83it [00:43,  1.91it/s]

# %%
te_metrics = test(best_model, te_dataloader)
te_metrics.compute()
# Out:
# 100%|██████████| 50/50 [00:04<00:00, 10.40it/s]
# {'test_metrics/F1Score': tensor(0.8479, device='cuda:0'),
#  'test_metrics/Accuracy': tensor(0.9743, device='cuda:0'),
#  'test_metrics/Dice': tensor(0.8479, device='cuda:0'),
#  'test_metrics/Precision': tensor(0.8920, device='cuda:0'),
#  'test_metrics/Recall': tensor(0.8080, device='cuda:0'),
#  'test_metrics/Specificity': tensor(0.9905, device='cuda:0'),
#  'test_metrics/JaccardIndex': tensor(0.8541, device='cuda:0')}

# %%
f"{config['model']['save_dir']}"
# Out:
# '../saved_models/segpc2021_resunet'

# %% [markdown]
# # Test the best inferred model
# ----

# %% [markdown]
# ## Load the best model

# %%
best_model = Net(**config['model']['params'])
torch.cuda.empty_cache()
best_model = best_model.to(device)

fn = "best_model_state_dict.pt"
os.makedirs(config['model']['save_dir'], exist_ok=True)
model_path = f"{config['model']['save_dir']}/{fn}"

best_model.load_state_dict(torch.load(model_path))
print("Loaded best model weights...")
# Out:
# Loaded best model weights...

# %% [markdown]
# ## Evaluation

# %%
te_metrics = test(best_model, te_dataloader)
te_metrics.compute()
# Out:
# 100%|██████████| 50/50 [00:10<00:00,  4.94it/s]
# {'test_metrics/F1Score': tensor(0.8479, device='cuda:0'),
#  'test_metrics/Accuracy': tensor(0.9743, device='cuda:0'),
#  'test_metrics/Dice': tensor(0.8479, device='cuda:0'),
#  'test_metrics/Precision': tensor(0.8920, device='cuda:0'),
#  'test_metrics/Recall': tensor(0.8080, device='cuda:0'),
#  'test_metrics/Specificity': tensor(0.9905, device='cuda:0'),
#  'test_metrics/JaccardIndex': tensor(0.8541, device='cuda:0')}

# %% [markdown]
# ## Plot graphs

# %%
result_file_path = f"{config['model']['save_dir']}/result.json"
with open(result_file_path, 'r') as f:
    results = json.loads(''.join(f.readlines()))
epochs_info = results['epochs_info']

tr_losses = [d['tr_loss'] for d in epochs_info]
vl_losses = [d['vl_loss'] for d in epochs_info]
tr_dice = [d['tr_metrics']['train_metrics/Dice'] for d in epochs_info]
vl_dice = [d['vl_metrics']['valid_metrics/Dice'] for d in epochs_info]
tr_js = [d['tr_metrics']['train_metrics/JaccardIndex'] for d in epochs_info]
vl_js = [d['vl_metrics']['valid_metrics/JaccardIndex'] for d in epochs_info]
tr_acc = [d['tr_metrics']['train_metrics/Accuracy'] for d in epochs_info]
vl_acc = [d['vl_metrics']['valid_metrics/Accuracy'] for d in epochs_info]


_, axs = plt.subplots(1, 4, figsize=[16,3])

axs[0].set_title("Loss")
axs[0].plot(tr_losses, 'r-', label="train loss")
axs[0].plot(vl_losses, 'b-', label="validatiton loss")
axs[0].legend()

axs[1].set_title("Dice score")
axs[1].plot(tr_dice, 'r-', label="train dice")
axs[1].plot(vl_dice, 'b-', label="validation dice")
axs[1].legend()

axs[2].set_title("Jaccard Similarity")
axs[2].plot(tr_js, 'r-', label="train JaccardIndex")
axs[2].plot(vl_js, 'b-', label="validatiton JaccardIndex")
axs[2].legend()

axs[3].set_title("Accuracy")
axs[3].plot(tr_acc, 'r-', label="train Accuracy")
axs[3].plot(vl_acc, 'b-', label="validation Accuracy")
axs[3].legend()

plt.show()

# %%
epochs_info

# %% [markdown]
# ## Save images

# %%
from PIL import Image


save_imgs_dir = f"{config['model']['save_dir']}/visualized"

if not os.path.isdir(save_imgs_dir):
    os.mkdir(save_imgs_dir)

with torch.no_grad():
    for batch in tqdm(te_dataloader):
        imgs = batch['image']
        msks = batch['mask']
        ids = batch['id']
        
        preds = best_model(imgs.to(device))
        
        txm = imgs.cpu().numpy()
        tbm = torch.argmax(msks, 1).cpu().numpy()
        tpm = torch.argmax(preds, 1).cpu().numpy()
        tid = ids.cpu().numpy()
        
        for idx in range(len(tbm)):
            img = np.moveaxis(txm[idx, :3], 0, -1)*255.
            nuc = np.uint8(txm[idx, -1]*255.)
            gt = np.uint8(tbm[idx]*255.)
            gt_3ch = np.stack([gt-nuc, nuc*0, nuc], -1)
            pred = np.where(tpm[idx]>0.5, 255, 0)
            pred_3ch = np.stack([pred-nuc, nuc*0, nuc], -1)
            
            img = np.ascontiguousarray(img, dtype=np.uint8)
            gt_3ch = np.ascontiguousarray(gt_3ch, dtype=np.uint8)
            pred_3ch = np.ascontiguousarray(pred_3ch, dtype=np.uint8)
            
            fid = tid[idx]
            Image.fromarray(img).save(f"{save_imgs_dir}/{fid}_img.png")
            Image.fromarray(gt_3ch).save(f"{save_imgs_dir}/{fid}_gt.png")
            Image.fromarray(pred_3ch).save(f"{save_imgs_dir}/{fid}_pred.png")
# Out:
# 100%|██████████| 50/50 [00:12<00:00,  4.08it/s]

# %%
f"{config['model']['save_dir']}/visualized"
# Out:
# '../saved_models/segpc2021_resunet/visualized'
