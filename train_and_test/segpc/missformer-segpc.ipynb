# %% [markdown]
# # MISSFormer - SegPC2021
# ---

# %% [markdown]
# ## Import packages & functions

# %%
from __future__ import print_function, division


import os
import sys
sys.path.append('../..')
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import copy
import json
import importlib
import glob
import pandas as pd
from skimage import io, transform
import matplotlib.pyplot as plt
from matplotlib.image import imread
import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchmetrics
from torch.optim import Adam, SGD
from losses import DiceLoss, DiceLossWithLogtis
from torch.nn import BCELoss, CrossEntropyLoss

from utils import (
    show_sbs,
    load_config,
    _print,
)

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# plt.ion()   # interactive mode

# %% [markdown]
# ## Set the seed

# %%
torch.manual_seed(0)
np.random.seed(0)
torch.cuda.manual_seed(0)
import random
random.seed(0)

# %% [markdown]
# ## Load the config

# %%
CONFIG_NAME = "segpc/segpc2021_missformer.yaml"
CONFIG_FILE_PATH = os.path.join("./configs", CONFIG_NAME)

# %%
config = load_config(CONFIG_FILE_PATH)
_print("Config:", "info_underline")
print(json.dumps(config, indent=2))
print(20*"~-", "\n")
# Out:
# Config:
# {
#   "run": {
#     "mode": "train",
#     "device": "gpu"
#   },
#   "transforms": "none",
#   "dataset": {
#     "class_name": "SegPC2021Dataset",
#     "input_size": 224,
#     "scale": 2.5,
#     "data_dir": "/path/to/datasets/segpc/np",
#     "dataset_dir": "/path/to/datasets/segpc/TCIA_SegPC_dataset",
#     "number_classes": 2
#   },
#   "data_loader": {
#     "train": {
#       "batch_size": 16,
#       "shuffle": true,
#       "num_workers": 4,
#       "pin_memory": true
#     },
#     "validation": {
#       "batch_size": 16,
#       "shuffle": false,
#       "num_workers": 4,
#       "pin_memory": true
#     },
#     "test": {
#       "batch_size": 16,
#       "shuffle": false,
#       "num_workers": 4,
#       "pin_memory": false
#     }
#   },
#   "training": {
#     "optimizer": {
#       "name": "SGD",
#       "params": {
#         "lr": 0.0001,
#         "momentum": 0.9,
#         "weight_decay": 0.0001
#       }
#     },
#     "criterion": {
#       "name": "DiceLoss",
#       "params": {}
#     },
#     "scheduler": {
#       "factor": 0.5,
#       "patience": 10
#     },
#     "epochs": 500
#   },
#   "model": {
#     "save_dir": "../saved_models/segpc2021_missformer",
#     "load_weights": false,
#     "name": "MISSFormer",
#     "params": {
#       "in_ch": 4,
#       "num_classes": 2
#     }
#   }
# }
# ~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-

# %% [markdown]
# ## Dataset and Dataloader

# %%
from datasets.segpc import SegPC2021Dataset
from torch.utils.data import DataLoader, Subset
from torchvision import transforms

# %%
# ----------------- transform ------------------
# transform for image
img_transform = transforms.Compose([
    transforms.ToTensor()
])
# transform for mask
msk_transform = transforms.Compose([
    transforms.ToTensor()
])
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<


# ----------------- dataset --------------------
# preparing training dataset
tr_dataset = SegPC2021Dataset(
    mode="tr",
    input_size=config['dataset']['input_size'],
    scale=config['dataset']['scale'],
    data_dir=config['dataset']['data_dir'], 
    dataset_dir=config['dataset']['dataset_dir'],
    one_hot=True,
    force_rebuild=False,
    img_transform=img_transform,
    msk_transform=msk_transform
)
# preparing training dataset
vl_dataset = SegPC2021Dataset(
    mode="vl",
    input_size=config['dataset']['input_size'],
    scale=config['dataset']['scale'],
    data_dir=config['dataset']['data_dir'], 
    dataset_dir=config['dataset']['dataset_dir'],
    one_hot=True,
    force_rebuild=False,
    img_transform=img_transform,
    msk_transform=msk_transform
)
# preparing training dataset
te_dataset = SegPC2021Dataset(
    mode="te",
    input_size=config['dataset']['input_size'],
    scale=config['dataset']['scale'],
    data_dir=config['dataset']['data_dir'], 
    dataset_dir=config['dataset']['dataset_dir'],
    one_hot=True,
    force_rebuild=False,
    img_transform=img_transform,
    msk_transform=msk_transform
)


def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(0)

# prepare train dataloader
tr_dataloader = DataLoader(tr_dataset, worker_init_fn=seed_worker, generator=g, **config['data_loader']['train'])

# prepare validation dataloader
vl_dataloader = DataLoader(vl_dataset, worker_init_fn=seed_worker, generator=g, **config['data_loader']['validation'])

# prepare test dataloader
te_dataloader = DataLoader(te_dataset, worker_init_fn=seed_worker, generator=g, **config['data_loader']['test'])



print(f"Length of trainig_dataset:\t{len(tr_dataset)}")
print(f"Length of validation_dataset:\t{len(vl_dataset)}")
print(f"Length of test_dataset:\t\t{len(te_dataset)}")

# -------------- test -----------------
# test and visualize the input data
for batch in tr_dataloader:
    img = batch['image']
    msk = batch['mask']
    print("Training")
    show_sbs(img[0,:-1,:,:], msk[0,1])
    break
    
for batch in vl_dataloader:
    img = batch['image']
    msk = batch['mask']
    print("Validation")
    show_sbs(img[0,:-1,:,:], msk[0,1])
    break
    
for batch in te_dataloader:
    img = batch['image']
    msk = batch['mask']
    print("Test")
    show_sbs(img[0,:-1,:,:], msk[0,1])
    break
# Out:
# loading X_tr...
# loading Y_tr...
# finished.
# loading X_vl...
# loading Y_vl...
# finished.
# loading X_te...
# loading Y_te...
# finished.
# Length of trainig_dataset:	1316
# Length of validation_dataset:	527
# Length of test_dataset:		790
# Training
# Validation
# Test

# %% [markdown]
# ### Device

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Torch device: {device}")
# Out:
# Torch device: cuda

# %% [markdown]
# ## Metrics

# %%
metrics = torchmetrics.MetricCollection(
    [
        torchmetrics.F1Score(),
        torchmetrics.Accuracy(),
        torchmetrics.Dice(),
        torchmetrics.Precision(),
        torchmetrics.Specificity(),
        torchmetrics.Recall(),
        # IoU
        torchmetrics.JaccardIndex(2)
    ],
    prefix='train_metrics/'
)

# train_metrics
train_metrics = metrics.clone(prefix='train_metrics/').to(device)

# valid_metrics
valid_metrics = metrics.clone(prefix='valid_metrics/').to(device)

# test_metrics
test_metrics = metrics.clone(prefix='test_metrics/').to(device)

# %%
def make_serializeable_metrics(computed_metrics):
    res = {}
    for k, v in computed_metrics.items():
        res[k] = float(v.cpu().detach().numpy())
    return res

# %% [markdown]
# ## Define validate function

# %%
def validate(model, criterion, vl_dataloader):
    model.eval()
    with torch.no_grad():
        
        evaluator = valid_metrics.clone().to(device)
        
        losses = []
        cnt = 0.
        for batch, batch_data in enumerate(vl_dataloader):
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            cnt += msks.shape[0]
            
            imgs = imgs.to(device)
            msks = msks.to(device)
            
            preds = model(imgs)
            loss = criterion(preds, msks)
            losses.append(loss.item())
            
            # we should remove nucs
            not_nucs = torch.where(imgs[:,-1,:,:]>0, 0, 1)
            preds_en = torch.argmax(preds, 1, keepdim=False).float() * not_nucs
            msks_en = torch.argmax(msks, 1, keepdim=False) * not_nucs
            
            # evaluate by metrics
            evaluator.update(preds_en, msks_en.int())
        
#             _cml = f"curr_mean-loss:{np.sum(losses)/cnt:0.5f}"
#             _bl = f"batch-loss:{losses[-1]/msks.shape[0]:0.5f}"
#             iterator.set_description(f"Validation) batch:{batch+1:04d} -> {_cml}, {_bl}")
        
        # print the final results
        loss = np.sum(losses)/cnt
        metrics = evaluator.compute()
    
    return evaluator, loss

# %% [markdown]
# ## Define train function

# %%
def train(
    model, 
    device, 
    tr_dataloader,
    vl_dataloader,
    config,
    
    criterion,
    optimizer,
    scheduler,
    
    save_dir='./',
    save_file_id=None,
):
    tr_prms = config['training']
    EPOCHS = tr_prms['epochs']
    
    torch.cuda.empty_cache()
    model = model.to(device)
    
    evaluator = train_metrics.clone().to(device)

    epochs_info = []
    best_model = None
    best_result = {}
    best_vl_loss = np.Inf
    for epoch in range(EPOCHS):
        model.train()
        
        evaluator.reset()
        tr_iterator = tqdm(enumerate(tr_dataloader))
        tr_losses = []
        cnt = 0
        for batch, batch_data in tr_iterator:
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            imgs = imgs.to(device)
            msks = msks.to(device)

            optimizer.zero_grad()
            preds = model(imgs)
            loss = criterion(preds, msks)
            loss.backward()
            optimizer.step()
            
            # we should remove nucs
            not_nucs = torch.where(imgs[:,-1,:,:]>0, 0, 1)
            preds_en = torch.argmax(preds, 1, keepdim=False).float() * not_nucs
            msks_en = torch.argmax(msks, 1, keepdim=False) * not_nucs
            
            # evaluate by metrics
            evaluator.update(preds_en, msks_en.int())
            
            cnt += imgs.shape[0]
            tr_losses.append(loss.item())
            
            # write details for each training batch
            _cml = f"curr_mean-loss:{np.sum(tr_losses)/cnt:0.5f}"
            _bl = f"mean_batch-loss:{tr_losses[-1]/imgs.shape[0]:0.5f}"
            tr_iterator.set_description(f"Training) ep:{epoch:03d}, batch:{batch+1:04d} -> {_cml}, {_bl}")
        
        tr_loss = np.sum(tr_losses)/cnt
        
        # validate model
        vl_metrics, vl_loss = validate(model, criterion, vl_dataloader)
        if vl_loss < best_vl_loss:
            # find a better model
            best_model = model
            best_vl_loss = vl_loss
            best_result = {
                'tr_loss': tr_loss,
                'vl_loss': vl_loss,
                'tr_metrics': make_serializeable_metrics(evaluator.compute()),
                'vl_metrics': make_serializeable_metrics(vl_metrics.compute())
            }
        
        # write the final results
        epoch_info = {
            'tr_loss': tr_loss,
            'vl_loss': vl_loss,
            'tr_metrics': make_serializeable_metrics(evaluator.compute()),
            'vl_metrics': make_serializeable_metrics(vl_metrics.compute())
        }
        epochs_info.append(epoch_info)
#         epoch_tqdm.set_description(f"Epoch:{epoch+1}/{EPOCHS} -> tr_loss:{tr_loss}, vl_loss:{vl_loss}")
        evaluator.reset()
    
        scheduler.step(vl_loss)
  
    # save final results
    res = {
        'id': save_file_id,
        'config': config,
        'epochs_info': epochs_info,
        'best_result': best_result
    }
    fn = f"{save_file_id+'_' if save_file_id else ''}result.json"
    fp = os.path.join(config['model']['save_dir'],fn)
    with open(fp, "w") as write_file:
        json.dump(res, write_file, indent=4)

    # save model's state_dict
    fn = "last_model_state_dict.pt"
    fp = os.path.join(config['model']['save_dir'],fn)
    torch.save(model.state_dict(), fp)
    
    # save the best model's state_dict
    fn = "best_model_state_dict.pt"
    fp = os.path.join(config['model']['save_dir'], fn)
    torch.save(best_model.state_dict(), fp)
    
    return best_model, model, res

# %% [markdown]
# ## Define test function

# %%
def test(model, te_dataloader):
    model.eval()
    with torch.no_grad():
        evaluator = test_metrics.clone().to(device)
        for batch_data in tqdm(te_dataloader):
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            imgs = imgs.to(device)
            msks = msks.to(device)
            
            preds = model(imgs)
            
            # we should remove nucs
            not_nucs = torch.where(imgs[:,-1,:,:]>0, 0, 1)
            preds_en = torch.argmax(preds, 1, keepdim=False).float() * not_nucs
            msks_en = torch.argmax(msks, 1, keepdim=False) * not_nucs
            
            # evaluate by metrics
            evaluator.update(preds_en, msks_en.int())
    return evaluator

# %% [markdown]
# ## Load and prepare model

# %%
from models._missformer.MISSFormer import MISSFormer as Net


model = Net(**config['model']['params'])
torch.cuda.empty_cache()
model = model.to(device)
print("Number of parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))

os.makedirs(config['model']['save_dir'], exist_ok=True)
model_path = f"{config['model']['save_dir']}/model_state_dict.pt"

if config['model']['load_weights']:
    model.load_state_dict(torch.load(model_path))
    print("Loaded pre-trained weights...")
    
    
# criterion_dice = DiceLoss()
criterion_dice = DiceLossWithLogtis()
# criterion_ce  = BCELoss()
criterion_ce  = CrossEntropyLoss()


def criterion(preds, masks):
    c_dice = criterion_dice(preds, masks)
    c_ce = criterion_ce(preds, masks)
    return 0.5*c_dice + 0.5*c_ce

tr_prms = config['training']
optimizer = globals()[tr_prms['optimizer']['name']](model.parameters(), **tr_prms['optimizer']['params'])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', **tr_prms['scheduler'])
# Out:
# Number of parameters: 42465218

# %% [markdown]
# ## Start traning

# %%
best_model, model, res = train(
    model, 
    device, 
    tr_dataloader,
    vl_dataloader,
    config,
    
    criterion,
    optimizer,
    scheduler,

    save_dir = config['model']['save_dir'],
    save_file_id = None,
)
# Out:
# Training) ep:000, batch:0083 -> curr_mean-loss:0.03184, mean_batch-loss:0.10971: : 83it [00:23,  3.52it/s]
# Training) ep:001, batch:0083 -> curr_mean-loss:0.02827, mean_batch-loss:0.11196: : 83it [00:21,  3.88it/s]
# Training) ep:002, batch:0083 -> curr_mean-loss:0.02662, mean_batch-loss:0.10371: : 83it [00:21,  3.86it/s]
# Training) ep:003, batch:0083 -> curr_mean-loss:0.02442, mean_batch-loss:0.09494: : 83it [00:21,  3.85it/s]
# Training) ep:004, batch:0083 -> curr_mean-loss:0.02227, mean_batch-loss:0.08501: : 83it [00:21,  3.83it/s]
# Training) ep:005, batch:0083 -> curr_mean-loss:0.02076, mean_batch-loss:0.09028: : 83it [00:21,  3.85it/s]
# Training) ep:006, batch:0083 -> curr_mean-loss:0.01974, mean_batch-loss:0.07702: : 83it [00:21,  3.86it/s]
# Training) ep:007, batch:0083 -> curr_mean-loss:0.01904, mean_batch-loss:0.06246: : 83it [00:21,  3.86it/s]
# Training) ep:008, batch:0083 -> curr_mean-loss:0.01862, mean_batch-loss:0.08136: : 83it [00:21,  3.85it/s]
# Training) ep:009, batch:0083 -> curr_mean-loss:0.01827, mean_batch-loss:0.07657: : 83it [00:21,  3.85it/s]
# Training) ep:010, batch:0083 -> curr_mean-loss:0.01799, mean_batch-loss:0.06929: : 83it [00:21,  3.85it/s]
# Training) ep:011, batch:0083 -> curr_mean-loss:0.01774, mean_batch-loss:0.06375: : 83it [00:21,  3.85it/s]
# Training) ep:012, batch:0083 -> curr_mean-loss:0.01753, mean_batch-loss:0.06518: : 83it [00:21,  3.85it/s]
# Training) ep:013, batch:0083 -> curr_mean-loss:0.01734, mean_batch-loss:0.06728: : 83it [00:21,  3.85it/s]
# Training) ep:014, batch:0083 -> curr_mean-loss:0.01713, mean_batch-loss:0.06205: : 83it [00:21,  3.85it/s]
# Training) ep:015, batch:0083 -> curr_mean-loss:0.01696, mean_batch-loss:0.08095: : 83it [00:21,  3.85it/s]
# Training) ep:016, batch:0083 -> curr_mean-loss:0.01671, mean_batch-loss:0.06398: : 83it [00:21,  3.84it/s]
# Training) ep:017, batch:0083 -> curr_mean-loss:0.01643, mean_batch-loss:0.05922: : 83it [00:21,  3.86it/s]
# Training) ep:018, batch:0083 -> curr_mean-loss:0.01616, mean_batch-loss:0.06513: : 83it [00:21,  3.85it/s]
# Training) ep:019, batch:0083 -> curr_mean-loss:0.01583, mean_batch-loss:0.06318: : 83it [00:21,  3.85it/s]
# Training) ep:020, batch:0083 -> curr_mean-loss:0.01533, mean_batch-loss:0.05679: : 83it [00:21,  3.86it/s]
# Training) ep:021, batch:0083 -> curr_mean-loss:0.01474, mean_batch-loss:0.04255: : 83it [00:21,  3.85it/s]
# Training) ep:022, batch:0083 -> curr_mean-loss:0.01416, mean_batch-loss:0.06227: : 83it [00:21,  3.85it/s]
# Training) ep:023, batch:0083 -> curr_mean-loss:0.01347, mean_batch-loss:0.04144: : 83it [00:21,  3.85it/s]
# Training) ep:024, batch:0083 -> curr_mean-loss:0.01290, mean_batch-loss:0.03473: : 83it [00:21,  3.84it/s]
# Training) ep:025, batch:0083 -> curr_mean-loss:0.01251, mean_batch-loss:0.05559: : 83it [00:21,  3.85it/s]
# Training) ep:026, batch:0083 -> curr_mean-loss:0.01203, mean_batch-loss:0.04585: : 83it [00:21,  3.84it/s]
# Training) ep:027, batch:0083 -> curr_mean-loss:0.01171, mean_batch-loss:0.03782: : 83it [00:21,  3.86it/s]
# Training) ep:028, batch:0083 -> curr_mean-loss:0.01148, mean_batch-loss:0.04220: : 83it [00:21,  3.85it/s]
# Training) ep:029, batch:0083 -> curr_mean-loss:0.01117, mean_batch-loss:0.03257: : 83it [00:21,  3.85it/s]
# Training) ep:030, batch:0083 -> curr_mean-loss:0.01100, mean_batch-loss:0.03972: : 83it [00:21,  3.85it/s]
# Training) ep:031, batch:0083 -> curr_mean-loss:0.01095, mean_batch-loss:0.04585: : 83it [00:21,  3.85it/s]
# Training) ep:032, batch:0083 -> curr_mean-loss:0.01071, mean_batch-loss:0.03376: : 83it [00:21,  3.85it/s]
# Training) ep:033, batch:0083 -> curr_mean-loss:0.01068, mean_batch-loss:0.04925: : 83it [00:21,  3.85it/s]
# Training) ep:034, batch:0083 -> curr_mean-loss:0.01051, mean_batch-loss:0.04308: : 83it [00:21,  3.85it/s]
# Training) ep:035, batch:0083 -> curr_mean-loss:0.01035, mean_batch-loss:0.03891: : 83it [00:21,  3.84it/s]
# Training) ep:036, batch:0083 -> curr_mean-loss:0.01038, mean_batch-loss:0.02973: : 83it [00:21,  3.84it/s]
# Training) ep:037, batch:0083 -> curr_mean-loss:0.01029, mean_batch-loss:0.04920: : 83it [00:21,  3.85it/s]
# Training) ep:038, batch:0083 -> curr_mean-loss:0.01008, mean_batch-loss:0.03997: : 83it [00:21,  3.84it/s]
# Training) ep:039, batch:0083 -> curr_mean-loss:0.00997, mean_batch-loss:0.04434: : 83it [00:21,  3.85it/s]
# Training) ep:040, batch:0083 -> curr_mean-loss:0.00986, mean_batch-loss:0.03297: : 83it [00:21,  3.85it/s]
# Training) ep:041, batch:0083 -> curr_mean-loss:0.00974, mean_batch-loss:0.03390: : 83it [00:21,  3.85it/s]
# Training) ep:042, batch:0083 -> curr_mean-loss:0.00966, mean_batch-loss:0.03714: : 83it [00:21,  3.85it/s]
# Training) ep:043, batch:0083 -> curr_mean-loss:0.00969, mean_batch-loss:0.03360: : 83it [00:21,  3.85it/s]
# Training) ep:044, batch:0083 -> curr_mean-loss:0.00949, mean_batch-loss:0.04139: : 83it [00:21,  3.85it/s]
# Training) ep:045, batch:0083 -> curr_mean-loss:0.00938, mean_batch-loss:0.03166: : 83it [00:21,  3.84it/s]
# Training) ep:046, batch:0083 -> curr_mean-loss:0.00932, mean_batch-loss:0.03031: : 83it [00:21,  3.86it/s]
# Training) ep:047, batch:0083 -> curr_mean-loss:0.00920, mean_batch-loss:0.04155: : 83it [00:21,  3.84it/s]
# Training) ep:048, batch:0083 -> curr_mean-loss:0.00911, mean_batch-loss:0.02198: : 83it [00:21,  3.85it/s]
# Training) ep:049, batch:0083 -> curr_mean-loss:0.00905, mean_batch-loss:0.03960: : 83it [00:21,  3.85it/s]
# Training) ep:050, batch:0083 -> curr_mean-loss:0.00895, mean_batch-loss:0.03672: : 83it [00:21,  3.85it/s]
# Training) ep:051, batch:0083 -> curr_mean-loss:0.00899, mean_batch-loss:0.04702: : 83it [00:21,  3.85it/s]
# Training) ep:052, batch:0083 -> curr_mean-loss:0.00882, mean_batch-loss:0.04330: : 83it [00:21,  3.85it/s]
# Training) ep:053, batch:0083 -> curr_mean-loss:0.00872, mean_batch-loss:0.03336: : 83it [00:21,  3.85it/s]
# Training) ep:054, batch:0083 -> curr_mean-loss:0.00869, mean_batch-loss:0.05321: : 83it [00:21,  3.85it/s]
# Training) ep:055, batch:0083 -> curr_mean-loss:0.00860, mean_batch-loss:0.03839: : 83it [00:21,  3.84it/s]
# Training) ep:056, batch:0083 -> curr_mean-loss:0.00856, mean_batch-loss:0.02677: : 83it [00:21,  3.85it/s]
# Training) ep:057, batch:0083 -> curr_mean-loss:0.00847, mean_batch-loss:0.03120: : 83it [00:21,  3.85it/s]
# Training) ep:058, batch:0083 -> curr_mean-loss:0.00840, mean_batch-loss:0.02392: : 83it [00:21,  3.85it/s]
# Training) ep:059, batch:0083 -> curr_mean-loss:0.00839, mean_batch-loss:0.03703: : 83it [00:21,  3.85it/s]
# Training) ep:060, batch:0083 -> curr_mean-loss:0.00827, mean_batch-loss:0.02639: : 83it [00:21,  3.83it/s]
# Training) ep:061, batch:0083 -> curr_mean-loss:0.00825, mean_batch-loss:0.03168: : 83it [00:21,  3.85it/s]
# Training) ep:062, batch:0083 -> curr_mean-loss:0.00826, mean_batch-loss:0.04193: : 83it [00:21,  3.85it/s]
# Training) ep:063, batch:0083 -> curr_mean-loss:0.00816, mean_batch-loss:0.03113: : 83it [00:21,  3.85it/s]
# Training) ep:064, batch:0083 -> curr_mean-loss:0.00808, mean_batch-loss:0.02256: : 83it [00:21,  3.85it/s]
# Training) ep:065, batch:0083 -> curr_mean-loss:0.00808, mean_batch-loss:0.03725: : 83it [00:21,  3.85it/s]
# Training) ep:066, batch:0083 -> curr_mean-loss:0.00806, mean_batch-loss:0.03629: : 83it [00:21,  3.84it/s]
# Training) ep:067, batch:0083 -> curr_mean-loss:0.00806, mean_batch-loss:0.03598: : 83it [00:21,  3.84it/s]
# Training) ep:068, batch:0083 -> curr_mean-loss:0.00794, mean_batch-loss:0.03068: : 83it [00:21,  3.84it/s]
# Training) ep:069, batch:0083 -> curr_mean-loss:0.00799, mean_batch-loss:0.02464: : 83it [00:21,  3.85it/s]
# Training) ep:070, batch:0083 -> curr_mean-loss:0.00797, mean_batch-loss:0.04432: : 83it [00:21,  3.84it/s]
# Training) ep:071, batch:0083 -> curr_mean-loss:0.00785, mean_batch-loss:0.03087: : 83it [00:21,  3.85it/s]
# Training) ep:072, batch:0083 -> curr_mean-loss:0.00778, mean_batch-loss:0.02163: : 83it [00:21,  3.84it/s]
# Training) ep:073, batch:0083 -> curr_mean-loss:0.00777, mean_batch-loss:0.03489: : 83it [00:21,  3.85it/s]
# Training) ep:074, batch:0083 -> curr_mean-loss:0.00772, mean_batch-loss:0.02558: : 83it [00:21,  3.84it/s]
# Training) ep:075, batch:0083 -> curr_mean-loss:0.00773, mean_batch-loss:0.02888: : 83it [00:21,  3.85it/s]
# Training) ep:076, batch:0083 -> curr_mean-loss:0.00773, mean_batch-loss:0.02786: : 83it [00:21,  3.85it/s]
# Training) ep:077, batch:0083 -> curr_mean-loss:0.00766, mean_batch-loss:0.02477: : 83it [00:21,  3.84it/s]
# Training) ep:078, batch:0083 -> curr_mean-loss:0.00765, mean_batch-loss:0.03532: : 83it [00:21,  3.84it/s]
# Training) ep:079, batch:0083 -> curr_mean-loss:0.00760, mean_batch-loss:0.02714: : 83it [00:21,  3.84it/s]
# Training) ep:080, batch:0083 -> curr_mean-loss:0.00761, mean_batch-loss:0.03280: : 83it [00:21,  3.84it/s]
# Training) ep:081, batch:0083 -> curr_mean-loss:0.00754, mean_batch-loss:0.03084: : 83it [00:21,  3.84it/s]
# Training) ep:082, batch:0083 -> curr_mean-loss:0.00751, mean_batch-loss:0.02586: : 83it [00:21,  3.85it/s]
# Training) ep:083, batch:0083 -> curr_mean-loss:0.00751, mean_batch-loss:0.02929: : 83it [00:21,  3.85it/s]
# Training) ep:084, batch:0083 -> curr_mean-loss:0.00746, mean_batch-loss:0.03331: : 83it [00:21,  3.85it/s]
# Training) ep:085, batch:0083 -> curr_mean-loss:0.00740, mean_batch-loss:0.01887: : 83it [00:21,  3.85it/s]
# Training) ep:086, batch:0083 -> curr_mean-loss:0.00746, mean_batch-loss:0.02947: : 83it [00:21,  3.84it/s]
# Training) ep:087, batch:0083 -> curr_mean-loss:0.00742, mean_batch-loss:0.02286: : 83it [00:21,  3.84it/s]
# Training) ep:088, batch:0083 -> curr_mean-loss:0.00739, mean_batch-loss:0.03050: : 83it [00:21,  3.85it/s]
# Training) ep:089, batch:0083 -> curr_mean-loss:0.00737, mean_batch-loss:0.02387: : 83it [00:21,  3.85it/s]
# Training) ep:090, batch:0083 -> curr_mean-loss:0.00739, mean_batch-loss:0.03369: : 83it [00:21,  3.85it/s]
# Training) ep:091, batch:0083 -> curr_mean-loss:0.00734, mean_batch-loss:0.03353: : 83it [00:21,  3.84it/s]
# Training) ep:092, batch:0083 -> curr_mean-loss:0.00733, mean_batch-loss:0.03064: : 83it [00:21,  3.84it/s]
# Training) ep:093, batch:0083 -> curr_mean-loss:0.00732, mean_batch-loss:0.02970: : 83it [00:21,  3.85it/s]
# Training) ep:094, batch:0083 -> curr_mean-loss:0.00724, mean_batch-loss:0.02478: : 83it [00:21,  3.84it/s]
# Training) ep:095, batch:0083 -> curr_mean-loss:0.00725, mean_batch-loss:0.02821: : 83it [00:21,  3.85it/s]
# Training) ep:096, batch:0083 -> curr_mean-loss:0.00723, mean_batch-loss:0.02607: : 83it [00:21,  3.85it/s]
# Training) ep:097, batch:0083 -> curr_mean-loss:0.00720, mean_batch-loss:0.02575: : 83it [00:21,  3.85it/s]
# Training) ep:098, batch:0083 -> curr_mean-loss:0.00721, mean_batch-loss:0.03346: : 83it [00:21,  3.85it/s]
# Training) ep:099, batch:0083 -> curr_mean-loss:0.00724, mean_batch-loss:0.05035: : 83it [00:21,  3.85it/s]
# Training) ep:100, batch:0083 -> curr_mean-loss:0.00715, mean_batch-loss:0.02236: : 83it [00:21,  3.84it/s]
# Training) ep:101, batch:0083 -> curr_mean-loss:0.00713, mean_batch-loss:0.02817: : 83it [00:21,  3.84it/s]
# Training) ep:102, batch:0083 -> curr_mean-loss:0.00714, mean_batch-loss:0.03468: : 83it [00:21,  3.84it/s]
# Training) ep:103, batch:0083 -> curr_mean-loss:0.00718, mean_batch-loss:0.04150: : 83it [00:21,  3.84it/s]
# Training) ep:104, batch:0083 -> curr_mean-loss:0.00715, mean_batch-loss:0.02511: : 83it [00:21,  3.85it/s]
# Training) ep:105, batch:0083 -> curr_mean-loss:0.00709, mean_batch-loss:0.03062: : 83it [00:21,  3.85it/s]
# Training) ep:106, batch:0083 -> curr_mean-loss:0.00709, mean_batch-loss:0.02902: : 83it [00:21,  3.85it/s]
# Training) ep:107, batch:0083 -> curr_mean-loss:0.00704, mean_batch-loss:0.02629: : 83it [00:21,  3.85it/s]
# Training) ep:108, batch:0083 -> curr_mean-loss:0.00702, mean_batch-loss:0.02421: : 83it [00:21,  3.85it/s]
# Training) ep:109, batch:0083 -> curr_mean-loss:0.00706, mean_batch-loss:0.03195: : 83it [00:21,  3.84it/s]
# Training) ep:110, batch:0083 -> curr_mean-loss:0.00703, mean_batch-loss:0.03706: : 83it [00:21,  3.85it/s]
# Training) ep:111, batch:0083 -> curr_mean-loss:0.00705, mean_batch-loss:0.02181: : 83it [00:21,  3.84it/s]
# Training) ep:112, batch:0083 -> curr_mean-loss:0.00697, mean_batch-loss:0.02406: : 83it [00:21,  3.84it/s]
# Training) ep:113, batch:0083 -> curr_mean-loss:0.00693, mean_batch-loss:0.02361: : 83it [00:21,  3.84it/s]
# Training) ep:114, batch:0083 -> curr_mean-loss:0.00693, mean_batch-loss:0.02613: : 83it [00:21,  3.84it/s]
# Training) ep:115, batch:0083 -> curr_mean-loss:0.00696, mean_batch-loss:0.03568: : 83it [00:21,  3.84it/s]
# Training) ep:116, batch:0083 -> curr_mean-loss:0.00695, mean_batch-loss:0.04489: : 83it [00:21,  3.85it/s]
# Training) ep:117, batch:0083 -> curr_mean-loss:0.00691, mean_batch-loss:0.03207: : 83it [00:21,  3.84it/s]
# Training) ep:118, batch:0083 -> curr_mean-loss:0.00686, mean_batch-loss:0.02158: : 83it [00:21,  3.85it/s]
# Training) ep:119, batch:0083 -> curr_mean-loss:0.00688, mean_batch-loss:0.03492: : 83it [00:21,  3.84it/s]
# Training) ep:120, batch:0083 -> curr_mean-loss:0.00684, mean_batch-loss:0.02035: : 83it [00:21,  3.85it/s]
# Training) ep:121, batch:0083 -> curr_mean-loss:0.00689, mean_batch-loss:0.04615: : 83it [00:21,  3.85it/s]
# Training) ep:122, batch:0083 -> curr_mean-loss:0.00688, mean_batch-loss:0.02141: : 83it [00:21,  3.85it/s]
# Training) ep:123, batch:0083 -> curr_mean-loss:0.00685, mean_batch-loss:0.02917: : 83it [00:21,  3.85it/s]
# Training) ep:124, batch:0083 -> curr_mean-loss:0.00690, mean_batch-loss:0.03293: : 83it [00:21,  3.85it/s]
# Training) ep:125, batch:0083 -> curr_mean-loss:0.00679, mean_batch-loss:0.02776: : 83it [00:21,  3.85it/s]
# Training) ep:126, batch:0083 -> curr_mean-loss:0.00679, mean_batch-loss:0.03347: : 83it [00:21,  3.83it/s]
# Training) ep:127, batch:0083 -> curr_mean-loss:0.00681, mean_batch-loss:0.02650: : 83it [00:21,  3.84it/s]
# Training) ep:128, batch:0083 -> curr_mean-loss:0.00677, mean_batch-loss:0.03098: : 83it [00:21,  3.85it/s]
# Training) ep:129, batch:0083 -> curr_mean-loss:0.00674, mean_batch-loss:0.02249: : 83it [00:21,  3.85it/s]
# Training) ep:130, batch:0083 -> curr_mean-loss:0.00672, mean_batch-loss:0.01925: : 83it [00:21,  3.85it/s]
# Training) ep:131, batch:0083 -> curr_mean-loss:0.00670, mean_batch-loss:0.02655: : 83it [00:21,  3.85it/s]
# Training) ep:132, batch:0083 -> curr_mean-loss:0.00669, mean_batch-loss:0.02174: : 83it [00:21,  3.84it/s]
# Training) ep:133, batch:0083 -> curr_mean-loss:0.00669, mean_batch-loss:0.02002: : 83it [00:21,  3.85it/s]
# Training) ep:134, batch:0083 -> curr_mean-loss:0.00670, mean_batch-loss:0.02673: : 83it [00:21,  3.85it/s]
# Training) ep:135, batch:0083 -> curr_mean-loss:0.00670, mean_batch-loss:0.03297: : 83it [00:21,  3.85it/s]
# Training) ep:136, batch:0083 -> curr_mean-loss:0.00668, mean_batch-loss:0.01900: : 83it [00:21,  3.84it/s]
# Training) ep:137, batch:0083 -> curr_mean-loss:0.00670, mean_batch-loss:0.04418: : 83it [00:21,  3.85it/s]
# Training) ep:138, batch:0083 -> curr_mean-loss:0.00665, mean_batch-loss:0.01868: : 83it [00:21,  3.84it/s]
# Training) ep:139, batch:0083 -> curr_mean-loss:0.00666, mean_batch-loss:0.05596: : 83it [00:21,  3.85it/s]
# Training) ep:140, batch:0083 -> curr_mean-loss:0.00658, mean_batch-loss:0.01878: : 83it [00:21,  3.84it/s]
# Training) ep:141, batch:0083 -> curr_mean-loss:0.00660, mean_batch-loss:0.02069: : 83it [00:21,  3.84it/s]
# Training) ep:142, batch:0083 -> curr_mean-loss:0.00655, mean_batch-loss:0.01718: : 83it [00:21,  3.84it/s]
# Training) ep:143, batch:0083 -> curr_mean-loss:0.00658, mean_batch-loss:0.02934: : 83it [00:21,  3.85it/s]
# Training) ep:144, batch:0083 -> curr_mean-loss:0.00658, mean_batch-loss:0.02503: : 83it [00:21,  3.84it/s]
# Training) ep:145, batch:0083 -> curr_mean-loss:0.00653, mean_batch-loss:0.01864: : 83it [00:21,  3.84it/s]
# Training) ep:146, batch:0083 -> curr_mean-loss:0.00652, mean_batch-loss:0.01914: : 83it [00:21,  3.84it/s]
# Training) ep:147, batch:0083 -> curr_mean-loss:0.00654, mean_batch-loss:0.02364: : 83it [00:21,  3.85it/s]
# Training) ep:148, batch:0083 -> curr_mean-loss:0.00651, mean_batch-loss:0.02165: : 83it [00:21,  3.85it/s]
# Training) ep:149, batch:0083 -> curr_mean-loss:0.00649, mean_batch-loss:0.02254: : 83it [00:21,  3.85it/s]
# Training) ep:150, batch:0083 -> curr_mean-loss:0.00647, mean_batch-loss:0.02037: : 83it [00:21,  3.84it/s]
# Training) ep:151, batch:0083 -> curr_mean-loss:0.00647, mean_batch-loss:0.02000: : 83it [00:21,  3.84it/s]
# Training) ep:152, batch:0083 -> curr_mean-loss:0.00649, mean_batch-loss:0.02706: : 83it [00:21,  3.84it/s]
# Training) ep:153, batch:0083 -> curr_mean-loss:0.00643, mean_batch-loss:0.02375: : 83it [00:21,  3.85it/s]
# Training) ep:154, batch:0083 -> curr_mean-loss:0.00646, mean_batch-loss:0.02804: : 83it [00:21,  3.84it/s]
# Training) ep:155, batch:0083 -> curr_mean-loss:0.00646, mean_batch-loss:0.02858: : 83it [00:21,  3.84it/s]
# Training) ep:156, batch:0083 -> curr_mean-loss:0.00646, mean_batch-loss:0.04938: : 83it [00:21,  3.85it/s]
# Training) ep:157, batch:0083 -> curr_mean-loss:0.00643, mean_batch-loss:0.02889: : 83it [00:21,  3.84it/s]
# Training) ep:158, batch:0083 -> curr_mean-loss:0.00643, mean_batch-loss:0.02874: : 83it [00:21,  3.84it/s]
# Training) ep:159, batch:0083 -> curr_mean-loss:0.00640, mean_batch-loss:0.02803: : 83it [00:21,  3.83it/s]
# Training) ep:160, batch:0083 -> curr_mean-loss:0.00649, mean_batch-loss:0.05782: : 83it [00:21,  3.85it/s]
# Training) ep:161, batch:0083 -> curr_mean-loss:0.00640, mean_batch-loss:0.02920: : 83it [00:21,  3.84it/s]
# Training) ep:162, batch:0083 -> curr_mean-loss:0.00638, mean_batch-loss:0.03451: : 83it [00:21,  3.85it/s]
# Training) ep:163, batch:0083 -> curr_mean-loss:0.00634, mean_batch-loss:0.02276: : 83it [00:21,  3.85it/s]
# Training) ep:164, batch:0083 -> curr_mean-loss:0.00636, mean_batch-loss:0.02617: : 83it [00:21,  3.84it/s]
# Training) ep:165, batch:0083 -> curr_mean-loss:0.00634, mean_batch-loss:0.02997: : 83it [00:21,  3.85it/s]
# Training) ep:166, batch:0083 -> curr_mean-loss:0.00632, mean_batch-loss:0.02615: : 83it [00:21,  3.84it/s]
# Training) ep:167, batch:0083 -> curr_mean-loss:0.00628, mean_batch-loss:0.01636: : 83it [00:21,  3.84it/s]
# Training) ep:168, batch:0083 -> curr_mean-loss:0.00634, mean_batch-loss:0.02762: : 83it [00:21,  3.84it/s]
# Training) ep:169, batch:0083 -> curr_mean-loss:0.00629, mean_batch-loss:0.02803: : 83it [00:21,  3.85it/s]
# Training) ep:170, batch:0083 -> curr_mean-loss:0.00626, mean_batch-loss:0.02030: : 83it [00:21,  3.84it/s]
# Training) ep:171, batch:0083 -> curr_mean-loss:0.00623, mean_batch-loss:0.01719: : 83it [00:21,  3.83it/s]
# Training) ep:172, batch:0083 -> curr_mean-loss:0.00622, mean_batch-loss:0.01602: : 83it [00:21,  3.85it/s]
# Training) ep:173, batch:0083 -> curr_mean-loss:0.00625, mean_batch-loss:0.02662: : 83it [00:21,  3.83it/s]
# Training) ep:174, batch:0083 -> curr_mean-loss:0.00621, mean_batch-loss:0.02000: : 83it [00:21,  3.84it/s]
# Training) ep:175, batch:0083 -> curr_mean-loss:0.00622, mean_batch-loss:0.02715: : 83it [00:21,  3.85it/s]
# Training) ep:176, batch:0083 -> curr_mean-loss:0.00622, mean_batch-loss:0.02547: : 83it [00:21,  3.85it/s]
# Training) ep:177, batch:0083 -> curr_mean-loss:0.00620, mean_batch-loss:0.01420: : 83it [00:21,  3.85it/s]
# Training) ep:178, batch:0083 -> curr_mean-loss:0.00621, mean_batch-loss:0.03483: : 83it [00:21,  3.84it/s]
# Training) ep:179, batch:0083 -> curr_mean-loss:0.00621, mean_batch-loss:0.02927: : 83it [00:21,  3.85it/s]
# Training) ep:180, batch:0083 -> curr_mean-loss:0.00621, mean_batch-loss:0.02707: : 83it [00:21,  3.84it/s]
# Training) ep:181, batch:0083 -> curr_mean-loss:0.00614, mean_batch-loss:0.02194: : 83it [00:21,  3.85it/s]
# Training) ep:182, batch:0083 -> curr_mean-loss:0.00618, mean_batch-loss:0.01975: : 83it [00:21,  3.85it/s]
# Training) ep:183, batch:0083 -> curr_mean-loss:0.00613, mean_batch-loss:0.02475: : 83it [00:21,  3.85it/s]
# Training) ep:184, batch:0083 -> curr_mean-loss:0.00609, mean_batch-loss:0.01746: : 83it [00:21,  3.85it/s]
# Training) ep:185, batch:0083 -> curr_mean-loss:0.00617, mean_batch-loss:0.03183: : 83it [00:21,  3.85it/s]
# Training) ep:186, batch:0083 -> curr_mean-loss:0.00611, mean_batch-loss:0.02387: : 83it [00:21,  3.84it/s]
# Training) ep:187, batch:0083 -> curr_mean-loss:0.00615, mean_batch-loss:0.02760: : 83it [00:21,  3.84it/s]
# Training) ep:188, batch:0083 -> curr_mean-loss:0.00613, mean_batch-loss:0.02772: : 83it [00:21,  3.83it/s]
# Training) ep:189, batch:0083 -> curr_mean-loss:0.00605, mean_batch-loss:0.02308: : 83it [00:21,  3.84it/s]
# Training) ep:190, batch:0083 -> curr_mean-loss:0.00608, mean_batch-loss:0.03038: : 83it [00:21,  3.85it/s]
# Training) ep:191, batch:0083 -> curr_mean-loss:0.00604, mean_batch-loss:0.01997: : 83it [00:21,  3.84it/s]
# Training) ep:192, batch:0083 -> curr_mean-loss:0.00611, mean_batch-loss:0.01785: : 83it [00:21,  3.84it/s]
# Training) ep:193, batch:0083 -> curr_mean-loss:0.00603, mean_batch-loss:0.01949: : 83it [00:21,  3.85it/s]
# Training) ep:194, batch:0083 -> curr_mean-loss:0.00606, mean_batch-loss:0.03095: : 83it [00:21,  3.84it/s]
# Training) ep:195, batch:0083 -> curr_mean-loss:0.00606, mean_batch-loss:0.02846: : 83it [00:21,  3.84it/s]
# Training) ep:196, batch:0083 -> curr_mean-loss:0.00602, mean_batch-loss:0.01545: : 83it [00:21,  3.84it/s]
# Training) ep:197, batch:0083 -> curr_mean-loss:0.00601, mean_batch-loss:0.03193: : 83it [00:21,  3.85it/s]
# Training) ep:198, batch:0083 -> curr_mean-loss:0.00596, mean_batch-loss:0.01985: : 83it [00:21,  3.84it/s]
# Training) ep:199, batch:0083 -> curr_mean-loss:0.00596, mean_batch-loss:0.01925: : 83it [00:21,  3.85it/s]
# Training) ep:200, batch:0083 -> curr_mean-loss:0.00601, mean_batch-loss:0.05089: : 83it [00:21,  3.84it/s]
# Training) ep:201, batch:0083 -> curr_mean-loss:0.00597, mean_batch-loss:0.02732: : 83it [00:21,  3.84it/s]
# Training) ep:202, batch:0083 -> curr_mean-loss:0.00592, mean_batch-loss:0.01757: : 83it [00:21,  3.85it/s]
# Training) ep:203, batch:0083 -> curr_mean-loss:0.00596, mean_batch-loss:0.01986: : 83it [00:21,  3.85it/s]
# Training) ep:204, batch:0083 -> curr_mean-loss:0.00594, mean_batch-loss:0.02157: : 83it [00:21,  3.84it/s]
# Training) ep:205, batch:0083 -> curr_mean-loss:0.00591, mean_batch-loss:0.01476: : 83it [00:21,  3.85it/s]
# Training) ep:206, batch:0083 -> curr_mean-loss:0.00590, mean_batch-loss:0.02703: : 83it [00:21,  3.85it/s]
# Training) ep:207, batch:0083 -> curr_mean-loss:0.00586, mean_batch-loss:0.01165: : 83it [00:21,  3.84it/s]
# Training) ep:208, batch:0083 -> curr_mean-loss:0.00586, mean_batch-loss:0.02119: : 83it [00:21,  3.85it/s]
# Training) ep:209, batch:0083 -> curr_mean-loss:0.00590, mean_batch-loss:0.04255: : 83it [00:21,  3.85it/s]
# Training) ep:210, batch:0083 -> curr_mean-loss:0.00585, mean_batch-loss:0.02094: : 83it [00:21,  3.84it/s]
# Training) ep:211, batch:0083 -> curr_mean-loss:0.00584, mean_batch-loss:0.01551: : 83it [00:21,  3.84it/s]
# Training) ep:212, batch:0083 -> curr_mean-loss:0.00582, mean_batch-loss:0.01526: : 83it [00:21,  3.85it/s]
# Training) ep:213, batch:0083 -> curr_mean-loss:0.00585, mean_batch-loss:0.03022: : 83it [00:21,  3.84it/s]
# Training) ep:214, batch:0083 -> curr_mean-loss:0.00581, mean_batch-loss:0.02526: : 83it [00:21,  3.84it/s]
# Training) ep:215, batch:0083 -> curr_mean-loss:0.00579, mean_batch-loss:0.01899: : 83it [00:21,  3.84it/s]
# Training) ep:216, batch:0083 -> curr_mean-loss:0.00580, mean_batch-loss:0.02977: : 83it [00:21,  3.85it/s]
# Training) ep:217, batch:0083 -> curr_mean-loss:0.00577, mean_batch-loss:0.02530: : 83it [00:21,  3.85it/s]
# Training) ep:218, batch:0083 -> curr_mean-loss:0.00574, mean_batch-loss:0.01801: : 83it [00:21,  3.84it/s]
# Training) ep:219, batch:0083 -> curr_mean-loss:0.00571, mean_batch-loss:0.01482: : 83it [00:21,  3.84it/s]
# Training) ep:220, batch:0083 -> curr_mean-loss:0.00573, mean_batch-loss:0.01607: : 83it [00:21,  3.85it/s]
# Training) ep:221, batch:0083 -> curr_mean-loss:0.00575, mean_batch-loss:0.02968: : 83it [00:21,  3.84it/s]
# Training) ep:222, batch:0083 -> curr_mean-loss:0.00569, mean_batch-loss:0.01500: : 83it [00:21,  3.85it/s]
# Training) ep:223, batch:0083 -> curr_mean-loss:0.00572, mean_batch-loss:0.03180: : 83it [00:21,  3.85it/s]
# Training) ep:224, batch:0083 -> curr_mean-loss:0.00573, mean_batch-loss:0.02825: : 83it [00:21,  3.84it/s]
# Training) ep:225, batch:0083 -> curr_mean-loss:0.00568, mean_batch-loss:0.02492: : 83it [00:21,  3.85it/s]
# Training) ep:226, batch:0083 -> curr_mean-loss:0.00568, mean_batch-loss:0.01913: : 83it [00:21,  3.85it/s]
# Training) ep:230, batch:0083 -> curr_mean-loss:0.00561, mean_batch-loss:0.02217: : 83it [00:21,  3.84it/s]
# Training) ep:336, batch:0083 -> curr_mean-loss:0.00427, mean_batch-loss:0.02690: : 83it [00:21,  3.84it/s]
# Training) ep:337, batch:0083 -> curr_mean-loss:0.00423, mean_batch-loss:0.01121: : 83it [00:21,  3.85it/s]
# Training) ep:338, batch:0083 -> curr_mean-loss:0.00423, mean_batch-loss:0.01988: : 83it [00:21,  3.85it/s]
# Training) ep:339, batch:0083 -> curr_mean-loss:0.00421, mean_batch-loss:0.01030: : 83it [00:21,  3.85it/s]
# Training) ep:340, batch:0083 -> curr_mean-loss:0.00424, mean_batch-loss:0.02362: : 83it [00:21,  3.85it/s]
# Training) ep:341, batch:0083 -> curr_mean-loss:0.00424, mean_batch-loss:0.02578: : 83it [00:21,  3.84it/s]
# Training) ep:342, batch:0083 -> curr_mean-loss:0.00422, mean_batch-loss:0.01839: : 83it [00:21,  3.83it/s]
# Training) ep:346, batch:0083 -> curr_mean-loss:0.00419, mean_batch-loss:0.01437: : 83it [00:21,  3.84it/s]
# Training) ep:347, batch:0034 -> curr_mean-loss:0.00414, mean_batch-loss:0.00327: : 33it [00:08,  3.86it/s]

# %%
te_metrics = test(best_model, te_dataloader)
te_metrics.compute()

# %%
f"{config['model']['save_dir']}"

# %% [markdown]
# # Test the best inferred model
# ----

# %% [markdown]
# ## Load the best model

# %%
best_model = Net(**config['model']['params'])
torch.cuda.empty_cache()
best_model = best_model.to(device)

fn = "best_model_state_dict.pt"
os.makedirs(config['model']['save_dir'], exist_ok=True)
model_path = f"{config['model']['save_dir']}/{fn}"

best_model.load_state_dict(torch.load(model_path))
print("Loaded best model weights...")

# %% [markdown]
# ## Evaluation

# %%
te_metrics = test(best_model, te_dataloader)
te_metrics.compute()
# Out:
# 100%|██████████| 50/50 [00:07<00:00,  6.47it/s]
# {'test_metrics/F1Score': tensor(0.8082, device='cuda:0'),
#  'test_metrics/Accuracy': tensor(0.9663, device='cuda:0'),
#  'test_metrics/Dice': tensor(0.8082, device='cuda:0'),
#  'test_metrics/Precision': tensor(0.8152, device='cuda:0'),
#  'test_metrics/Recall': tensor(0.8014, device='cuda:0'),
#  'test_metrics/Specificity': tensor(0.9823, device='cuda:0'),
#  'test_metrics/JaccardIndex': tensor(0.8209, device='cuda:0')}

# %% [markdown]
# ## Plot graphs

# %%
result_file_path = f"{config['model']['save_dir']}/result.json"
with open(result_file_path, 'r') as f:
    results = json.loads(''.join(f.readlines()))
epochs_info = results['epochs_info']

tr_losses = [d['tr_loss'] for d in epochs_info]
vl_losses = [d['vl_loss'] for d in epochs_info]
tr_dice = [d['tr_metrics']['train_metrics/Dice'] for d in epochs_info]
vl_dice = [d['vl_metrics']['valid_metrics/Dice'] for d in epochs_info]
tr_js = [d['tr_metrics']['train_metrics/JaccardIndex'] for d in epochs_info]
vl_js = [d['vl_metrics']['valid_metrics/JaccardIndex'] for d in epochs_info]
tr_acc = [d['tr_metrics']['train_metrics/Accuracy'] for d in epochs_info]
vl_acc = [d['vl_metrics']['valid_metrics/Accuracy'] for d in epochs_info]


_, axs = plt.subplots(1, 4, figsize=[16,3])

axs[0].set_title("Loss")
axs[0].plot(tr_losses, 'r-', label="train loss")
axs[0].plot(vl_losses, 'b-', label="validatiton loss")
axs[0].legend()

axs[1].set_title("Dice score")
axs[1].plot(tr_dice, 'r-', label="train dice")
axs[1].plot(vl_dice, 'b-', label="validation dice")
axs[1].legend()

axs[2].set_title("Jaccard Similarity")
axs[2].plot(tr_js, 'r-', label="train JaccardIndex")
axs[2].plot(vl_js, 'b-', label="validatiton JaccardIndex")
axs[2].legend()

axs[3].set_title("Accuracy")
axs[3].plot(tr_acc, 'r-', label="train Accuracy")
axs[3].plot(vl_acc, 'b-', label="validation Accuracy")
axs[3].legend()

plt.show()

# %%
epochs_info

# %% [markdown]
# ## Save images

# %%
from PIL import Image


save_imgs_dir = f"{config['model']['save_dir']}/visualized"

if not os.path.isdir(save_imgs_dir):
    os.mkdir(save_imgs_dir)

with torch.no_grad():
    for batch in tqdm(te_dataloader):
        imgs = batch['image']
        msks = batch['mask']
        ids = batch['id']
        
        preds = best_model(imgs.to(device))
        
        txm = imgs.cpu().numpy()
        tbm = torch.argmax(msks, 1).cpu().numpy()
        tpm = torch.argmax(preds, 1).cpu().numpy()
        tid = ids.cpu().numpy()
        
        for idx in range(len(tbm)):
            img = np.moveaxis(txm[idx, :3], 0, -1)*255.
            nuc = np.uint8(txm[idx, -1]*255.)
            gt = np.uint8(tbm[idx]*255.)
            gt_3ch = np.stack([gt-nuc, nuc*0, nuc], -1)
            pred = np.where(tpm[idx]>0.5, 255, 0)
            pred_3ch = np.stack([pred-nuc, nuc*0, nuc], -1)
            
            img = np.ascontiguousarray(img, dtype=np.uint8)
            gt_3ch = np.ascontiguousarray(gt_3ch, dtype=np.uint8)
            pred_3ch = np.ascontiguousarray(pred_3ch, dtype=np.uint8)
            
            fid = tid[idx]
            Image.fromarray(img).save(f"{save_imgs_dir}/{fid}_img.png")
            Image.fromarray(gt_3ch).save(f"{save_imgs_dir}/{fid}_gt.png")
            Image.fromarray(pred_3ch).save(f"{save_imgs_dir}/{fid}_pred.png")

# %%
f"{config['model']['save_dir']}/visualized"
# Out:
# '../saved_models/segpc2021_missformer/visualized'
