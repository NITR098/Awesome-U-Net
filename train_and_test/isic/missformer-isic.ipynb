# %% [markdown]
# # MISSFormer - ISIC2018
# ---

# %% [markdown]
# ## Import packages & functions

# %%
from __future__ import print_function, division


import os
import sys
sys.path.append('../..')
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import copy
import json
import importlib
import glob
import pandas as pd
from skimage import io, transform
import matplotlib.pyplot as plt
from matplotlib.image import imread
import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchmetrics
from torch.optim import Adam, SGD
from losses import DiceLoss, DiceLossWithLogtis
from torch.nn import BCELoss, CrossEntropyLoss

from utils import (
    show_sbs,
    load_config,
    _print,
)

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# plt.ion()   # interactive mode

# %% [markdown]
# ## Set the seed

# %%
torch.manual_seed(0)
np.random.seed(0)
torch.cuda.manual_seed(0)
import random
random.seed(0)

# %% [markdown]
# ## Load the config

# %%
CONFIG_NAME = "isic/isic2018_missformer.yaml"
CONFIG_FILE_PATH = os.path.join("./configs", CONFIG_NAME)

# %%
config = load_config(CONFIG_FILE_PATH)
_print("Config:", "info_underline")
print(json.dumps(config, indent=2))
print(20*"~-", "\n")
# Out:
# Config:
# {
#   "run": {
#     "mode": "train",
#     "device": "gpu"
#   },
#   "transforms": "none",
#   "dataset": {
#     "class_name": "ISIC2018Dataset",
#     "input_size": 224,
#     "training": {
#       "params": {
#         "data_dir": "/path/to/datasets/ISIC2018"
#       }
#     },
#     "validation": {
#       "params": {
#         "data_dir": "/path/to/datasets/ISIC2018"
#       }
#     },
#     "number_classes": 2
#   },
#   "data_loader": {
#     "train": {
#       "batch_size": 16,
#       "shuffle": true,
#       "num_workers": 8,
#       "pin_memory": true
#     },
#     "validation": {
#       "batch_size": 16,
#       "shuffle": false,
#       "num_workers": 8,
#       "pin_memory": true
#     },
#     "test": {
#       "batch_size": 16,
#       "shuffle": false,
#       "num_workers": 4,
#       "pin_memory": false
#     }
#   },
#   "training": {
#     "optimizer": {
#       "name": "SGD",
#       "params": {
#         "lr": 0.0001,
#         "momentum": 0.9,
#         "weight_decay": 0.0001
#       }
#     },
#     "criterion": {
#       "name": "DiceLoss",
#       "params": {}
#     },
#     "scheduler": {
#       "factor": 0.5,
#       "patience": 10
#     },
#     "epochs": 300
#   },
#   "model": {
#     "save_dir": "../saved_models/isic2018_missformer",
#     "load_weights": false,
#     "name": "MISSFormer",
#     "params": {
#       "in_ch": 3,
#       "num_classes": 2
#     }
#   }
# }
# ~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-

# %% [markdown]
# ## Dataset and Dataloader

# %%
from datasets.isic import ISIC2018DatasetFast
from torch.utils.data import DataLoader, Subset
from torchvision import transforms

# %%
# ------------------- params --------------------
INPUT_SIZE = config['dataset']['input_size']
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<


# ----------------- dataset --------------------
# preparing training dataset
tr_dataset = ISIC2018DatasetFast(mode="tr", one_hot=True)
vl_dataset = ISIC2018DatasetFast(mode="vl", one_hot=True)
te_dataset = ISIC2018DatasetFast(mode="te", one_hot=True)

# We consider 1815 samples for training, 259 samples for validation and 520 samples for testing
# !cat ~/deeplearning/skin/Prepare_ISIC2018.py

print(f"Length of trainig_dataset:\t{len(tr_dataset)}")
print(f"Length of validation_dataset:\t{len(vl_dataset)}")
print(f"Length of test_dataset:\t\t{len(te_dataset)}")


# prepare train dataloader
tr_dataloader = DataLoader(tr_dataset, **config['data_loader']['train'])

# prepare validation dataloader
vl_dataloader = DataLoader(vl_dataset, **config['data_loader']['validation'])

# prepare test dataloader
te_dataloader = DataLoader(te_dataset, **config['data_loader']['test'])

# -------------- test -----------------
# test and visualize the input data
for sample in tr_dataloader:
    img = sample['image']
    msk = sample['mask']
    print("\n Training")
    show_sbs(img[0], msk[0,1])
    break
    
for sample in vl_dataloader:
    img = sample['image']
    msk = sample['mask']
    print("Validation")
    show_sbs(img[0], msk[0,1])
    break
    
for sample in te_dataloader:
    img = sample['image']
    msk = sample['mask']
    print("Test")
    show_sbs(img[0], msk[0,1])
    break
# Out:
# Length of trainig_dataset:	1815
# Length of validation_dataset:	259
# Length of test_dataset:		520
#
#  Training
# Validation
# Test

# %% [markdown]
# ### Device

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Torch device: {device}")
# Out:
# Torch device: cuda

# %% [markdown]
# ## Metrics

# %%
metrics = torchmetrics.MetricCollection(
    [
        torchmetrics.F1Score(),
        torchmetrics.Accuracy(),
        torchmetrics.Dice(),
        torchmetrics.Precision(),
        torchmetrics.Specificity(),
        torchmetrics.Recall(),
        # IoU
        torchmetrics.JaccardIndex(2)
    ],
    prefix='train_metrics/'
)

# train_metrics
train_metrics = metrics.clone(prefix='train_metrics/').to(device)

# valid_metrics
valid_metrics = metrics.clone(prefix='valid_metrics/').to(device)

# test_metrics
test_metrics = metrics.clone(prefix='test_metrics/').to(device)

# %%
def make_serializeable_metrics(computed_metrics):
    res = {}
    for k, v in computed_metrics.items():
        res[k] = float(v.cpu().detach().numpy())
    return res

# %% [markdown]
# ## Define validate function

# %%
def validate(model, criterion, vl_dataloader):
    model.eval()
    with torch.no_grad():
        
        evaluator = valid_metrics.clone().to(device)
        
        losses = []
        cnt = 0.
        for batch, batch_data in enumerate(vl_dataloader):
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            cnt += msks.shape[0]
            
            imgs = imgs.to(device)
            msks = msks.to(device)
            
            preds = model(imgs)
            loss = criterion(preds, msks)
            losses.append(loss.item())
            
            
            preds_ = torch.argmax(preds, 1, keepdim=False).float()
            msks_ = torch.argmax(msks, 1, keepdim=False)
            evaluator.update(preds_, msks_)
        
#             _cml = f"curr_mean-loss:{np.sum(losses)/cnt:0.5f}"
#             _bl = f"batch-loss:{losses[-1]/msks.shape[0]:0.5f}"
#             iterator.set_description(f"Validation) batch:{batch+1:04d} -> {_cml}, {_bl}")
        
        # print the final results
        loss = np.sum(losses)/cnt
        metrics = evaluator.compute()
    
    return evaluator, loss

# %% [markdown]
# ## Define train function

# %%
def train(
    model, 
    device, 
    tr_dataloader,
    vl_dataloader,
    config,
    
    criterion,
    optimizer,
    scheduler,
    
    save_dir='./',
    save_file_id=None,
):
    
    EPOCHS = tr_prms['epochs']
    
    torch.cuda.empty_cache()
    model = model.to(device)

    evaluator = train_metrics.clone().to(device)
    
    epochs_info = []
    best_model = None
    best_result = {}
    best_vl_loss = np.Inf
    for epoch in range(EPOCHS):
        model.train()
        
        evaluator.reset()
        tr_iterator = tqdm(enumerate(tr_dataloader))
        tr_losses = []
        cnt = 0
        for batch, batch_data in tr_iterator:
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            imgs = imgs.to(device)
            msks = msks.to(device)
            
            optimizer.zero_grad()
            preds = model(imgs)
            loss = criterion(preds, msks)
            loss.backward()
            optimizer.step()
            
            # evaluate by metrics
            preds_ = torch.argmax(preds, 1, keepdim=False).float()
            msks_ = torch.argmax(msks, 1, keepdim=False)
            evaluator.update(preds_, msks_)
            
            cnt += imgs.shape[0]
            tr_losses.append(loss.item())
            
            # write details for each training batch
            _cml = f"curr_mean-loss:{np.sum(tr_losses)/cnt:0.5f}"
            _bl = f"mean_batch-loss:{tr_losses[-1]/imgs.shape[0]:0.5f}"
            tr_iterator.set_description(f"Training) ep:{epoch:03d}, batch:{batch+1:04d} -> {_cml}, {_bl}")
            
        tr_loss = np.sum(tr_losses)/cnt
        
        # validate model
        vl_metrics, vl_loss = validate(model, criterion, vl_dataloader)
        if vl_loss < best_vl_loss:
            # find a better model
            best_model = model
            best_vl_loss = vl_loss
            best_result = {
                'tr_loss': tr_loss,
                'vl_loss': vl_loss,
                'tr_metrics': make_serializeable_metrics(evaluator.compute()),
                'vl_metrics': make_serializeable_metrics(vl_metrics.compute())
            }
        
        # write the final results
        epoch_info = {
            'tr_loss': tr_loss,
            'vl_loss': vl_loss,
            'tr_metrics': make_serializeable_metrics(evaluator.compute()),
            'vl_metrics': make_serializeable_metrics(vl_metrics.compute())
        }
        epochs_info.append(epoch_info)
#         epoch_tqdm.set_description(f"Epoch:{epoch+1}/{EPOCHS} -> tr_loss:{tr_loss}, vl_loss:{vl_loss}")
        evaluator.reset()
    
        scheduler.step(vl_loss)
  
    # save final results
    res = {
        'id': save_file_id,
        'config': config,
        'epochs_info': epochs_info,
        'best_result': best_result
    }
    fn = f"{save_file_id+'_' if save_file_id else ''}result.json"
    fp = os.path.join(config['model']['save_dir'],fn)
    with open(fp, "w") as write_file:
        json.dump(res, write_file, indent=4)

    # save model's state_dict
    fn = "last_model_state_dict.pt"
    fp = os.path.join(config['model']['save_dir'],fn)
    torch.save(model.state_dict(), fp)
    
    # save the best model's state_dict
    fn = "best_model_state_dict.pt"
    fp = os.path.join(config['model']['save_dir'], fn)
    torch.save(best_model.state_dict(), fp)
    
    return best_model, model, res

# %% [markdown]
# ## Define test function

# %%
def test(model, te_dataloader):
    model.eval()
    with torch.no_grad():
        evaluator = test_metrics.clone().to(device)            
        for batch_data in tqdm(te_dataloader):
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            imgs = imgs.to(device)
            msks = msks.to(device)
            
            preds = model(imgs)
            
            # evaluate by metrics
            preds_ = torch.argmax(preds, 1, keepdim=False).float()
            msks_ = torch.argmax(msks, 1, keepdim=False)
            evaluator.update(preds_, msks_)
            
    return evaluator

# %% [markdown]
# ## Load and prepare model

# %%
# download weights

# !wget "https://storage.googleapis.com/vit_models/imagenet21k/R50%2BViT-B_16.npz"
# !mkdir -p ../model/vit_checkpoint/imagenet21k
# !mv R50+ViT-B_16.npz ../model/vit_checkpoint/imagenet21k/R50+ViT-B_16.npz

# %%
from models._missformer.MISSFormer import MISSFormer as Net

model = Net(**config['model']['params'])
torch.cuda.empty_cache()
model = model.to(device)
print("Number of parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))

os.makedirs(config['model']['save_dir'], exist_ok=True)
model_path = f"{config['model']['save_dir']}/model_state_dict.pt"

if config['model']['load_weights']:
    model.load_state_dict(torch.load(model_path))
    print("Loaded pre-trained weights...")
    
    
# criterion_dice = DiceLoss()
criterion_dice = DiceLossWithLogtis()
# criterion_ce  = BCELoss()
criterion_ce  = CrossEntropyLoss()


def criterion(preds, masks):
    c_dice = criterion_dice(preds, masks)
    c_ce = criterion_ce(preds, masks)
    return 0.5*c_dice + 0.5*c_ce

tr_prms = config['training']
optimizer = globals()[tr_prms['optimizer']['name']](model.parameters(), **tr_prms['optimizer']['params'])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', **tr_prms['scheduler'])
# Out:
# Number of parameters: 42462082

# %% [markdown]
# ## Start traning

# %%
best_model, model, res = train(
    model, 
    device, 
    tr_dataloader,
    vl_dataloader,
    config,
    
    criterion,
    optimizer,
    scheduler,

    save_dir = config['model']['save_dir'],
    save_file_id = None,
)
# Out:
# Training) ep:000, batch:0114 -> curr_mean-loss:0.03352, mean_batch-loss:0.07507: : 114it [01:04,  1.77it/s]
# Training) ep:001, batch:0114 -> curr_mean-loss:0.03128, mean_batch-loss:0.06256: : 114it [01:00,  1.88it/s]
# Training) ep:002, batch:0114 -> curr_mean-loss:0.02990, mean_batch-loss:0.07402: : 114it [01:00,  1.88it/s]
# Training) ep:003, batch:0114 -> curr_mean-loss:0.02747, mean_batch-loss:0.05993: : 114it [00:59,  1.90it/s]
# Training) ep:004, batch:0114 -> curr_mean-loss:0.02356, mean_batch-loss:0.05525: : 114it [01:00,  1.88it/s]
# Training) ep:005, batch:0114 -> curr_mean-loss:0.02026, mean_batch-loss:0.03041: : 114it [01:00,  1.89it/s]
# Training) ep:006, batch:0114 -> curr_mean-loss:0.01672, mean_batch-loss:0.03323: : 114it [00:59,  1.90it/s]
# Training) ep:007, batch:0114 -> curr_mean-loss:0.01525, mean_batch-loss:0.06875: : 114it [01:00,  1.88it/s]
# Training) ep:008, batch:0114 -> curr_mean-loss:0.01430, mean_batch-loss:0.03526: : 114it [01:00,  1.88it/s]
# Training) ep:009, batch:0114 -> curr_mean-loss:0.01365, mean_batch-loss:0.04552: : 114it [00:59,  1.92it/s]
# Training) ep:010, batch:0114 -> curr_mean-loss:0.01325, mean_batch-loss:0.03007: : 114it [01:00,  1.88it/s]
# Training) ep:011, batch:0114 -> curr_mean-loss:0.01312, mean_batch-loss:0.02095: : 114it [01:00,  1.88it/s]
# Training) ep:012, batch:0114 -> curr_mean-loss:0.01268, mean_batch-loss:0.03720: : 114it [00:59,  1.92it/s]
# Training) ep:013, batch:0114 -> curr_mean-loss:0.01240, mean_batch-loss:0.04885: : 114it [01:00,  1.89it/s]
# Training) ep:014, batch:0114 -> curr_mean-loss:0.01220, mean_batch-loss:0.03313: : 114it [01:00,  1.88it/s]
# Training) ep:015, batch:0114 -> curr_mean-loss:0.01225, mean_batch-loss:0.03413: : 114it [01:00,  1.89it/s]
# Training) ep:016, batch:0114 -> curr_mean-loss:0.01186, mean_batch-loss:0.01702: : 114it [01:00,  1.88it/s]
# Training) ep:017, batch:0114 -> curr_mean-loss:0.01182, mean_batch-loss:0.01280: : 114it [01:00,  1.87it/s]
# Training) ep:018, batch:0114 -> curr_mean-loss:0.01153, mean_batch-loss:0.01544: : 114it [00:59,  1.90it/s]
# Training) ep:019, batch:0114 -> curr_mean-loss:0.01152, mean_batch-loss:0.02133: : 114it [01:00,  1.88it/s]
# Training) ep:020, batch:0114 -> curr_mean-loss:0.01166, mean_batch-loss:0.02735: : 114it [01:00,  1.89it/s]
# Training) ep:021, batch:0114 -> curr_mean-loss:0.01132, mean_batch-loss:0.02057: : 114it [01:00,  1.88it/s]
# Training) ep:022, batch:0114 -> curr_mean-loss:0.01145, mean_batch-loss:0.01971: : 114it [01:00,  1.88it/s]
# Training) ep:023, batch:0114 -> curr_mean-loss:0.01121, mean_batch-loss:0.03433: : 114it [01:00,  1.90it/s]
# Training) ep:024, batch:0114 -> curr_mean-loss:0.01115, mean_batch-loss:0.02258: : 114it [01:00,  1.87it/s]
# Training) ep:025, batch:0114 -> curr_mean-loss:0.01101, mean_batch-loss:0.02675: : 114it [01:00,  1.88it/s]
# Training) ep:026, batch:0114 -> curr_mean-loss:0.01113, mean_batch-loss:0.02389: : 114it [00:59,  1.90it/s]
# Training) ep:027, batch:0114 -> curr_mean-loss:0.01081, mean_batch-loss:0.01471: : 114it [01:00,  1.88it/s]
# Training) ep:028, batch:0114 -> curr_mean-loss:0.01058, mean_batch-loss:0.02772: : 114it [01:00,  1.87it/s]
# Training) ep:029, batch:0114 -> curr_mean-loss:0.01085, mean_batch-loss:0.01258: : 114it [00:59,  1.91it/s]
# Training) ep:030, batch:0114 -> curr_mean-loss:0.01038, mean_batch-loss:0.01105: : 114it [01:00,  1.88it/s]
# Training) ep:031, batch:0114 -> curr_mean-loss:0.01037, mean_batch-loss:0.03788: : 114it [01:00,  1.88it/s]
# Training) ep:032, batch:0114 -> curr_mean-loss:0.01051, mean_batch-loss:0.03394: : 114it [00:59,  1.92it/s]
# Training) ep:033, batch:0114 -> curr_mean-loss:0.01038, mean_batch-loss:0.01757: : 114it [01:00,  1.89it/s]
# Training) ep:034, batch:0114 -> curr_mean-loss:0.01025, mean_batch-loss:0.02366: : 114it [01:00,  1.89it/s]
# Training) ep:035, batch:0114 -> curr_mean-loss:0.01007, mean_batch-loss:0.01743: : 114it [00:59,  1.90it/s]
# Training) ep:036, batch:0114 -> curr_mean-loss:0.01014, mean_batch-loss:0.01826: : 114it [01:00,  1.89it/s]
# Training) ep:037, batch:0114 -> curr_mean-loss:0.01018, mean_batch-loss:0.02022: : 114it [01:00,  1.88it/s]
# Training) ep:038, batch:0114 -> curr_mean-loss:0.00978, mean_batch-loss:0.01633: : 114it [01:00,  1.89it/s]
# Training) ep:039, batch:0114 -> curr_mean-loss:0.00991, mean_batch-loss:0.03634: : 114it [01:00,  1.89it/s]
# Training) ep:040, batch:0114 -> curr_mean-loss:0.00963, mean_batch-loss:0.02587: : 114it [01:00,  1.89it/s]
# Training) ep:041, batch:0114 -> curr_mean-loss:0.00970, mean_batch-loss:0.04540: : 114it [01:00,  1.89it/s]
# Training) ep:042, batch:0114 -> curr_mean-loss:0.00979, mean_batch-loss:0.02747: : 114it [01:00,  1.88it/s]
# Training) ep:043, batch:0114 -> curr_mean-loss:0.00948, mean_batch-loss:0.01762: : 114it [01:00,  1.88it/s]
# Training) ep:044, batch:0114 -> curr_mean-loss:0.00957, mean_batch-loss:0.02564: : 114it [01:00,  1.89it/s]
# Training) ep:045, batch:0114 -> curr_mean-loss:0.00931, mean_batch-loss:0.02980: : 114it [01:00,  1.88it/s]
# Training) ep:046, batch:0114 -> curr_mean-loss:0.00941, mean_batch-loss:0.02541: : 114it [01:00,  1.90it/s]
# Training) ep:047, batch:0114 -> curr_mean-loss:0.00912, mean_batch-loss:0.01311: : 114it [01:00,  1.87it/s]
# Training) ep:048, batch:0114 -> curr_mean-loss:0.00929, mean_batch-loss:0.03136: : 114it [01:00,  1.87it/s]
# Training) ep:049, batch:0114 -> curr_mean-loss:0.00916, mean_batch-loss:0.01591: : 114it [00:59,  1.91it/s]
# Training) ep:050, batch:0114 -> curr_mean-loss:0.00911, mean_batch-loss:0.00975: : 114it [01:00,  1.88it/s]
# Training) ep:051, batch:0114 -> curr_mean-loss:0.00896, mean_batch-loss:0.02893: : 114it [01:00,  1.88it/s]
# Training) ep:052, batch:0114 -> curr_mean-loss:0.00894, mean_batch-loss:0.01238: : 114it [00:59,  1.92it/s]
# Training) ep:053, batch:0114 -> curr_mean-loss:0.00894, mean_batch-loss:0.02671: : 114it [01:00,  1.89it/s]
# Training) ep:054, batch:0114 -> curr_mean-loss:0.00907, mean_batch-loss:0.02298: : 114it [01:00,  1.89it/s]
# Training) ep:055, batch:0114 -> curr_mean-loss:0.00882, mean_batch-loss:0.01831: : 114it [00:59,  1.92it/s]
# Training) ep:056, batch:0114 -> curr_mean-loss:0.00876, mean_batch-loss:0.02094: : 114it [01:00,  1.88it/s]
# Training) ep:057, batch:0114 -> curr_mean-loss:0.00863, mean_batch-loss:0.01007: : 114it [01:00,  1.88it/s]
# Training) ep:058, batch:0114 -> curr_mean-loss:0.00881, mean_batch-loss:0.00951: : 114it [00:59,  1.91it/s]
# Training) ep:059, batch:0114 -> curr_mean-loss:0.00865, mean_batch-loss:0.02475: : 114it [01:00,  1.88it/s]
# Training) ep:060, batch:0114 -> curr_mean-loss:0.00856, mean_batch-loss:0.01677: : 114it [01:00,  1.89it/s]
# Training) ep:061, batch:0114 -> curr_mean-loss:0.00844, mean_batch-loss:0.02371: : 114it [01:00,  1.90it/s]
# Training) ep:062, batch:0114 -> curr_mean-loss:0.00839, mean_batch-loss:0.01137: : 114it [01:00,  1.88it/s]
# Training) ep:063, batch:0114 -> curr_mean-loss:0.00832, mean_batch-loss:0.02577: : 114it [01:00,  1.88it/s]
# Training) ep:064, batch:0114 -> curr_mean-loss:0.00838, mean_batch-loss:0.01417: : 114it [01:00,  1.88it/s]
# Training) ep:065, batch:0114 -> curr_mean-loss:0.00827, mean_batch-loss:0.01361: : 114it [01:00,  1.89it/s]
# Training) ep:066, batch:0114 -> curr_mean-loss:0.00812, mean_batch-loss:0.01638: : 114it [01:00,  1.89it/s]
# Training) ep:067, batch:0114 -> curr_mean-loss:0.00840, mean_batch-loss:0.02064: : 114it [01:00,  1.88it/s]
# Training) ep:068, batch:0114 -> curr_mean-loss:0.00832, mean_batch-loss:0.01615: : 114it [01:00,  1.88it/s]
# Training) ep:069, batch:0114 -> curr_mean-loss:0.00854, mean_batch-loss:0.01327: : 114it [01:00,  1.89it/s]
# Training) ep:070, batch:0114 -> curr_mean-loss:0.00796, mean_batch-loss:0.02526: : 114it [01:00,  1.89it/s]
# Training) ep:071, batch:0114 -> curr_mean-loss:0.00818, mean_batch-loss:0.03318: : 114it [01:00,  1.87it/s]
# Training) ep:072, batch:0114 -> curr_mean-loss:0.00796, mean_batch-loss:0.00867: : 114it [00:59,  1.92it/s]
# Training) ep:073, batch:0114 -> curr_mean-loss:0.00816, mean_batch-loss:0.02938: : 114it [01:00,  1.88it/s]
# Training) ep:074, batch:0114 -> curr_mean-loss:0.00781, mean_batch-loss:0.01979: : 114it [01:00,  1.88it/s]
# Training) ep:075, batch:0114 -> curr_mean-loss:0.00769, mean_batch-loss:0.01220: : 114it [00:59,  1.92it/s]
# Training) ep:076, batch:0114 -> curr_mean-loss:0.00768, mean_batch-loss:0.01492: : 114it [01:00,  1.89it/s]
# Training) ep:077, batch:0114 -> curr_mean-loss:0.00781, mean_batch-loss:0.01644: : 114it [01:00,  1.88it/s]
# Training) ep:078, batch:0114 -> curr_mean-loss:0.00749, mean_batch-loss:0.01935: : 114it [01:00,  1.90it/s]
# Training) ep:079, batch:0114 -> curr_mean-loss:0.00752, mean_batch-loss:0.01104: : 114it [01:00,  1.88it/s]
# Training) ep:080, batch:0114 -> curr_mean-loss:0.00747, mean_batch-loss:0.00903: : 114it [01:00,  1.89it/s]
# Training) ep:081, batch:0114 -> curr_mean-loss:0.00747, mean_batch-loss:0.01527: : 114it [00:59,  1.91it/s]
# Training) ep:082, batch:0114 -> curr_mean-loss:0.00747, mean_batch-loss:0.01831: : 114it [01:00,  1.88it/s]
# Training) ep:083, batch:0114 -> curr_mean-loss:0.00740, mean_batch-loss:0.01372: : 114it [01:00,  1.88it/s]
# Training) ep:084, batch:0114 -> curr_mean-loss:0.00726, mean_batch-loss:0.00986: : 114it [01:00,  1.88it/s]
# Training) ep:085, batch:0114 -> curr_mean-loss:0.00727, mean_batch-loss:0.01488: : 114it [01:00,  1.89it/s]
# Training) ep:086, batch:0114 -> curr_mean-loss:0.00721, mean_batch-loss:0.01636: : 114it [01:00,  1.88it/s]
# Training) ep:087, batch:0114 -> curr_mean-loss:0.00706, mean_batch-loss:0.01358: : 114it [01:00,  1.88it/s]
# Training) ep:088, batch:0114 -> curr_mean-loss:0.00731, mean_batch-loss:0.02142: : 114it [01:00,  1.87it/s]
# Training) ep:089, batch:0114 -> curr_mean-loss:0.00711, mean_batch-loss:0.01395: : 114it [01:00,  1.90it/s]
# Training) ep:090, batch:0114 -> curr_mean-loss:0.00714, mean_batch-loss:0.01186: : 114it [01:00,  1.88it/s]
# Training) ep:091, batch:0114 -> curr_mean-loss:0.00694, mean_batch-loss:0.02075: : 114it [01:00,  1.88it/s]
# Training) ep:092, batch:0114 -> curr_mean-loss:0.00699, mean_batch-loss:0.01121: : 114it [00:59,  1.91it/s]
# Training) ep:093, batch:0114 -> curr_mean-loss:0.00691, mean_batch-loss:0.01460: : 114it [01:00,  1.88it/s]
# Training) ep:094, batch:0114 -> curr_mean-loss:0.00706, mean_batch-loss:0.02395: : 114it [01:00,  1.88it/s]
# Training) ep:095, batch:0114 -> curr_mean-loss:0.00694, mean_batch-loss:0.01232: : 114it [00:59,  1.92it/s]
# Training) ep:096, batch:0114 -> curr_mean-loss:0.00675, mean_batch-loss:0.02474: : 114it [01:00,  1.88it/s]
# Training) ep:097, batch:0114 -> curr_mean-loss:0.00684, mean_batch-loss:0.01359: : 114it [01:00,  1.88it/s]
# Training) ep:098, batch:0114 -> curr_mean-loss:0.00682, mean_batch-loss:0.01533: : 114it [00:59,  1.91it/s]
# Training) ep:099, batch:0114 -> curr_mean-loss:0.00672, mean_batch-loss:0.01100: : 114it [01:00,  1.88it/s]
# Training) ep:100, batch:0114 -> curr_mean-loss:0.00666, mean_batch-loss:0.00994: : 114it [01:00,  1.88it/s]
# Training) ep:101, batch:0114 -> curr_mean-loss:0.00662, mean_batch-loss:0.00960: : 114it [01:00,  1.90it/s]
# Training) ep:102, batch:0114 -> curr_mean-loss:0.00670, mean_batch-loss:0.02807: : 114it [01:00,  1.88it/s]
# Training) ep:103, batch:0114 -> curr_mean-loss:0.00667, mean_batch-loss:0.00897: : 114it [01:00,  1.88it/s]
# Training) ep:104, batch:0114 -> curr_mean-loss:0.00652, mean_batch-loss:0.00945: : 114it [01:00,  1.88it/s]
# Training) ep:105, batch:0114 -> curr_mean-loss:0.00663, mean_batch-loss:0.01145: : 114it [01:00,  1.89it/s]
# Training) ep:106, batch:0114 -> curr_mean-loss:0.00633, mean_batch-loss:0.01301: : 114it [01:00,  1.88it/s]
# Training) ep:107, batch:0114 -> curr_mean-loss:0.00627, mean_batch-loss:0.01938: : 114it [01:00,  1.88it/s]
# Training) ep:108, batch:0114 -> curr_mean-loss:0.00626, mean_batch-loss:0.01564: : 114it [01:00,  1.88it/s]
# Training) ep:109, batch:0114 -> curr_mean-loss:0.00630, mean_batch-loss:0.02978: : 114it [01:00,  1.90it/s]
# Training) ep:110, batch:0114 -> curr_mean-loss:0.00618, mean_batch-loss:0.01511: : 114it [01:00,  1.89it/s]
# Training) ep:111, batch:0114 -> curr_mean-loss:0.00618, mean_batch-loss:0.01451: : 114it [01:00,  1.87it/s]
# Training) ep:112, batch:0114 -> curr_mean-loss:0.00614, mean_batch-loss:0.01016: : 114it [00:59,  1.92it/s]
# Training) ep:113, batch:0114 -> curr_mean-loss:0.00613, mean_batch-loss:0.01403: : 114it [01:00,  1.88it/s]
# Training) ep:114, batch:0114 -> curr_mean-loss:0.00611, mean_batch-loss:0.01228: : 114it [01:00,  1.88it/s]
# Training) ep:115, batch:0114 -> curr_mean-loss:0.00609, mean_batch-loss:0.01155: : 114it [00:59,  1.91it/s]
# Training) ep:116, batch:0114 -> curr_mean-loss:0.00610, mean_batch-loss:0.01289: : 114it [01:00,  1.89it/s]
# Training) ep:117, batch:0114 -> curr_mean-loss:0.00605, mean_batch-loss:0.00877: : 114it [01:00,  1.88it/s]
# Training) ep:118, batch:0114 -> curr_mean-loss:0.00601, mean_batch-loss:0.01458: : 114it [00:59,  1.91it/s]
# Training) ep:119, batch:0114 -> curr_mean-loss:0.00596, mean_batch-loss:0.01553: : 114it [01:00,  1.88it/s]
# Training) ep:120, batch:0114 -> curr_mean-loss:0.00597, mean_batch-loss:0.01125: : 114it [01:00,  1.88it/s]
# Training) ep:121, batch:0114 -> curr_mean-loss:0.00596, mean_batch-loss:0.01305: : 114it [00:59,  1.90it/s]
# Training) ep:122, batch:0114 -> curr_mean-loss:0.00590, mean_batch-loss:0.01924: : 114it [01:00,  1.88it/s]
# Training) ep:123, batch:0114 -> curr_mean-loss:0.00590, mean_batch-loss:0.01412: : 114it [01:00,  1.88it/s]
# Training) ep:124, batch:0114 -> curr_mean-loss:0.00591, mean_batch-loss:0.01274: : 114it [01:00,  1.90it/s]
# Training) ep:125, batch:0114 -> curr_mean-loss:0.00590, mean_batch-loss:0.01782: : 114it [01:00,  1.88it/s]
# Training) ep:126, batch:0114 -> curr_mean-loss:0.00591, mean_batch-loss:0.01599: : 114it [01:00,  1.89it/s]
# Training) ep:127, batch:0114 -> curr_mean-loss:0.00587, mean_batch-loss:0.01737: : 114it [01:00,  1.89it/s]
# Training) ep:128, batch:0114 -> curr_mean-loss:0.00585, mean_batch-loss:0.01055: : 114it [01:00,  1.88it/s]
# Training) ep:129, batch:0114 -> curr_mean-loss:0.00590, mean_batch-loss:0.01506: : 114it [01:00,  1.90it/s]
# Training) ep:130, batch:0114 -> curr_mean-loss:0.00581, mean_batch-loss:0.00908: : 114it [01:00,  1.89it/s]
# Training) ep:131, batch:0114 -> curr_mean-loss:0.00579, mean_batch-loss:0.01045: : 114it [01:00,  1.88it/s]
# Training) ep:132, batch:0114 -> curr_mean-loss:0.00577, mean_batch-loss:0.01234: : 114it [00:59,  1.91it/s]
# Training) ep:133, batch:0114 -> curr_mean-loss:0.00578, mean_batch-loss:0.01152: : 114it [01:00,  1.88it/s]
# Training) ep:134, batch:0114 -> curr_mean-loss:0.00578, mean_batch-loss:0.01653: : 114it [01:00,  1.88it/s]
# Training) ep:135, batch:0114 -> curr_mean-loss:0.00580, mean_batch-loss:0.01826: : 114it [00:59,  1.92it/s]
# Training) ep:136, batch:0114 -> curr_mean-loss:0.00574, mean_batch-loss:0.01401: : 114it [01:00,  1.88it/s]
# Training) ep:137, batch:0114 -> curr_mean-loss:0.00578, mean_batch-loss:0.01272: : 114it [01:00,  1.88it/s]
# Training) ep:138, batch:0114 -> curr_mean-loss:0.00577, mean_batch-loss:0.01666: : 114it [00:59,  1.91it/s]
# Training) ep:139, batch:0114 -> curr_mean-loss:0.00574, mean_batch-loss:0.01097: : 114it [01:00,  1.88it/s]
# Training) ep:140, batch:0114 -> curr_mean-loss:0.00577, mean_batch-loss:0.01308: : 114it [01:00,  1.88it/s]
# Training) ep:141, batch:0114 -> curr_mean-loss:0.00577, mean_batch-loss:0.01764: : 114it [01:00,  1.90it/s]
# Training) ep:142, batch:0114 -> curr_mean-loss:0.00572, mean_batch-loss:0.00950: : 114it [01:00,  1.88it/s]
# Training) ep:143, batch:0114 -> curr_mean-loss:0.00572, mean_batch-loss:0.01565: : 114it [01:00,  1.88it/s]
# Training) ep:144, batch:0114 -> curr_mean-loss:0.00572, mean_batch-loss:0.00981: : 114it [01:00,  1.89it/s]
# Training) ep:145, batch:0114 -> curr_mean-loss:0.00570, mean_batch-loss:0.01190: : 114it [01:00,  1.89it/s]
# Training) ep:146, batch:0114 -> curr_mean-loss:0.00570, mean_batch-loss:0.01133: : 114it [01:00,  1.87it/s]
# Training) ep:147, batch:0114 -> curr_mean-loss:0.00570, mean_batch-loss:0.01085: : 114it [01:00,  1.88it/s]
# Training) ep:148, batch:0114 -> curr_mean-loss:0.00575, mean_batch-loss:0.02348: : 114it [01:00,  1.88it/s]
# Training) ep:149, batch:0114 -> curr_mean-loss:0.00569, mean_batch-loss:0.01214: : 114it [01:00,  1.90it/s]
# Training) ep:150, batch:0114 -> curr_mean-loss:0.00570, mean_batch-loss:0.00873: : 114it [01:00,  1.88it/s]
# Training) ep:151, batch:0114 -> curr_mean-loss:0.00570, mean_batch-loss:0.01721: : 114it [01:00,  1.88it/s]
# Training) ep:152, batch:0114 -> curr_mean-loss:0.00571, mean_batch-loss:0.02043: : 114it [00:59,  1.90it/s]
# Training) ep:153, batch:0114 -> curr_mean-loss:0.00568, mean_batch-loss:0.00697: : 114it [01:00,  1.88it/s]
# Training) ep:154, batch:0114 -> curr_mean-loss:0.00568, mean_batch-loss:0.01270: : 114it [01:00,  1.87it/s]
# Training) ep:155, batch:0114 -> curr_mean-loss:0.00568, mean_batch-loss:0.00982: : 114it [00:59,  1.91it/s]
# Training) ep:156, batch:0114 -> curr_mean-loss:0.00570, mean_batch-loss:0.01415: : 114it [01:00,  1.89it/s]
# Training) ep:157, batch:0114 -> curr_mean-loss:0.00568, mean_batch-loss:0.01085: : 114it [01:00,  1.88it/s]
# Training) ep:158, batch:0114 -> curr_mean-loss:0.00569, mean_batch-loss:0.00845: : 114it [00:59,  1.91it/s]
# Training) ep:159, batch:0114 -> curr_mean-loss:0.00570, mean_batch-loss:0.01239: : 114it [01:00,  1.87it/s]
# Training) ep:160, batch:0114 -> curr_mean-loss:0.00570, mean_batch-loss:0.02296: : 114it [01:00,  1.87it/s]
# Training) ep:161, batch:0114 -> curr_mean-loss:0.00569, mean_batch-loss:0.02045: : 114it [00:59,  1.90it/s]
# Training) ep:162, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.00889: : 114it [01:00,  1.88it/s]
# Training) ep:163, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.01340: : 114it [01:00,  1.88it/s]
# Training) ep:164, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.01099: : 114it [00:59,  1.90it/s]
# Training) ep:165, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.00916: : 114it [01:00,  1.89it/s]
# Training) ep:166, batch:0114 -> curr_mean-loss:0.00567, mean_batch-loss:0.01242: : 114it [01:00,  1.89it/s]
# Training) ep:167, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.00974: : 114it [01:00,  1.88it/s]
# Training) ep:168, batch:0114 -> curr_mean-loss:0.00568, mean_batch-loss:0.01342: : 114it [01:00,  1.88it/s]
# Training) ep:169, batch:0114 -> curr_mean-loss:0.00568, mean_batch-loss:0.01737: : 114it [01:00,  1.89it/s]
# Training) ep:170, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.00628: : 114it [01:00,  1.88it/s]
# Training) ep:171, batch:0114 -> curr_mean-loss:0.00567, mean_batch-loss:0.01512: : 114it [01:00,  1.88it/s]
# Training) ep:172, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01223: : 114it [01:00,  1.89it/s]
# Training) ep:173, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.00896: : 114it [01:00,  1.88it/s]
# Training) ep:174, batch:0114 -> curr_mean-loss:0.00568, mean_batch-loss:0.01742: : 114it [01:00,  1.88it/s]
# Training) ep:175, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.01233: : 114it [01:00,  1.90it/s]
# Training) ep:176, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01166: : 114it [01:00,  1.88it/s]
# Training) ep:177, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.00833: : 114it [01:00,  1.88it/s]
# Training) ep:178, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00887: : 114it [00:59,  1.92it/s]
# Training) ep:179, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.00888: : 114it [01:00,  1.88it/s]
# Training) ep:180, batch:0114 -> curr_mean-loss:0.00567, mean_batch-loss:0.01172: : 114it [01:00,  1.89it/s]
# Training) ep:181, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01120: : 114it [00:59,  1.92it/s]
# Training) ep:182, batch:0114 -> curr_mean-loss:0.00567, mean_batch-loss:0.01785: : 114it [01:00,  1.87it/s]
# Training) ep:183, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.01634: : 114it [01:00,  1.89it/s]
# Training) ep:184, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00970: : 114it [01:00,  1.90it/s]
# Training) ep:185, batch:0114 -> curr_mean-loss:0.00567, mean_batch-loss:0.01319: : 114it [01:00,  1.88it/s]
# Training) ep:186, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01278: : 114it [01:00,  1.88it/s]
# Training) ep:187, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00470: : 114it [00:59,  1.90it/s]
# Training) ep:188, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.01177: : 114it [01:00,  1.88it/s]
# Training) ep:189, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01388: : 114it [01:00,  1.87it/s]
# Training) ep:190, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01561: : 114it [01:00,  1.88it/s]
# Training) ep:191, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00765: : 114it [01:00,  1.89it/s]
# Training) ep:192, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01236: : 114it [01:00,  1.90it/s]
# Training) ep:193, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.01164: : 114it [01:00,  1.88it/s]
# Training) ep:194, batch:0114 -> curr_mean-loss:0.00567, mean_batch-loss:0.02198: : 114it [01:00,  1.88it/s]
# Training) ep:195, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01708: : 114it [01:00,  1.90it/s]
# Training) ep:196, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01080: : 114it [00:56,  2.03it/s]
# Training) ep:197, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01255: : 114it [00:33,  3.39it/s]
# Training) ep:198, batch:0114 -> curr_mean-loss:0.00567, mean_batch-loss:0.01505: : 114it [00:29,  3.82it/s]
# Training) ep:199, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.00866: : 114it [00:29,  3.83it/s]
# Training) ep:200, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01817: : 114it [00:29,  3.83it/s]
# Training) ep:201, batch:0114 -> curr_mean-loss:0.00567, mean_batch-loss:0.01202: : 114it [00:29,  3.83it/s]
# Training) ep:202, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01089: : 114it [00:29,  3.83it/s]
# Training) ep:203, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.01513: : 114it [00:29,  3.84it/s]
# Training) ep:204, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.02198: : 114it [00:29,  3.83it/s]
# Training) ep:205, batch:0114 -> curr_mean-loss:0.00568, mean_batch-loss:0.02150: : 114it [00:29,  3.84it/s]
# Training) ep:206, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.00982: : 114it [00:29,  3.82it/s]
# Training) ep:207, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00907: : 114it [00:29,  3.83it/s]
# Training) ep:208, batch:0114 -> curr_mean-loss:0.00567, mean_batch-loss:0.02145: : 114it [00:29,  3.83it/s]
# Training) ep:209, batch:0114 -> curr_mean-loss:0.00567, mean_batch-loss:0.01642: : 114it [00:29,  3.84it/s]
# Training) ep:210, batch:0114 -> curr_mean-loss:0.00567, mean_batch-loss:0.01291: : 114it [00:29,  3.82it/s]
# Training) ep:211, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00843: : 114it [00:29,  3.82it/s]
# Training) ep:212, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01149: : 114it [00:29,  3.83it/s]
# Training) ep:213, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.00857: : 114it [00:29,  3.83it/s]
# Training) ep:214, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00668: : 114it [00:29,  3.83it/s]
# Training) ep:215, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.01160: : 114it [00:29,  3.82it/s]
# Training) ep:216, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.01459: : 114it [00:29,  3.83it/s]
# Training) ep:217, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.00983: : 114it [00:29,  3.83it/s]
# Training) ep:218, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.01206: : 114it [00:29,  3.82it/s]
# Training) ep:219, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01677: : 114it [00:29,  3.82it/s]
# Training) ep:220, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00943: : 114it [00:29,  3.81it/s]
# Training) ep:221, batch:0114 -> curr_mean-loss:0.00568, mean_batch-loss:0.01837: : 114it [00:29,  3.82it/s]
# Training) ep:222, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.01500: : 114it [00:29,  3.84it/s]
# Training) ep:223, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01712: : 114it [00:29,  3.83it/s]
# Training) ep:224, batch:0114 -> curr_mean-loss:0.00568, mean_batch-loss:0.02451: : 114it [00:29,  3.83it/s]
# Training) ep:225, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.00991: : 114it [00:29,  3.83it/s]
# Training) ep:226, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01383: : 114it [00:29,  3.83it/s]
# Training) ep:227, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00730: : 114it [00:29,  3.83it/s]
# Training) ep:228, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01054: : 114it [00:29,  3.82it/s]
# Training) ep:229, batch:0114 -> curr_mean-loss:0.00568, mean_batch-loss:0.01749: : 114it [00:29,  3.83it/s]
# Training) ep:230, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01102: : 114it [00:29,  3.83it/s]
# Training) ep:231, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.00946: : 114it [00:29,  3.82it/s]
# Training) ep:232, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01214: : 114it [00:29,  3.83it/s]
# Training) ep:233, batch:0114 -> curr_mean-loss:0.00567, mean_batch-loss:0.02463: : 114it [00:29,  3.83it/s]
# Training) ep:234, batch:0114 -> curr_mean-loss:0.00562, mean_batch-loss:0.00656: : 114it [00:29,  3.82it/s]
# Training) ep:235, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01252: : 114it [00:29,  3.82it/s]
# Training) ep:236, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01216: : 114it [00:29,  3.83it/s]
# Training) ep:237, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00998: : 114it [00:29,  3.83it/s]
# Training) ep:238, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01415: : 114it [00:29,  3.82it/s]
# Training) ep:239, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01145: : 114it [00:29,  3.84it/s]
# Training) ep:240, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.01000: : 114it [00:29,  3.82it/s]
# Training) ep:241, batch:0114 -> curr_mean-loss:0.00562, mean_batch-loss:0.01187: : 114it [00:29,  3.83it/s]
# Training) ep:242, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00962: : 114it [00:29,  3.83it/s]
# Training) ep:243, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.00959: : 114it [00:29,  3.84it/s]
# Training) ep:244, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00787: : 114it [00:29,  3.83it/s]
# Training) ep:245, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01057: : 114it [00:29,  3.83it/s]
# Training) ep:246, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00716: : 114it [00:29,  3.83it/s]
# Training) ep:247, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01185: : 114it [00:29,  3.83it/s]
# Training) ep:248, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01713: : 114it [00:29,  3.84it/s]
# Training) ep:249, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.01632: : 114it [00:29,  3.83it/s]
# Training) ep:250, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.00884: : 114it [00:29,  3.83it/s]
# Training) ep:251, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01664: : 114it [00:29,  3.82it/s]
# Training) ep:252, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.01371: : 114it [00:29,  3.84it/s]
# Training) ep:253, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01563: : 114it [00:29,  3.84it/s]
# Training) ep:254, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01203: : 114it [00:29,  3.83it/s]
# Training) ep:255, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01758: : 114it [00:29,  3.84it/s]
# Training) ep:256, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.01344: : 114it [00:29,  3.82it/s]
# Training) ep:257, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00720: : 114it [00:29,  3.83it/s]
# Training) ep:258, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.01283: : 114it [00:29,  3.83it/s]
# Training) ep:259, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.00931: : 114it [00:29,  3.83it/s]
# Training) ep:260, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.01721: : 114it [00:29,  3.83it/s]
# Training) ep:261, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.02197: : 114it [00:29,  3.83it/s]
# Training) ep:262, batch:0114 -> curr_mean-loss:0.00567, mean_batch-loss:0.01844: : 114it [00:29,  3.83it/s]
# Training) ep:263, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01309: : 114it [00:29,  3.83it/s]
# Training) ep:264, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01006: : 114it [00:29,  3.84it/s]
# Training) ep:265, batch:0114 -> curr_mean-loss:0.00562, mean_batch-loss:0.00474: : 114it [00:29,  3.82it/s]
# Training) ep:266, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01308: : 114it [00:29,  3.83it/s]
# Training) ep:267, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.00667: : 114it [00:29,  3.83it/s]
# Training) ep:268, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01635: : 114it [00:29,  3.83it/s]
# Training) ep:269, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.01260: : 114it [00:29,  3.83it/s]
# Training) ep:270, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.01718: : 114it [00:29,  3.83it/s]
# Training) ep:271, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01070: : 114it [00:29,  3.83it/s]
# Training) ep:272, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01230: : 114it [00:29,  3.84it/s]
# Training) ep:273, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.00880: : 114it [00:29,  3.82it/s]
# Training) ep:274, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.01114: : 114it [00:29,  3.83it/s]
# Training) ep:275, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.00876: : 114it [00:29,  3.82it/s]
# Training) ep:276, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01303: : 114it [00:29,  3.83it/s]
# Training) ep:277, batch:0114 -> curr_mean-loss:0.00570, mean_batch-loss:0.02479: : 114it [00:29,  3.83it/s]
# Training) ep:278, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00882: : 114it [00:29,  3.82it/s]
# Training) ep:279, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00861: : 114it [00:29,  3.83it/s]
# Training) ep:280, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.00751: : 114it [00:29,  3.82it/s]
# Training) ep:281, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01821: : 114it [00:29,  3.81it/s]
# Training) ep:282, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01166: : 114it [00:29,  3.83it/s]
# Training) ep:283, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01564: : 114it [00:29,  3.82it/s]
# Training) ep:284, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.01080: : 114it [00:29,  3.82it/s]
# Training) ep:285, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01144: : 114it [00:29,  3.84it/s]
# Training) ep:286, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01925: : 114it [00:29,  3.83it/s]
# Training) ep:287, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01373: : 114it [00:29,  3.82it/s]
# Training) ep:288, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01023: : 114it [00:29,  3.84it/s]
# Training) ep:289, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01552: : 114it [00:29,  3.83it/s]
# Training) ep:290, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01156: : 114it [00:29,  3.84it/s]
# Training) ep:291, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01344: : 114it [00:29,  3.83it/s]
# Training) ep:292, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01400: : 114it [00:29,  3.83it/s]
# Training) ep:293, batch:0114 -> curr_mean-loss:0.00564, mean_batch-loss:0.01317: : 114it [00:29,  3.82it/s]
# Training) ep:294, batch:0114 -> curr_mean-loss:0.00562, mean_batch-loss:0.00916: : 114it [00:29,  3.82it/s]
# Training) ep:295, batch:0114 -> curr_mean-loss:0.00562, mean_batch-loss:0.00743: : 114it [00:29,  3.83it/s]
# Training) ep:296, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.01742: : 114it [00:29,  3.83it/s]
# Training) ep:297, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.01844: : 114it [00:29,  3.82it/s]
# Training) ep:298, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01535: : 114it [00:29,  3.84it/s]
# Training) ep:299, batch:0114 -> curr_mean-loss:0.00567, mean_batch-loss:0.01670: : 114it [00:29,  3.82it/s]

# %%
te_metrics = test(best_model, te_dataloader)
te_metrics.compute()
# Out:
# 100%|██████████| 33/33 [00:02<00:00, 11.68it/s]
# {'test_metrics/F1Score': tensor(0.8657, device='cuda:0'),
#  'test_metrics/Accuracy': tensor(0.9453, device='cuda:0'),
#  'test_metrics/Dice': tensor(0.8657, device='cuda:0'),
#  'test_metrics/Precision': tensor(0.8964, device='cuda:0'),
#  'test_metrics/Specificity': tensor(0.9742, device='cuda:0'),
#  'test_metrics/Recall': tensor(0.8371, device='cuda:0'),
#  'test_metrics/JaccardIndex': tensor(0.8484, device='cuda:0')}

# %%
f"{config['model']['save_dir']}"
# Out:
# '../saved_models/isic2018_missformer'

# %% [markdown]
# # Test the best inferred model
# ----

# %% [markdown]
# ## Load the best model

# %%
best_model = Net(**config['model']['params'])
torch.cuda.empty_cache()
best_model = best_model.to(device)

fn = "best_model_state_dict.pt"
os.makedirs(config['model']['save_dir'], exist_ok=True)
model_path = f"{config['model']['save_dir']}/{fn}"

best_model.load_state_dict(torch.load(model_path))
print("Loaded best model weights...")
# Out:
# Loaded best model weights...

# %% [markdown]
# ## Evaluation

# %%
te_metrics = test(best_model, te_dataloader)
te_metrics.compute()
# Out:
# 100%|██████████| 33/33 [00:02<00:00, 11.67it/s]
# {'test_metrics/F1Score': tensor(0.8657, device='cuda:0'),
#  'test_metrics/Accuracy': tensor(0.9453, device='cuda:0'),
#  'test_metrics/Dice': tensor(0.8657, device='cuda:0'),
#  'test_metrics/Precision': tensor(0.8964, device='cuda:0'),
#  'test_metrics/Specificity': tensor(0.9742, device='cuda:0'),
#  'test_metrics/Recall': tensor(0.8371, device='cuda:0'),
#  'test_metrics/JaccardIndex': tensor(0.8484, device='cuda:0')}

# %% [markdown]
# ## Plot graphs

# %%
result_file_path = f"{config['model']['save_dir']}/result.json"
with open(result_file_path, 'r') as f:
    results = json.loads(''.join(f.readlines()))
epochs_info = results['epochs_info']

tr_losses = [d['tr_loss'] for d in epochs_info]
vl_losses = [d['vl_loss'] for d in epochs_info]
tr_dice = [d['tr_metrics']['train_metrics/Dice'] for d in epochs_info]
vl_dice = [d['vl_metrics']['valid_metrics/Dice'] for d in epochs_info]
tr_js = [d['tr_metrics']['train_metrics/JaccardIndex'] for d in epochs_info]
vl_js = [d['vl_metrics']['valid_metrics/JaccardIndex'] for d in epochs_info]
tr_acc = [d['tr_metrics']['train_metrics/Accuracy'] for d in epochs_info]
vl_acc = [d['vl_metrics']['valid_metrics/Accuracy'] for d in epochs_info]


_, axs = plt.subplots(1, 4, figsize=[16,3])

axs[0].set_title("Loss")
axs[0].plot(tr_losses, 'r-', label="train loss")
axs[0].plot(vl_losses, 'b-', label="validatiton loss")
axs[0].legend()

axs[1].set_title("Dice score")
axs[1].plot(tr_dice, 'r-', label="train dice")
axs[1].plot(vl_dice, 'b-', label="validation dice")
axs[1].legend()

axs[2].set_title("Jaccard Similarity")
axs[2].plot(tr_js, 'r-', label="train JaccardIndex")
axs[2].plot(vl_js, 'b-', label="validatiton JaccardIndex")
axs[2].legend()

axs[3].set_title("Accuracy")
axs[3].plot(tr_acc, 'r-', label="train Accuracy")
axs[3].plot(vl_acc, 'b-', label="validation Accuracy")
axs[3].legend()

plt.show()

# %%
epochs_info
# Out:
# [{'tr_loss': 0.03352450004293899,
#   'vl_loss': 0.032482477919015186,
#   'tr_metrics': {'train_metrics/F1Score': 0.08500541746616364,
#    'train_metrics/Accuracy': 0.7621284127235413,
#    'train_metrics/Dice': 0.08500541746616364,
#    'train_metrics/Precision': 0.26696792244911194,
#    'train_metrics/Specificity': 0.9611741304397583,
#    'train_metrics/Recall': 0.050550635904073715,
#    'train_metrics/JaccardIndex': 0.401930034160614},
#   'vl_metrics': {'valid_metrics/F1Score': 0.04924056679010391,
#    'valid_metrics/Accuracy': 0.8080562353134155,
#    'valid_metrics/Dice': 0.04924057051539421,
#    'valid_metrics/Precision': 0.376349538564682,
#    'valid_metrics/Specificity': 0.9898479580879211,
#    'valid_metrics/Recall': 0.026343651115894318,
#    'valid_metrics/JaccardIndex': 0.41616958379745483}},
#  {'tr_loss': 0.03128287560683637,
#   'vl_loss': 0.03134331049606146,
#   'tr_metrics': {'train_metrics/F1Score': 0.09441855549812317,
#    'train_metrics/Accuracy': 0.7827290296554565,
#    'train_metrics/Dice': 0.09441856294870377,
#    'train_metrics/Precision': 0.5307081937789917,
#    'train_metrics/Specificity': 0.9871824979782104,
#    'train_metrics/Recall': 0.051818836480379105,
#    'train_metrics/JaccardIndex': 0.414894163608551},
#   'vl_metrics': {'valid_metrics/F1Score': 0.0786411240696907,
#    'valid_metrics/Accuracy': 0.810945987701416,
#    'valid_metrics/Dice': 0.0786411315202713,
#    'valid_metrics/Precision': 0.48860400915145874,
#    'valid_metrics/Specificity': 0.9895915985107422,
#    'valid_metrics/Recall': 0.04276183620095253,
#    'valid_metrics/JaccardIndex': 0.4251691401004791}},
#  {'tr_loss': 0.0298978240857768,
#   'vl_loss': 0.029677335129741536,
#   'tr_metrics': {'train_metrics/F1Score': 0.222602978348732,
#    'train_metrics/Accuracy': 0.7908003330230713,
#    'train_metrics/Dice': 0.222602978348732,
#    'train_metrics/Precision': 0.5928531885147095,
#    'train_metrics/Specificity': 0.9736768007278442,
#    'train_metrics/Recall': 0.13702669739723206,
#    'train_metrics/JaccardIndex': 0.45479100942611694},
#   'vl_metrics': {'valid_metrics/F1Score': 0.2481333613395691,
#    'valid_metrics/Accuracy': 0.8184577822685242,
#    'valid_metrics/Dice': 0.2481333613395691,
#    'valid_metrics/Precision': 0.5675988793373108,
#    'valid_metrics/Specificity': 0.9718716740608215,
#    'valid_metrics/Recall': 0.15877112746238708,
#    'valid_metrics/JaccardIndex': 0.4772454500198364}},
#  {'tr_loss': 0.027467320477666934,
#   'vl_loss': 0.026371989931379045,
#   'tr_metrics': {'train_metrics/F1Score': 0.3863036036491394,
#    'train_metrics/Accuracy': 0.8079246878623962,
#    'train_metrics/Dice': 0.3863036036491394,
#    'train_metrics/Precision': 0.6403954029083252,
#    'train_metrics/Specificity': 0.9565579295158386,
#    'train_metrics/Recall': 0.27656856179237366,
#    'train_metrics/JaccardIndex': 0.5174782872200012},
#   'vl_metrics': {'valid_metrics/F1Score': 0.42418619990348816,
#    'valid_metrics/Accuracy': 0.8409879803657532,
#    'valid_metrics/Dice': 0.42418622970581055,
#    'valid_metrics/Precision': 0.6695678234100342,
#    'valid_metrics/Specificity': 0.9643738865852356,
#    'valid_metrics/Recall': 0.3104231059551239,
#    'valid_metrics/JaccardIndex': 0.550140380859375}},
#  {'tr_loss': 0.023555361846918574,
#   'vl_loss': 0.023112697490854154,
#   'tr_metrics': {'train_metrics/F1Score': 0.5534476637840271,
#    'train_metrics/Accuracy': 0.8419463038444519,
#    'train_metrics/Dice': 0.5534476637840271,
#    'train_metrics/Precision': 0.7235807180404663,
#    'train_metrics/Specificity': 0.9521174430847168,
#    'train_metrics/Recall': 0.4480898380279541,
#    'train_metrics/JaccardIndex': 0.6036913394927979},
#   'vl_metrics': {'valid_metrics/F1Score': 0.5337177515029907,
#    'valid_metrics/Accuracy': 0.8630953431129456,
#    'valid_metrics/Dice': 0.533717691898346,
#    'valid_metrics/Precision': 0.7466992735862732,
#    'valid_metrics/Specificity': 0.9672396779060364,
#    'valid_metrics/Recall': 0.41526997089385986,
#    'valid_metrics/JaccardIndex': 0.6077252626419067}},
#  {'tr_loss': 0.020263627672326794,
#   'vl_loss': 0.01827856817760983,
#   'tr_metrics': {'train_metrics/F1Score': 0.652195394039154,
#    'train_metrics/Accuracy': 0.8683553338050842,
#    'train_metrics/Dice': 0.6521953344345093,
#    'train_metrics/Precision': 0.7718141674995422,
#    'train_metrics/Specificity': 0.9533010125160217,
#    'train_metrics/Recall': 0.5646791458129883,
#    'train_metrics/JaccardIndex': 0.6668566465377808},
#   'vl_metrics': {'valid_metrics/F1Score': 0.6964156627655029,
#    'valid_metrics/Accuracy': 0.8946164846420288,
#    'valid_metrics/Dice': 0.6964156627655029,
#    'valid_metrics/Precision': 0.7628351449966431,
#    'valid_metrics/Specificity': 0.9536811113357544,
#    'valid_metrics/Recall': 0.6406359672546387,
#    'valid_metrics/JaccardIndex': 0.7071791887283325}},
#  {'tr_loss': 0.016715676405213094,
#   'vl_loss': 0.015776474906210734,
#   'tr_metrics': {'train_metrics/F1Score': 0.738452136516571,
#    'train_metrics/Accuracy': 0.8951969742774963,
#    'train_metrics/Dice': 0.7384520769119263,
#    'train_metrics/Precision': 0.8123708963394165,
#    'train_metrics/Specificity': 0.9562702775001526,
#    'train_metrics/Recall': 0.6768633723258972,
#    'train_metrics/JaccardIndex': 0.731176495552063},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7362970113754272,
#    'valid_metrics/Accuracy': 0.9072971940040588,
#    'valid_metrics/Dice': 0.7362969517707825,
#    'valid_metrics/Precision': 0.7946457266807556,
#    'valid_metrics/Specificity': 0.9587771892547607,
#    'valid_metrics/Recall': 0.6859308481216431,
#    'valid_metrics/JaccardIndex': 0.7380831837654114}},
#  {'tr_loss': 0.015249868874379098,
#   'vl_loss': 0.015054109531479913,
#   'tr_metrics': {'train_metrics/F1Score': 0.7638232707977295,
#    'train_metrics/Accuracy': 0.9043185710906982,
#    'train_metrics/Dice': 0.7638232707977295,
#    'train_metrics/Precision': 0.829412579536438,
#    'train_metrics/Specificity': 0.9592764377593994,
#    'train_metrics/Recall': 0.7078472375869751,
#    'train_metrics/JaccardIndex': 0.7523481845855713},
#   'vl_metrics': {'valid_metrics/F1Score': 0.753406286239624,
#    'valid_metrics/Accuracy': 0.9084754586219788,
#    'valid_metrics/Dice': 0.753406286239624,
#    'valid_metrics/Precision': 0.7662054896354675,
#    'valid_metrics/Specificity': 0.947416365146637,
#    'valid_metrics/Recall': 0.7410276532173157,
#    'valid_metrics/JaccardIndex': 0.7489854693412781}},
#  {'tr_loss': 0.014302283862077173,
#   'vl_loss': 0.014640339380525714,
#   'tr_metrics': {'train_metrics/F1Score': 0.7776689529418945,
#    'train_metrics/Accuracy': 0.9090006947517395,
#    'train_metrics/Dice': 0.7776691317558289,
#    'train_metrics/Precision': 0.8344846963882446,
#    'train_metrics/Specificity': 0.9596039056777954,
#    'train_metrics/Recall': 0.7280967235565186,
#    'train_metrics/JaccardIndex': 0.7639976739883423},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7573546171188354,
#    'valid_metrics/Accuracy': 0.9107664823532104,
#    'valid_metrics/Dice': 0.7573546171188354,
#    'valid_metrics/Precision': 0.7776600122451782,
#    'valid_metrics/Specificity': 0.9509250521659851,
#    'valid_metrics/Recall': 0.7380826473236084,
#    'valid_metrics/JaccardIndex': 0.7528994679450989}},
#  {'tr_loss': 0.013652139245314375,
#   'vl_loss': 0.014139351956402472,
#   'tr_metrics': {'train_metrics/F1Score': 0.7877245545387268,
#    'train_metrics/Accuracy': 0.9127312898635864,
#    'train_metrics/Dice': 0.787724494934082,
#    'train_metrics/Precision': 0.8410220742225647,
#    'train_metrics/Specificity': 0.9608303904533386,
#    'train_metrics/Recall': 0.7407795786857605,
#    'train_metrics/JaccardIndex': 0.7728303074836731},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7632216215133667,
#    'valid_metrics/Accuracy': 0.9150577783584595,
#    'valid_metrics/Dice': 0.7632216215133667,
#    'valid_metrics/Precision': 0.8049893975257874,
#    'valid_metrics/Specificity': 0.9591231942176819,
#    'valid_metrics/Recall': 0.7255743741989136,
#    'valid_metrics/JaccardIndex': 0.7593446969985962}},
#  {'tr_loss': 0.01324726931401849,
#   'vl_loss': 0.014697153279449949,
#   'tr_metrics': {'train_metrics/F1Score': 0.793739914894104,
#    'train_metrics/Accuracy': 0.9152039289474487,
#    'train_metrics/Dice': 0.7937400341033936,
#    'train_metrics/Precision': 0.847440242767334,
#    'train_metrics/Specificity': 0.9624114036560059,
#    'train_metrics/Recall': 0.7464398145675659,
#    'train_metrics/JaccardIndex': 0.7783443927764893},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7668257355690002,
#    'valid_metrics/Accuracy': 0.9088295698165894,
#    'valid_metrics/Dice': 0.766825795173645,
#    'valid_metrics/Precision': 0.7409734129905701,
#    'valid_metrics/Specificity': 0.9354065656661987,
#    'valid_metrics/Recall': 0.7945473194122314,
#    'valid_metrics/JaccardIndex': 0.7572912573814392}},
#  {'tr_loss': 0.013121380741110189,
#   'vl_loss': 0.013777614646666759,
#   'tr_metrics': {'train_metrics/F1Score': 0.7950282692909241,
#    'train_metrics/Accuracy': 0.9154155850410461,
#    'train_metrics/Dice': 0.7950282692909241,
#    'train_metrics/Precision': 0.845208466053009,
#    'train_metrics/Specificity': 0.961554229259491,
#    'train_metrics/Recall': 0.7504724860191345,
#    'train_metrics/JaccardIndex': 0.779303789138794},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7673484683036804,
#    'valid_metrics/Accuracy': 0.9155253767967224,
#    'valid_metrics/Dice': 0.7673485279083252,
#    'valid_metrics/Precision': 0.798717200756073,
#    'valid_metrics/Specificity': 0.9567283987998962,
#    'valid_metrics/Recall': 0.7383506298065186,
#    'valid_metrics/JaccardIndex': 0.7621855139732361}},
#  {'tr_loss': 0.012681834572110294,
#   'vl_loss': 0.01361058171996739,
#   'tr_metrics': {'train_metrics/F1Score': 0.804375410079956,
#    'train_metrics/Accuracy': 0.9190223217010498,
#    'train_metrics/Dice': 0.8043754696846008,
#    'train_metrics/Precision': 0.8521761298179626,
#    'train_metrics/Specificity': 0.9630425572395325,
#    'train_metrics/Recall': 0.7616524696350098,
#    'train_metrics/JaccardIndex': 0.787807047367096},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7714337110519409,
#    'valid_metrics/Accuracy': 0.9160688519477844,
#    'valid_metrics/Dice': 0.7714337706565857,
#    'valid_metrics/Precision': 0.7933592200279236,
#    'valid_metrics/Specificity': 0.9545292258262634,
#    'valid_metrics/Recall': 0.7506875991821289,
#    'valid_metrics/JaccardIndex': 0.7650666236877441}},
#  {'tr_loss': 0.012401520015451205,
#   'vl_loss': 0.013226384476805285,
#   'tr_metrics': {'train_metrics/F1Score': 0.8074339032173157,
#    'train_metrics/Accuracy': 0.9200683832168579,
#    'train_metrics/Dice': 0.8074339628219604,
#    'train_metrics/Precision': 0.8527904152870178,
#    'train_metrics/Specificity': 0.9629809260368347,
#    'train_metrics/Recall': 0.7666584849357605,
#    'train_metrics/JaccardIndex': 0.7905166149139404},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7782254815101624,
#    'valid_metrics/Accuracy': 0.9179591536521912,
#    'valid_metrics/Dice': 0.7782254219055176,
#    'valid_metrics/Precision': 0.7941679358482361,
#    'valid_metrics/Specificity': 0.9540165662765503,
#    'valid_metrics/Recall': 0.7629104256629944,
#    'valid_metrics/JaccardIndex': 0.7705636620521545}},
#  {'tr_loss': 0.012197573704660432,
#   'vl_loss': 0.013344148296186823,
#   'tr_metrics': {'train_metrics/F1Score': 0.8106772899627686,
#    'train_metrics/Accuracy': 0.9213186502456665,
#    'train_metrics/Dice': 0.8106772899627686,
#    'train_metrics/Precision': 0.8550556898117065,
#    'train_metrics/Specificity': 0.9634564518928528,
#    'train_metrics/Recall': 0.7706781625747681,
#    'train_metrics/JaccardIndex': 0.7935043573379517},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7757186889648438,
#    'valid_metrics/Accuracy': 0.9170476198196411,
#    'valid_metrics/Dice': 0.7757186889648438,
#    'valid_metrics/Precision': 0.7917665839195251,
#    'valid_metrics/Specificity': 0.9534981846809387,
#    'valid_metrics/Recall': 0.7603084444999695,
#    'valid_metrics/JaccardIndex': 0.7683831453323364}},
#  {'tr_loss': 0.01225096041505987,
#   'vl_loss': 0.013112822094479122,
#   'tr_metrics': {'train_metrics/F1Score': 0.8089136481285095,
#    'train_metrics/Accuracy': 0.9205976724624634,
#    'train_metrics/Dice': 0.8089136481285095,
#    'train_metrics/Precision': 0.8533374071121216,
#    'train_metrics/Specificity': 0.963034987449646,
#    'train_metrics/Recall': 0.7688862681388855,
#    'train_metrics/JaccardIndex': 0.7918481826782227},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7743156552314758,
#    'valid_metrics/Accuracy': 0.9192251563072205,
#    'valid_metrics/Dice': 0.7743156552314758,
#    'valid_metrics/Precision': 0.8187994956970215,
#    'valid_metrics/Specificity': 0.9622035622596741,
#    'valid_metrics/Recall': 0.7344162464141846,
#    'valid_metrics/JaccardIndex': 0.768986701965332}},
#  {'tr_loss': 0.011864546938868594,
#   'vl_loss': 0.01282395891356192,
#   'tr_metrics': {'train_metrics/F1Score': 0.8144815564155579,
#    'train_metrics/Accuracy': 0.9227549433708191,
#    'train_metrics/Dice': 0.8144815564155579,
#    'train_metrics/Precision': 0.8572861552238464,
#    'train_metrics/Specificity': 0.9638763070106506,
#    'train_metrics/Recall': 0.775748074054718,
#    'train_metrics/JaccardIndex': 0.7970040440559387},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7816001772880554,
#    'valid_metrics/Accuracy': 0.9215991497039795,
#    'valid_metrics/Dice': 0.7816001176834106,
#    'valid_metrics/Precision': 0.8237704634666443,
#    'valid_metrics/Specificity': 0.963008463382721,
#    'valid_metrics/Recall': 0.7435370683670044,
#    'valid_metrics/JaccardIndex': 0.7751513719558716}},
#  {'tr_loss': 0.011823725794793488,
#   'vl_loss': 0.012955897045411658,
#   'tr_metrics': {'train_metrics/F1Score': 0.8152968883514404,
#    'train_metrics/Accuracy': 0.9230286478996277,
#    'train_metrics/Dice': 0.8152969479560852,
#    'train_metrics/Precision': 0.8573340773582458,
#    'train_metrics/Specificity': 0.9638234972953796,
#    'train_metrics/Recall': 0.7771894931793213,
#    'train_metrics/JaccardIndex': 0.797731876373291},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7771246433258057,
#    'valid_metrics/Accuracy': 0.919634997844696,
#    'valid_metrics/Dice': 0.7771246433258057,
#    'valid_metrics/Precision': 0.8150362968444824,
#    'valid_metrics/Specificity': 0.9608094096183777,
#    'valid_metrics/Recall': 0.7425830960273743,
#    'valid_metrics/JaccardIndex': 0.7710150480270386}},
#  {'tr_loss': 0.01153411077073783,
#   'vl_loss': 0.012884409357452024,
#   'tr_metrics': {'train_metrics/F1Score': 0.8187295794487,
#    'train_metrics/Accuracy': 0.9246002435684204,
#    'train_metrics/Dice': 0.8187295794487,
#    'train_metrics/Precision': 0.862724244594574,
#    'train_metrics/Specificity': 0.9653269648551941,
#    'train_metrics/Recall': 0.7790042161941528,
#    'train_metrics/JaccardIndex': 0.8011095523834229},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7795121669769287,
#    'valid_metrics/Accuracy': 0.9200138449668884,
#    'valid_metrics/Dice': 0.7795121073722839,
#    'valid_metrics/Precision': 0.8121678829193115,
#    'valid_metrics/Specificity': 0.9596954584121704,
#    'valid_metrics/Recall': 0.749380886554718,
#    'valid_metrics/JaccardIndex': 0.7727655172348022}},
#  {'tr_loss': 0.011524537751661516,
#   'vl_loss': 0.01270520715869992,
#   'tr_metrics': {'train_metrics/F1Score': 0.8183763027191162,
#    'train_metrics/Accuracy': 0.9242333769798279,
#    'train_metrics/Dice': 0.8183762431144714,
#    'train_metrics/Precision': 0.8595900535583496,
#    'train_metrics/Specificity': 0.964317798614502,
#    'train_metrics/Recall': 0.780933678150177,
#    'train_metrics/JaccardIndex': 0.8006120920181274},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7838746309280396,
#    'valid_metrics/Accuracy': 0.9199705719947815,
#    'valid_metrics/Dice': 0.7838745713233948,
#    'valid_metrics/Precision': 0.7991186380386353,
#    'valid_metrics/Specificity': 0.9550328254699707,
#    'valid_metrics/Recall': 0.7692012190818787,
#    'valid_metrics/JaccardIndex': 0.7754756212234497}},
#  {'tr_loss': 0.011656602695789548,
#   'vl_loss': 0.012643267663059087,
#   'tr_metrics': {'train_metrics/F1Score': 0.8173052668571472,
#    'train_metrics/Accuracy': 0.9238584637641907,
#    'train_metrics/Dice': 0.8173052668571472,
#    'train_metrics/Precision': 0.8593577742576599,
#    'train_metrics/Specificity': 0.9643296003341675,
#    'train_metrics/Recall': 0.7791763544082642,
#    'train_metrics/JaccardIndex': 0.799640953540802},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7851155400276184,
#    'valid_metrics/Accuracy': 0.9203369617462158,
#    'valid_metrics/Dice': 0.7851155996322632,
#    'valid_metrics/Precision': 0.7994123697280884,
#    'valid_metrics/Specificity': 0.9549914002418518,
#    'valid_metrics/Recall': 0.771321177482605,
#    'valid_metrics/JaccardIndex': 0.7765080332756042}},
#  {'tr_loss': 0.011315924832315156,
#   'vl_loss': 0.012291799928690936,
#   'tr_metrics': {'train_metrics/F1Score': 0.8227073550224304,
#    'train_metrics/Accuracy': 0.9256487488746643,
#    'train_metrics/Dice': 0.8227074146270752,
#    'train_metrics/Precision': 0.859159529209137,
#    'train_metrics/Specificity': 0.9638104438781738,
#    'train_metrics/Recall': 0.7892225384712219,
#    'train_metrics/JaccardIndex': 0.804480791091919},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7868139147758484,
#    'valid_metrics/Accuracy': 0.9233555197715759,
#    'valid_metrics/Dice': 0.7868139147758484,
#    'valid_metrics/Precision': 0.8278860449790955,
#    'valid_metrics/Specificity': 0.9637576341629028,
#    'valid_metrics/Recall': 0.7496243715286255,
#    'valid_metrics/JaccardIndex': 0.7796404957771301}},
#  {'tr_loss': 0.01144953795783119,
#   'vl_loss': 0.012437280368160558,
#   'tr_metrics': {'train_metrics/F1Score': 0.8200366497039795,
#    'train_metrics/Accuracy': 0.9248248338699341,
#    'train_metrics/Dice': 0.8200366497039795,
#    'train_metrics/Precision': 0.8600596189498901,
#    'train_metrics/Specificity': 0.9643364548683167,
#    'train_metrics/Recall': 0.7835729122161865,
#    'train_metrics/JaccardIndex': 0.8021280765533447},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7814119458198547,
#    'valid_metrics/Accuracy': 0.9236435890197754,
#    'valid_metrics/Dice': 0.7814120054244995,
#    'valid_metrics/Precision': 0.8496078848838806,
#    'valid_metrics/Specificity': 0.9702228903770447,
#    'valid_metrics/Recall': 0.723350465297699,
#    'valid_metrics/JaccardIndex': 0.7764096260070801}},
#  {'tr_loss': 0.011208689496044285,
#   'vl_loss': 0.012483232068509209,
#   'tr_metrics': {'train_metrics/F1Score': 0.823874831199646,
#    'train_metrics/Accuracy': 0.9264779686927795,
#    'train_metrics/Dice': 0.823874831199646,
#    'train_metrics/Precision': 0.8647279143333435,
#    'train_metrics/Specificity': 0.965575098991394,
#    'train_metrics/Recall': 0.7867077589035034,
#    'train_metrics/JaccardIndex': 0.8058544397354126},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7882266640663147,
#    'valid_metrics/Accuracy': 0.9203293919563293,
#    'valid_metrics/Dice': 0.7882267236709595,
#    'valid_metrics/Precision': 0.7906398177146912,
#    'valid_metrics/Specificity': 0.951608419418335,
#    'valid_metrics/Recall': 0.7858282327651978,
#    'valid_metrics/JaccardIndex': 0.778467059135437}},
#  {'tr_loss': 0.011146280887862538,
#   'vl_loss': 0.012298261250538255,
#   'tr_metrics': {'train_metrics/F1Score': 0.8246318697929382,
#    'train_metrics/Accuracy': 0.9263929724693298,
#    'train_metrics/Dice': 0.8246318697929382,
#    'train_metrics/Precision': 0.8603705167770386,
#    'train_metrics/Specificity': 0.9640576839447021,
#    'train_metrics/Recall': 0.7917438745498657,
#    'train_metrics/JaccardIndex': 0.8062915802001953},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7912219166755676,
#    'valid_metrics/Accuracy': 0.9222140312194824,
#    'valid_metrics/Dice': 0.7912218570709229,
#    'valid_metrics/Precision': 0.801500678062439,
#    'valid_metrics/Specificity': 0.9550068378448486,
#    'valid_metrics/Recall': 0.7812033891677856,
#    'valid_metrics/JaccardIndex': 0.7816649675369263}},
#  {'tr_loss': 0.011009248261937754,
#   'vl_loss': 0.012077652550802268,
#   'tr_metrics': {'train_metrics/F1Score': 0.8270814418792725,
#    'train_metrics/Accuracy': 0.9276079535484314,
#    'train_metrics/Dice': 0.8270814418792725,
#    'train_metrics/Precision': 0.8653520345687866,
#    'train_metrics/Specificity': 0.9655260443687439,
#    'train_metrics/Recall': 0.7920525670051575,
#    'train_metrics/JaccardIndex': 0.8087995052337646},
#   'vl_metrics': {'valid_metrics/F1Score': 0.789260745048523,
#    'valid_metrics/Accuracy': 0.9252296090126038,
#    'valid_metrics/Dice': 0.7892606854438782,
#    'valid_metrics/Precision': 0.8428404331207275,
#    'valid_metrics/Specificity': 0.9678207039833069,
#    'valid_metrics/Recall': 0.7420859932899475,
#    'valid_metrics/JaccardIndex': 0.7824696898460388}},
#  {'tr_loss': 0.011125647282797442,
#   'vl_loss': 0.012013356082687967,
#   'tr_metrics': {'train_metrics/F1Score': 0.8244098424911499,
#    'train_metrics/Accuracy': 0.9265302419662476,
#    'train_metrics/Dice': 0.8244099617004395,
#    'train_metrics/Precision': 0.8630809187889099,
#    'train_metrics/Specificity': 0.9649853110313416,
#    'train_metrics/Recall': 0.7890555262565613,
#    'train_metrics/JaccardIndex': 0.8062454462051392},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7910730838775635,
#    'valid_metrics/Accuracy': 0.9247591495513916,
#    'valid_metrics/Dice': 0.791073203086853,
#    'valid_metrics/Precision': 0.8308107852935791,
#    'valid_metrics/Specificity': 0.9642460942268372,
#    'valid_metrics/Recall': 0.7549633383750916,
#    'valid_metrics/JaccardIndex': 0.7833105325698853}},
#  {'tr_loss': 0.010811546141122655,
#   'vl_loss': 0.011867674420008788,
#   'tr_metrics': {'train_metrics/F1Score': 0.8288829326629639,
#    'train_metrics/Accuracy': 0.9281826019287109,
#    'train_metrics/Dice': 0.8288829922676086,
#    'train_metrics/Precision': 0.8648759126663208,
#    'train_metrics/Specificity': 0.9652228951454163,
#    'train_metrics/Recall': 0.7957659959793091,
#    'train_metrics/JaccardIndex': 0.8104158639907837},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7954127192497253,
#    'valid_metrics/Accuracy': 0.9253866672515869,
#    'valid_metrics/Dice': 0.7954127192497253,
#    'valid_metrics/Precision': 0.8240019083023071,
#    'valid_metrics/Specificity': 0.9618155360221863,
#    'valid_metrics/Recall': 0.7687408328056335,
#    'valid_metrics/JaccardIndex': 0.7865240573883057}},
#  {'tr_loss': 0.010576291447992823,
#   'vl_loss': 0.011523894160180478,
#   'tr_metrics': {'train_metrics/F1Score': 0.8333585858345032,
#    'train_metrics/Accuracy': 0.9300752282142639,
#    'train_metrics/Dice': 0.8333585858345032,
#    'train_metrics/Precision': 0.8697373867034912,
#    'train_metrics/Specificity': 0.9664881229400635,
#    'train_metrics/Recall': 0.7999008893966675,
#    'train_metrics/JaccardIndex': 0.8147907257080078},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8009998202323914,
#    'valid_metrics/Accuracy': 0.9268355369567871,
#    'valid_metrics/Dice': 0.8009998202323914,
#    'valid_metrics/Precision': 0.8226935863494873,
#    'valid_metrics/Specificity': 0.9608851075172424,
#    'valid_metrics/Recall': 0.7804207801818848,
#    'valid_metrics/JaccardIndex': 0.7911292314529419}},
#  {'tr_loss': 0.010853729686461205,
#   'vl_loss': 0.011814890163285392,
#   'tr_metrics': {'train_metrics/F1Score': 0.8277576565742493,
#    'train_metrics/Accuracy': 0.9279252290725708,
#    'train_metrics/Dice': 0.8277575969696045,
#    'train_metrics/Precision': 0.8665103316307068,
#    'train_metrics/Specificity': 0.965856671333313,
#    'train_metrics/Recall': 0.7923227548599243,
#    'train_metrics/JaccardIndex': 0.8094800114631653},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7968035340309143,
#    'valid_metrics/Accuracy': 0.9245938658714294,
#    'valid_metrics/Dice': 0.7968035936355591,
#    'valid_metrics/Precision': 0.8104651570320129,
#    'valid_metrics/Specificity': 0.957383930683136,
#    'valid_metrics/Recall': 0.7835949659347534,
#    'valid_metrics/JaccardIndex': 0.7868750095367432}},
#  {'tr_loss': 0.010381210958662112,
#   'vl_loss': 0.01163538605780215,
#   'tr_metrics': {'train_metrics/F1Score': 0.8352322578430176,
#    'train_metrics/Accuracy': 0.93067866563797,
#    'train_metrics/Dice': 0.8352322578430176,
#    'train_metrics/Precision': 0.8692012429237366,
#    'train_metrics/Specificity': 0.9661645889282227,
#    'train_metrics/Recall': 0.8038184642791748,
#    'train_metrics/JaccardIndex': 0.8164916634559631},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7940294146537781,
#    'valid_metrics/Accuracy': 0.926595151424408,
#    'valid_metrics/Dice': 0.7940294146537781,
#    'valid_metrics/Precision': 0.8436720967292786,
#    'valid_metrics/Specificity': 0.9676856398582458,
#    'valid_metrics/Recall': 0.7499041557312012,
#    'valid_metrics/JaccardIndex': 0.7864563465118408}},
#  {'tr_loss': 0.010367723055614913,
#   'vl_loss': 0.011893545050878782,
#   'tr_metrics': {'train_metrics/F1Score': 0.8359472751617432,
#    'train_metrics/Accuracy': 0.9310917258262634,
#    'train_metrics/Dice': 0.8359473347663879,
#    'train_metrics/Precision': 0.8714790940284729,
#    'train_metrics/Specificity': 0.9668663144111633,
#    'train_metrics/Recall': 0.8031993508338928,
#    'train_metrics/JaccardIndex': 0.8172764778137207},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7988797426223755,
#    'valid_metrics/Accuracy': 0.9224799871444702,
#    'valid_metrics/Dice': 0.7988798022270203,
#    'valid_metrics/Precision': 0.782464861869812,
#    'valid_metrics/Specificity': 0.9472429156303406,
#    'valid_metrics/Recall': 0.8159981966018677,
#    'valid_metrics/JaccardIndex': 0.7867426872253418}},
#  {'tr_loss': 0.01051461917884422,
#   'vl_loss': 0.011410197955070775,
#   'tr_metrics': {'train_metrics/F1Score': 0.833766520023346,
#    'train_metrics/Accuracy': 0.9302594661712646,
#    'train_metrics/Dice': 0.8337665796279907,
#    'train_metrics/Precision': 0.8703401684761047,
#    'train_metrics/Specificity': 0.9666562080383301,
#    'train_metrics/Recall': 0.8001428842544556,
#    'train_metrics/JaccardIndex': 0.815199613571167},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8003023266792297,
#    'valid_metrics/Accuracy': 0.9280133247375488,
#    'valid_metrics/Dice': 0.800302267074585,
#    'valid_metrics/Precision': 0.8396115899085999,
#    'valid_metrics/Specificity': 0.9660371541976929,
#    'valid_metrics/Recall': 0.7645091414451599,
#    'valid_metrics/JaccardIndex': 0.7914829254150391}},
#  {'tr_loss': 0.01037912818682752,
#   'vl_loss': 0.011627370153614914,
#   'tr_metrics': {'train_metrics/F1Score': 0.8353976011276245,
#    'train_metrics/Accuracy': 0.9307888150215149,
#    'train_metrics/Dice': 0.8353976607322693,
#    'train_metrics/Precision': 0.8699249029159546,
#    'train_metrics/Specificity': 0.9663928151130676,
#    'train_metrics/Recall': 0.8035064935684204,
#    'train_metrics/JaccardIndex': 0.8166838884353638},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7945953607559204,
#    'valid_metrics/Accuracy': 0.927229106426239,
#    'valid_metrics/Dice': 0.7945953011512756,
#    'valid_metrics/Precision': 0.8499539494514465,
#    'valid_metrics/Specificity': 0.9693734049797058,
#    'valid_metrics/Recall': 0.7460069060325623,
#    'valid_metrics/JaccardIndex': 0.7872511148452759}},
#  {'tr_loss': 0.010249441295615898,
#   'vl_loss': 0.01160354883514316,
#   'tr_metrics': {'train_metrics/F1Score': 0.836659848690033,
#    'train_metrics/Accuracy': 0.9313520789146423,
#    'train_metrics/Dice': 0.836659848690033,
#    'train_metrics/Precision': 0.8716866374015808,
#    'train_metrics/Specificity': 0.9668806791305542,
#    'train_metrics/Recall': 0.8043392300605774,
#    'train_metrics/JaccardIndex': 0.8179478645324707},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8032899498939514,
#    'valid_metrics/Accuracy': 0.9242525696754456,
#    'valid_metrics/Dice': 0.8032899498939514,
#    'valid_metrics/Precision': 0.7875096201896667,
#    'valid_metrics/Specificity': 0.9485632181167603,
#    'valid_metrics/Recall': 0.8197156190872192,
#    'valid_metrics/JaccardIndex': 0.7908212542533875}},
#  {'tr_loss': 0.010066275146710314,
#   'vl_loss': 0.011364317107154596,
#   'tr_metrics': {'train_metrics/F1Score': 0.8400494456291199,
#    'train_metrics/Accuracy': 0.9326506853103638,
#    'train_metrics/Dice': 0.8400494456291199,
#    'train_metrics/Precision': 0.873447835445404,
#    'train_metrics/Specificity': 0.9672077298164368,
#    'train_metrics/Recall': 0.8091111183166504,
#    'train_metrics/JaccardIndex': 0.8211958408355713},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8036289215087891,
#    'valid_metrics/Accuracy': 0.9275815486907959,
#    'valid_metrics/Dice': 0.8036288619041443,
#    'valid_metrics/Precision': 0.8227521777153015,
#    'valid_metrics/Specificity': 0.9606526494026184,
#    'valid_metrics/Recall': 0.7853743433952332,
#    'valid_metrics/JaccardIndex': 0.7933528423309326}},
#  {'tr_loss': 0.010142244025038622,
#   'vl_loss': 0.011596116320046678,
#   'tr_metrics': {'train_metrics/F1Score': 0.8393322229385376,
#    'train_metrics/Accuracy': 0.9324699640274048,
#    'train_metrics/Dice': 0.8393321633338928,
#    'train_metrics/Precision': 0.8743981719017029,
#    'train_metrics/Specificity': 0.9675754308700562,
#    'train_metrics/Recall': 0.8069702386856079,
#    'train_metrics/JaccardIndex': 0.8205766677856445},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8040674924850464,
#    'valid_metrics/Accuracy': 0.9244375824928284,
#    'valid_metrics/Dice': 0.8040674924850464,
#    'valid_metrics/Precision': 0.7871267199516296,
#    'valid_metrics/Specificity': 0.948317289352417,
#    'valid_metrics/Recall': 0.8217535614967346,
#    'valid_metrics/JaccardIndex': 0.7914535999298096}},
#  {'tr_loss': 0.010179648271276931,
#   'vl_loss': 0.01129681386887797,
#   'tr_metrics': {'train_metrics/F1Score': 0.8378386497497559,
#    'train_metrics/Accuracy': 0.9319170117378235,
#    'train_metrics/Dice': 0.8378387093544006,
#    'train_metrics/Precision': 0.8738807439804077,
#    'train_metrics/Specificity': 0.9675161838531494,
#    'train_metrics/Recall': 0.8046518564224243,
#    'train_metrics/JaccardIndex': 0.8191591501235962},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8074662089347839,
#    'valid_metrics/Accuracy': 0.9272490739822388,
#    'valid_metrics/Dice': 0.8074661493301392,
#    'valid_metrics/Precision': 0.8063877820968628,
#    'valid_metrics/Specificity': 0.9548537731170654,
#    'valid_metrics/Recall': 0.8085474967956543,
#    'valid_metrics/JaccardIndex': 0.7956269383430481}},
#  {'tr_loss': 0.009778519492011424,
#   'vl_loss': 0.011537543997801408,
#   'tr_metrics': {'train_metrics/F1Score': 0.8444448113441467,
#    'train_metrics/Accuracy': 0.9344986081123352,
#    'train_metrics/Dice': 0.8444448709487915,
#    'train_metrics/Precision': 0.8779764771461487,
#    'train_metrics/Specificity': 0.9683783054351807,
#    'train_metrics/Recall': 0.8133801817893982,
#    'train_metrics/JaccardIndex': 0.8255524039268494},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8080592751502991,
#    'valid_metrics/Accuracy': 0.9255437850952148,
#    'valid_metrics/Dice': 0.8080592751502991,
#    'valid_metrics/Precision': 0.7866501212120056,
#    'valid_metrics/Specificity': 0.9476080536842346,
#    'valid_metrics/Recall': 0.8306663632392883,
#    'valid_metrics/JaccardIndex': 0.7948206663131714}},
#  {'tr_loss': 0.009914305169884495,
#   'vl_loss': 0.011080015839066745,
#   'tr_metrics': {'train_metrics/F1Score': 0.8433772325515747,
#    'train_metrics/Accuracy': 0.9341519474983215,
#    'train_metrics/Dice': 0.8433771729469299,
#    'train_metrics/Precision': 0.8783480525016785,
#    'train_metrics/Specificity': 0.968576967716217,
#    'train_metrics/Recall': 0.8110844492912292,
#    'train_metrics/JaccardIndex': 0.8245671987533569},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8099748492240906,
#    'valid_metrics/Accuracy': 0.9294394254684448,
#    'valid_metrics/Dice': 0.8099748492240906,
#    'valid_metrics/Precision': 0.823352038860321,
#    'valid_metrics/Specificity': 0.9602330923080444,
#    'valid_metrics/Recall': 0.7970253229141235,
#    'valid_metrics/JaccardIndex': 0.7987935543060303}},
#  {'tr_loss': 0.009634239474932353,
#   'vl_loss': 0.010813455352681944,
#   'tr_metrics': {'train_metrics/F1Score': 0.847619354724884,
#    'train_metrics/Accuracy': 0.9358484148979187,
#    'train_metrics/Dice': 0.847619354724884,
#    'train_metrics/Precision': 0.8814712166786194,
#    'train_metrics/Specificity': 0.9692969918251038,
#    'train_metrics/Recall': 0.8162713050842285,
#    'train_metrics/JaccardIndex': 0.8287270665168762},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8145366311073303,
#    'valid_metrics/Accuracy': 0.932417631149292,
#    'valid_metrics/Dice': 0.8145365715026855,
#    'valid_metrics/Precision': 0.8445698022842407,
#    'valid_metrics/Specificity': 0.9663363099098206,
#    'valid_metrics/Recall': 0.7865660190582275,
#    'valid_metrics/JaccardIndex': 0.8038719892501831}},
#  {'tr_loss': 0.009695993651207485,
#   'vl_loss': 0.010772473534792087,
#   'tr_metrics': {'train_metrics/F1Score': 0.8466787338256836,
#    'train_metrics/Accuracy': 0.9354720711708069,
#    'train_metrics/Dice': 0.8466787934303284,
#    'train_metrics/Precision': 0.8807827830314636,
#    'train_metrics/Specificity': 0.9691382646560669,
#    'train_metrics/Recall': 0.8151172995567322,
#    'train_metrics/JaccardIndex': 0.8278024792671204},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8123345375061035,
#    'valid_metrics/Accuracy': 0.9320729374885559,
#    'valid_metrics/Dice': 0.8123345375061035,
#    'valid_metrics/Precision': 0.8484246730804443,
#    'valid_metrics/Specificity': 0.9676268100738525,
#    'valid_metrics/Recall': 0.7791895270347595,
#    'valid_metrics/JaccardIndex': 0.8021706342697144}},
#  {'tr_loss': 0.00978581063839358,
#   'vl_loss': 0.010713439190249646,
#   'tr_metrics': {'train_metrics/F1Score': 0.8446516394615173,
#    'train_metrics/Accuracy': 0.9346742033958435,
#    'train_metrics/Dice': 0.8446516990661621,
#    'train_metrics/Precision': 0.8794776797294617,
#    'train_metrics/Specificity': 0.9688553214073181,
#    'train_metrics/Recall': 0.8124786019325256,
#    'train_metrics/JaccardIndex': 0.8258236050605774},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8149648308753967,
#    'valid_metrics/Accuracy': 0.9315216541290283,
#    'valid_metrics/Dice': 0.8149648308753967,
#    'valid_metrics/Precision': 0.8313006162643433,
#    'valid_metrics/Specificity': 0.9622801542282104,
#    'valid_metrics/Recall': 0.7992586493492126,
#    'valid_metrics/JaccardIndex': 0.8035373687744141}},
#  {'tr_loss': 0.009481732555493179,
#   'vl_loss': 0.010673741231093535,
#   'tr_metrics': {'train_metrics/F1Score': 0.8487510085105896,
#    'train_metrics/Accuracy': 0.9362518191337585,
#    'train_metrics/Dice': 0.8487510085105896,
#    'train_metrics/Precision': 0.881557285785675,
#    'train_metrics/Specificity': 0.9692460894584656,
#    'train_metrics/Recall': 0.8182987570762634,
#    'train_metrics/JaccardIndex': 0.8298046588897705},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8114511966705322,
#    'valid_metrics/Accuracy': 0.9335873126983643,
#    'valid_metrics/Dice': 0.8114511966705322,
#    'valid_metrics/Precision': 0.8737770915031433,
#    'valid_metrics/Specificity': 0.9745548963546753,
#    'valid_metrics/Recall': 0.7574246525764465,
#    'valid_metrics/JaccardIndex': 0.8026190996170044}},
#  {'tr_loss': 0.009565299585174266,
#   'vl_loss': 0.01077957678600628,
#   'tr_metrics': {'train_metrics/F1Score': 0.8476212024688721,
#    'train_metrics/Accuracy': 0.9359785914421082,
#    'train_metrics/Dice': 0.8476212024688721,
#    'train_metrics/Precision': 0.8834021687507629,
#    'train_metrics/Specificity': 0.9699239730834961,
#    'train_metrics/Recall': 0.8146259188652039,
#    'train_metrics/JaccardIndex': 0.8288248181343079},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8165799379348755,
#    'valid_metrics/Accuracy': 0.9305214881896973,
#    'valid_metrics/Dice': 0.8165799379348755,
#    'valid_metrics/Precision': 0.8134890198707581,
#    'valid_metrics/Specificity': 0.9562949538230896,
#    'valid_metrics/Recall': 0.8196943998336792,
#    'valid_metrics/JaccardIndex': 0.8039135336875916}},
#  {'tr_loss': 0.009306837909806201,
#   'vl_loss': 0.010460647865842209,
#   'tr_metrics': {'train_metrics/F1Score': 0.8524940013885498,
#    'train_metrics/Accuracy': 0.937730610370636,
#    'train_metrics/Dice': 0.8524940013885498,
#    'train_metrics/Precision': 0.8839340209960938,
#    'train_metrics/Specificity': 0.9697637557983398,
#    'train_metrics/Recall': 0.8232136964797974,
#    'train_metrics/JaccardIndex': 0.8334888219833374},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8165263533592224,
#    'valid_metrics/Accuracy': 0.9337037801742554,
#    'valid_metrics/Dice': 0.8165263533592224,
#    'valid_metrics/Precision': 0.8543968200683594,
#    'valid_metrics/Specificity': 0.9690134525299072,
#    'valid_metrics/Recall': 0.7818706035614014,
#    'valid_metrics/JaccardIndex': 0.8060858249664307}},
#  {'tr_loss': 0.009414157644940474,
#   'vl_loss': 0.010953381139799434,
#   'tr_metrics': {'train_metrics/F1Score': 0.8496331572532654,
#    'train_metrics/Accuracy': 0.9366673827171326,
#    'train_metrics/Dice': 0.8496331572532654,
#    'train_metrics/Precision': 0.8831310272216797,
#    'train_metrics/Specificity': 0.9696983098983765,
#    'train_metrics/Recall': 0.818583607673645,
#    'train_metrics/JaccardIndex': 0.8307209014892578},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8152911067008972,
#    'valid_metrics/Accuracy': 0.9290423393249512,
#    'valid_metrics/Dice': 0.815291166305542,
#    'valid_metrics/Precision': 0.8011021614074707,
#    'valid_metrics/Specificity': 0.9520771503448486,
#    'valid_metrics/Recall': 0.8299918174743652,
#    'valid_metrics/JaccardIndex': 0.8020228147506714}},
#  {'tr_loss': 0.009122261663606345,
#   'vl_loss': 0.010578729643784895,
#   'tr_metrics': {'train_metrics/F1Score': 0.8543323278427124,
#    'train_metrics/Accuracy': 0.938745379447937,
#    'train_metrics/Dice': 0.8543323874473572,
#    'train_metrics/Precision': 0.889562726020813,
#    'train_metrics/Specificity': 0.9714617133140564,
#    'train_metrics/Recall': 0.8217862248420715,
#    'train_metrics/JaccardIndex': 0.8355200886726379},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8189607858657837,
#    'valid_metrics/Accuracy': 0.9337778687477112,
#    'valid_metrics/Dice': 0.8189607858657837,
#    'valid_metrics/Precision': 0.8457024097442627,
#    'valid_metrics/Specificity': 0.9663169384002686,
#    'valid_metrics/Recall': 0.793858528137207,
#    'valid_metrics/JaccardIndex': 0.8077676892280579}},
#  {'tr_loss': 0.009288803017993275,
#   'vl_loss': 0.01059862393094766,
#   'tr_metrics': {'train_metrics/F1Score': 0.8518206477165222,
#    'train_metrics/Accuracy': 0.937495231628418,
#    'train_metrics/Dice': 0.8518206477165222,
#    'train_metrics/Precision': 0.8839794397354126,
#    'train_metrics/Specificity': 0.9698246717453003,
#    'train_metrics/Recall': 0.8219195604324341,
#    'train_metrics/JaccardIndex': 0.8328474164009094},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8150013089179993,
#    'valid_metrics/Accuracy': 0.9332311153411865,
#    'valid_metrics/Dice': 0.8150013089179993,
#    'valid_metrics/Precision': 0.8538962006568909,
#    'valid_metrics/Specificity': 0.9689831733703613,
#    'valid_metrics/Recall': 0.7794954180717468,
#    'valid_metrics/JaccardIndex': 0.8047417402267456}},
#  {'tr_loss': 0.009158047376913801,
#   'vl_loss': 0.010909367884908403,
#   'tr_metrics': {'train_metrics/F1Score': 0.8537001013755798,
#    'train_metrics/Accuracy': 0.9384735226631165,
#    'train_metrics/Dice': 0.8537000417709351,
#    'train_metrics/Precision': 0.8888113498687744,
#    'train_metrics/Specificity': 0.971261739730835,
#    'train_metrics/Recall': 0.8212574124336243,
#    'train_metrics/JaccardIndex': 0.8348782062530518},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8152880072593689,
#    'valid_metrics/Accuracy': 0.9297627806663513,
#    'valid_metrics/Dice': 0.8152880072593689,
#    'valid_metrics/Precision': 0.809122622013092,
#    'valid_metrics/Specificity': 0.9549286961555481,
#    'valid_metrics/Recall': 0.8215479850769043,
#    'valid_metrics/JaccardIndex': 0.8025261163711548}},
#  {'tr_loss': 0.009106932744671161,
#   'vl_loss': 0.010609204273196261,
#   'tr_metrics': {'train_metrics/F1Score': 0.8544586896896362,
#    'train_metrics/Accuracy': 0.9385483264923096,
#    'train_metrics/Dice': 0.8544586896896362,
#    'train_metrics/Precision': 0.8857907056808472,
#    'train_metrics/Specificity': 0.9702357649803162,
#    'train_metrics/Recall': 0.825267493724823,
#    'train_metrics/JaccardIndex': 0.8354614973068237},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8176146745681763,
#    'valid_metrics/Accuracy': 0.9321528673171997,
#    'valid_metrics/Dice': 0.817614734172821,
#    'valid_metrics/Precision': 0.8295594453811646,
#    'valid_metrics/Specificity': 0.9614883065223694,
#    'valid_metrics/Recall': 0.8060091137886047,
#    'valid_metrics/JaccardIndex': 0.805740237236023}},
#  {'tr_loss': 0.00895758707579174,
#   'vl_loss': 0.010879323260434346,
#   'tr_metrics': {'train_metrics/F1Score': 0.8580566048622131,
#    'train_metrics/Accuracy': 0.9401025176048279,
#    'train_metrics/Dice': 0.8580566048622131,
#    'train_metrics/Precision': 0.8900794982910156,
#    'train_metrics/Specificity': 0.9713881611824036,
#    'train_metrics/Recall': 0.8282578587532043,
#    'train_metrics/JaccardIndex': 0.8391308188438416},
#   'vl_metrics': {'valid_metrics/F1Score': 0.817162275314331,
#    'valid_metrics/Accuracy': 0.9295337796211243,
#    'valid_metrics/Dice': 0.817162275314331,
#    'valid_metrics/Precision': 0.800447404384613,
#    'valid_metrics/Specificity': 0.9516134262084961,
#    'valid_metrics/Recall': 0.8345901370048523,
#    'valid_metrics/JaccardIndex': 0.8036063313484192}},
#  {'tr_loss': 0.008935164309237614,
#   'vl_loss': 0.01095917950380723,
#   'tr_metrics': {'train_metrics/F1Score': 0.857945442199707,
#    'train_metrics/Accuracy': 0.9400389194488525,
#    'train_metrics/Dice': 0.857945442199707,
#    'train_metrics/Precision': 0.889698326587677,
#    'train_metrics/Specificity': 0.9712724089622498,
#    'train_metrics/Recall': 0.8283808827400208,
#    'train_metrics/JaccardIndex': 0.8390055298805237},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8178845643997192,
#    'valid_metrics/Accuracy': 0.9296768307685852,
#    'valid_metrics/Dice': 0.8178845047950745,
#    'valid_metrics/Precision': 0.7996792197227478,
#    'valid_metrics/Specificity': 0.9512437582015991,
#    'valid_metrics/Recall': 0.8369380235671997,
#    'valid_metrics/JaccardIndex': 0.8041858077049255}},
#  {'tr_loss': 0.00894201841236146,
#   'vl_loss': 0.010556395392160158,
#   'tr_metrics': {'train_metrics/F1Score': 0.857373833656311,
#    'train_metrics/Accuracy': 0.9398359060287476,
#    'train_metrics/Dice': 0.8573737740516663,
#    'train_metrics/Precision': 0.8897130489349365,
#    'train_metrics/Specificity': 0.9713140726089478,
#    'train_metrics/Recall': 0.8273029923439026,
#    'train_metrics/JaccardIndex': 0.8384540677070618},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8164251446723938,
#    'valid_metrics/Accuracy': 0.9322741627693176,
#    'valid_metrics/Dice': 0.8164251446723938,
#    'valid_metrics/Precision': 0.8355110287666321,
#    'valid_metrics/Specificity': 0.9634557962417603,
#    'valid_metrics/Recall': 0.7981917262077332,
#    'valid_metrics/JaccardIndex': 0.8050310611724854}},
#  {'tr_loss': 0.009071688612630545,
#   'vl_loss': 0.010312607648519935,
#   'tr_metrics': {'train_metrics/F1Score': 0.8551111817359924,
#    'train_metrics/Accuracy': 0.9389621615409851,
#    'train_metrics/Dice': 0.8551111817359924,
#    'train_metrics/Precision': 0.8886293172836304,
#    'train_metrics/Specificity': 0.9711116552352905,
#    'train_metrics/Recall': 0.8240296244621277,
#    'train_metrics/JaccardIndex': 0.8362237215042114},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8228111267089844,
#    'valid_metrics/Accuracy': 0.9346446394920349,
#    'valid_metrics/Dice': 0.8228110671043396,
#    'valid_metrics/Precision': 0.8422426581382751,
#    'valid_metrics/Specificity': 0.9649673104286194,
#    'valid_metrics/Recall': 0.8042558431625366,
#    'valid_metrics/JaccardIndex': 0.8109579086303711}},
#  {'tr_loss': 0.00882039973230073,
#   'vl_loss': 0.010367069062579093,
#   'tr_metrics': {'train_metrics/F1Score': 0.8592568039894104,
#    'train_metrics/Accuracy': 0.9406360387802124,
#    'train_metrics/Dice': 0.8592569231987,
#    'train_metrics/Precision': 0.8917617797851562,
#    'train_metrics/Specificity': 0.971852719783783,
#    'train_metrics/Recall': 0.829038143157959,
#    'train_metrics/JaccardIndex': 0.8403704166412354},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8230276107788086,
#    'valid_metrics/Accuracy': 0.9334219098091125,
#    'valid_metrics/Dice': 0.8230276107788086,
#    'valid_metrics/Precision': 0.8255494832992554,
#    'valid_metrics/Specificity': 0.9596776366233826,
#    'valid_metrics/Recall': 0.8205210566520691,
#    'valid_metrics/JaccardIndex': 0.810250997543335}},
#  {'tr_loss': 0.008756252207867698,
#   'vl_loss': 0.010737713440734908,
#   'tr_metrics': {'train_metrics/F1Score': 0.8602165579795837,
#    'train_metrics/Accuracy': 0.9410772323608398,
#    'train_metrics/Dice': 0.860216498374939,
#    'train_metrics/Precision': 0.8933512568473816,
#    'train_metrics/Specificity': 0.9723016023635864,
#    'train_metrics/Recall': 0.829451858997345,
#    'train_metrics/JaccardIndex': 0.8413739204406738},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8220869302749634,
#    'valid_metrics/Accuracy': 0.931031346321106,
#    'valid_metrics/Dice': 0.8220869302749634,
#    'valid_metrics/Precision': 0.8008124828338623,
#    'valid_metrics/Specificity': 0.9511494636535645,
#    'valid_metrics/Recall': 0.8445225358009338,
#    'valid_metrics/JaccardIndex': 0.8079384565353394}},
#  {'tr_loss': 0.008627280527238346,
#   'vl_loss': 0.010503895638302027,
#   'tr_metrics': {'train_metrics/F1Score': 0.8611537218093872,
#    'train_metrics/Accuracy': 0.941219687461853,
#    'train_metrics/Dice': 0.8611537218093872,
#    'train_metrics/Precision': 0.8902047872543335,
#    'train_metrics/Specificity': 0.9712287783622742,
#    'train_metrics/Recall': 0.8339388370513916,
#    'train_metrics/JaccardIndex': 0.8421398401260376},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8166947960853577,
#    'valid_metrics/Accuracy': 0.934566080570221,
#    'valid_metrics/Dice': 0.8166947960853577,
#    'valid_metrics/Precision': 0.866165816783905,
#    'valid_metrics/Specificity': 0.9722393155097961,
#    'valid_metrics/Recall': 0.7725695371627808,
#    'valid_metrics/JaccardIndex': 0.8067907094955444}},
#  {'tr_loss': 0.008806559730824032,
#   'vl_loss': 0.01071939243428035,
#   'tr_metrics': {'train_metrics/F1Score': 0.8581040501594543,
#    'train_metrics/Accuracy': 0.9402151107788086,
#    'train_metrics/Dice': 0.8581040501594543,
#    'train_metrics/Precision': 0.8916128277778625,
#    'train_metrics/Specificity': 0.9718777537345886,
#    'train_metrics/Recall': 0.8270227313041687,
#    'train_metrics/JaccardIndex': 0.83924800157547},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8231691718101501,
#    'valid_metrics/Accuracy': 0.9306468367576599,
#    'valid_metrics/Dice': 0.8231691718101501,
#    'valid_metrics/Precision': 0.7931472659111023,
#    'valid_metrics/Specificity': 0.9481102824211121,
#    'valid_metrics/Recall': 0.8555532097816467,
#    'valid_metrics/JaccardIndex': 0.8083880543708801}},
#  {'tr_loss': 0.008651333259156914,
#   'vl_loss': 0.010180825604895367,
#   'tr_metrics': {'train_metrics/F1Score': 0.8626860976219177,
#    'train_metrics/Accuracy': 0.941909909248352,
#    'train_metrics/Dice': 0.8626860976219177,
#    'train_metrics/Precision': 0.8924688100814819,
#    'train_metrics/Specificity': 0.9718635678291321,
#    'train_metrics/Recall': 0.8348270058631897,
#    'train_metrics/JaccardIndex': 0.8437366485595703},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8221975564956665,
#    'valid_metrics/Accuracy': 0.9346781373023987,
#    'valid_metrics/Dice': 0.8221975564956665,
#    'valid_metrics/Precision': 0.8451340198516846,
#    'valid_metrics/Specificity': 0.965888261795044,
#    'valid_metrics/Recall': 0.800473153591156,
#    'valid_metrics/JaccardIndex': 0.8105674982070923}},
#  {'tr_loss': 0.008564388064395627,
#   'vl_loss': 0.0102389711153093,
#   'tr_metrics': {'train_metrics/F1Score': 0.8628051280975342,
#    'train_metrics/Accuracy': 0.9420506358146667,
#    'train_metrics/Dice': 0.8628051280975342,
#    'train_metrics/Precision': 0.894082248210907,
#    'train_metrics/Specificity': 0.9723750948905945,
#    'train_metrics/Recall': 0.8336423635482788,
#    'train_metrics/JaccardIndex': 0.843925952911377},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8191173076629639,
#    'valid_metrics/Accuracy': 0.9364036917686462,
#    'valid_metrics/Dice': 0.8191173076629639,
#    'valid_metrics/Precision': 0.8838948011398315,
#    'valid_metrics/Specificity': 0.976686418056488,
#    'valid_metrics/Recall': 0.7631860971450806,
# ...
#    'valid_metrics/Dice': 0.8472635746002197,
#    'valid_metrics/Precision': 0.852992594242096,
#    'valid_metrics/Specificity': 0.96626877784729,
#    'valid_metrics/Recall': 0.8416110277175903,
#    'valid_metrics/JaccardIndex': 0.8334716558456421}},
#  {'tr_loss': 0.005635896269693848,
#   'vl_loss': 0.00931064732746728,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097411632537842,
#    'train_metrics/Accuracy': 0.9611427187919617,
#    'train_metrics/Dice': 0.909741222858429,
#    'train_metrics/Precision': 0.9240224361419678,
#    'train_metrics/Specificity': 0.9793941974639893,
#    'train_metrics/Recall': 0.8958947062492371,
#    'train_metrics/JaccardIndex': 0.8930537700653076},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472673296928406,
#    'valid_metrics/Accuracy': 0.9427502155303955,
#    'valid_metrics/Dice': 0.8472672700881958,
#    'valid_metrics/Precision': 0.8529996871948242,
#    'valid_metrics/Specificity': 0.9662706255912781,
#    'valid_metrics/Recall': 0.8416114449501038,
#    'valid_metrics/JaccardIndex': 0.8334754705429077}},
#  {'tr_loss': 0.005652766089794065,
#   'vl_loss': 0.00931038224213832,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097415208816528,
#    'train_metrics/Accuracy': 0.9611429572105408,
#    'train_metrics/Dice': 0.9097415804862976,
#    'train_metrics/Precision': 0.9240261316299438,
#    'train_metrics/Specificity': 0.97939532995224,
#    'train_metrics/Recall': 0.8958919048309326,
#    'train_metrics/JaccardIndex': 0.893054187297821},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472715020179749,
#    'valid_metrics/Accuracy': 0.9427520632743835,
#    'valid_metrics/Dice': 0.8472715020179749,
#    'valid_metrics/Precision': 0.8530078530311584,
#    'valid_metrics/Specificity': 0.9662728309631348,
#    'valid_metrics/Recall': 0.8416118025779724,
#    'valid_metrics/JaccardIndex': 0.8334797620773315}},
#  {'tr_loss': 0.005653299136759492,
#   'vl_loss': 0.009310531253750259,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097418189048767,
#    'train_metrics/Accuracy': 0.9611430764198303,
#    'train_metrics/Dice': 0.9097418785095215,
#    'train_metrics/Precision': 0.9240245819091797,
#    'train_metrics/Specificity': 0.9793949127197266,
#    'train_metrics/Recall': 0.895893931388855,
#    'train_metrics/JaccardIndex': 0.8930544853210449},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472673892974854,
#    'valid_metrics/Accuracy': 0.9427502155303955,
#    'valid_metrics/Dice': 0.8472673296928406,
#    'valid_metrics/Precision': 0.8529993891716003,
#    'valid_metrics/Specificity': 0.9662705659866333,
#    'valid_metrics/Recall': 0.8416118025779724,
#    'valid_metrics/JaccardIndex': 0.8334754705429077}},
#  {'tr_loss': 0.005651797298803802,
#   'vl_loss': 0.009310599229510686,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097424149513245,
#    'train_metrics/Accuracy': 0.9611434936523438,
#    'train_metrics/Dice': 0.9097424745559692,
#    'train_metrics/Precision': 0.9240298271179199,
#    'train_metrics/Specificity': 0.9793964624404907,
#    'train_metrics/Recall': 0.8958901166915894,
#    'train_metrics/JaccardIndex': 0.8930552005767822},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472686409950256,
#    'valid_metrics/Accuracy': 0.9427505731582642,
#    'valid_metrics/Dice': 0.8472686409950256,
#    'valid_metrics/Precision': 0.8529981970787048,
#    'valid_metrics/Specificity': 0.9662700891494751,
#    'valid_metrics/Recall': 0.8416154980659485,
#    'valid_metrics/JaccardIndex': 0.8334766030311584}},
#  {'tr_loss': 0.005634884117556012,
#   'vl_loss': 0.009310790700802011,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097416996955872,
#    'train_metrics/Accuracy': 0.9611432552337646,
#    'train_metrics/Dice': 0.9097416996955872,
#    'train_metrics/Precision': 0.9240307211875916,
#    'train_metrics/Specificity': 0.9793967008590698,
#    'train_metrics/Recall': 0.8958879113197327,
#    'train_metrics/JaccardIndex': 0.8930543661117554},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472696542739868,
#    'valid_metrics/Accuracy': 0.942750871181488,
#    'valid_metrics/Dice': 0.8472697138786316,
#    'valid_metrics/Precision': 0.8529978394508362,
#    'valid_metrics/Specificity': 0.9662699103355408,
#    'valid_metrics/Recall': 0.8416179418563843,
#    'valid_metrics/JaccardIndex': 0.8334776163101196}},
#  {'tr_loss': 0.005638479240259192,
#   'vl_loss': 0.009310456546577247,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097425937652588,
#    'train_metrics/Accuracy': 0.9611433148384094,
#    'train_metrics/Dice': 0.9097426533699036,
#    'train_metrics/Precision': 0.9240238666534424,
#    'train_metrics/Specificity': 0.9793945550918579,
#    'train_metrics/Recall': 0.8958961367607117,
#    'train_metrics/JaccardIndex': 0.8930553197860718},
#   'vl_metrics': {'valid_metrics/F1Score': 0.847274124622345,
#    'valid_metrics/Accuracy': 0.9427526593208313,
#    'valid_metrics/Dice': 0.847274124622345,
#    'valid_metrics/Precision': 0.8530039191246033,
#    'valid_metrics/Specificity': 0.9662714004516602,
#    'valid_metrics/Recall': 0.8416208028793335,
#    'valid_metrics/JaccardIndex': 0.8334819078445435}},
#  {'tr_loss': 0.005653659168107451,
#   'vl_loss': 0.009310619941549412,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097433090209961,
#    'train_metrics/Accuracy': 0.9611436724662781,
#    'train_metrics/Dice': 0.9097434282302856,
#    'train_metrics/Precision': 0.9240240454673767,
#    'train_metrics/Specificity': 0.9793946743011475,
#    'train_metrics/Recall': 0.8958973288536072,
#    'train_metrics/JaccardIndex': 0.8930560350418091},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472689986228943,
#    'valid_metrics/Accuracy': 0.9427508115768433,
#    'valid_metrics/Dice': 0.8472689986228943,
#    'valid_metrics/Precision': 0.8529998064041138,
#    'valid_metrics/Specificity': 0.9662705659866333,
#    'valid_metrics/Recall': 0.8416146636009216,
#    'valid_metrics/JaccardIndex': 0.8334770202636719}},
#  {'tr_loss': 0.005635495007694917,
#   'vl_loss': 0.00931025535213441,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097415208816528,
#    'train_metrics/Accuracy': 0.961142897605896,
#    'train_metrics/Dice': 0.9097416400909424,
#    'train_metrics/Precision': 0.924023449420929,
#    'train_metrics/Specificity': 0.9793944358825684,
#    'train_metrics/Recall': 0.8958944082260132,
#    'train_metrics/JaccardIndex': 0.8930541276931763},
#   'vl_metrics': {'valid_metrics/F1Score': 0.847272515296936,
#    'valid_metrics/Accuracy': 0.9427524209022522,
#    'valid_metrics/Dice': 0.847272515296936,
#    'valid_metrics/Precision': 0.8530078530311584,
#    'valid_metrics/Specificity': 0.9662727117538452,
#    'valid_metrics/Recall': 0.8416138887405396,
#    'valid_metrics/JaccardIndex': 0.8334806561470032}},
#  {'tr_loss': 0.0056357377406322596,
#   'vl_loss': 0.009310447456293584,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097424149513245,
#    'train_metrics/Accuracy': 0.9611436724662781,
#    'train_metrics/Dice': 0.9097424149513245,
#    'train_metrics/Precision': 0.9240343570709229,
#    'train_metrics/Specificity': 0.9793979525566101,
#    'train_metrics/Recall': 0.8958858847618103,
#    'train_metrics/JaccardIndex': 0.8930553197860718},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472724556922913,
#    'valid_metrics/Accuracy': 0.9427527785301208,
#    'valid_metrics/Dice': 0.8472724556922913,
#    'valid_metrics/Precision': 0.8530139923095703,
#    'valid_metrics/Specificity': 0.966274619102478,
#    'valid_metrics/Recall': 0.8416077494621277,
#    'valid_metrics/JaccardIndex': 0.8334808945655823}},
#  {'tr_loss': 0.0056539286902949175,
#   'vl_loss': 0.009310338372889634,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097422957420349,
#    'train_metrics/Accuracy': 0.9611433148384094,
#    'train_metrics/Dice': 0.9097423553466797,
#    'train_metrics/Precision': 0.9240264296531677,
#    'train_metrics/Specificity': 0.97939532995224,
#    'train_metrics/Recall': 0.8958930969238281,
#    'train_metrics/JaccardIndex': 0.8930550217628479},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472758531570435,
#    'valid_metrics/Accuracy': 0.9427535533905029,
#    'valid_metrics/Dice': 0.8472758531570435,
#    'valid_metrics/Precision': 0.8530098795890808,
#    'valid_metrics/Specificity': 0.9662731289863586,
#    'valid_metrics/Recall': 0.8416183590888977,
#    'valid_metrics/JaccardIndex': 0.8334838151931763}},
#  {'tr_loss': 0.0056413481222368144,
#   'vl_loss': 0.00931049690628604,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097428917884827,
#    'train_metrics/Accuracy': 0.9611434936523438,
#    'train_metrics/Dice': 0.9097428917884827,
#    'train_metrics/Precision': 0.9240258932113647,
#    'train_metrics/Specificity': 0.9793950915336609,
#    'train_metrics/Recall': 0.8958947062492371,
#    'train_metrics/JaccardIndex': 0.8930555582046509},
#   'vl_metrics': {'valid_metrics/F1Score': 0.847271203994751,
#    'valid_metrics/Accuracy': 0.9427517652511597,
#    'valid_metrics/Dice': 0.847271203994751,
#    'valid_metrics/Precision': 0.8530046939849854,
#    'valid_metrics/Specificity': 0.9662718772888184,
#    'valid_metrics/Recall': 0.8416142463684082,
#    'valid_metrics/JaccardIndex': 0.8334792852401733}},
#  {'tr_loss': 0.005638889262334703,
#   'vl_loss': 0.00931075111779467,
#   'tr_metrics': {'train_metrics/F1Score': 0.909741997718811,
#    'train_metrics/Accuracy': 0.9611431360244751,
#    'train_metrics/Dice': 0.909741997718811,
#    'train_metrics/Precision': 0.9240256547927856,
#    'train_metrics/Specificity': 0.9793950915336609,
#    'train_metrics/Recall': 0.8958932161331177,
#    'train_metrics/JaccardIndex': 0.8930546045303345},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472674489021301,
#    'valid_metrics/Accuracy': 0.9427498579025269,
#    'valid_metrics/Dice': 0.8472674489021301,
#    'valid_metrics/Precision': 0.8529932498931885,
#    'valid_metrics/Specificity': 0.9662686586380005,
#    'valid_metrics/Recall': 0.8416179418563843,
#    'valid_metrics/JaccardIndex': 0.8334752917289734}},
#  {'tr_loss': 0.005652996788914867,
#   'vl_loss': 0.009310625407226297,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097427129745483,
#    'train_metrics/Accuracy': 0.9611431360244751,
#    'train_metrics/Dice': 0.9097427129745483,
#    'train_metrics/Precision': 0.9240169525146484,
#    'train_metrics/Specificity': 0.979392409324646,
#    'train_metrics/Recall': 0.8959027528762817,
#    'train_metrics/JaccardIndex': 0.8930552005767822},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472709655761719,
#    'valid_metrics/Accuracy': 0.9427509307861328,
#    'valid_metrics/Dice': 0.8472709059715271,
#    'valid_metrics/Precision': 0.8529932498931885,
#    'valid_metrics/Specificity': 0.9662683606147766,
#    'valid_metrics/Recall': 0.8416248559951782,
#    'valid_metrics/JaccardIndex': 0.8334784507751465}},
#  {'tr_loss': 0.005644076795781611,
#   'vl_loss': 0.009310584989984064,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097437262535095,
#    'train_metrics/Accuracy': 0.9611434936523438,
#    'train_metrics/Dice': 0.9097436666488647,
#    'train_metrics/Precision': 0.9240192174911499,
#    'train_metrics/Specificity': 0.9793930649757385,
#    'train_metrics/Recall': 0.8959025740623474,
#    'train_metrics/JaccardIndex': 0.8930562734603882},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472757339477539,
#    'valid_metrics/Accuracy': 0.9427527189254761,
#    'valid_metrics/Dice': 0.8472756743431091,
#    'valid_metrics/Precision': 0.8529978394508362,
#    'valid_metrics/Specificity': 0.9662694334983826,
#    'valid_metrics/Recall': 0.8416297435760498,
#    'valid_metrics/JaccardIndex': 0.833483099937439}},
#  {'tr_loss': 0.0056187693163054706,
#   'vl_loss': 0.009310815842915685,
#   'tr_metrics': {'train_metrics/F1Score': 0.90974360704422,
#    'train_metrics/Accuracy': 0.9611434936523438,
#    'train_metrics/Dice': 0.90974360704422,
#    'train_metrics/Precision': 0.9240192174911499,
#    'train_metrics/Specificity': 0.9793930649757385,
#    'train_metrics/Recall': 0.8959023952484131,
#    'train_metrics/JaccardIndex': 0.8930561542510986},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472665548324585,
#    'valid_metrics/Accuracy': 0.9427490830421448,
#    'valid_metrics/Dice': 0.8472664952278137,
#    'valid_metrics/Precision': 0.8529859781265259,
#    'valid_metrics/Specificity': 0.9662664532661438,
#    'valid_metrics/Recall': 0.8416232466697693,
#    'valid_metrics/JaccardIndex': 0.8334740400314331}},
#  {'tr_loss': 0.005615567777192954,
#   'vl_loss': 0.00931068161739806,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097431898117065,
#    'train_metrics/Accuracy': 0.9611429572105408,
#    'train_metrics/Dice': 0.9097433090209961,
#    'train_metrics/Precision': 0.9240086078643799,
#    'train_metrics/Specificity': 0.9793897271156311,
#    'train_metrics/Recall': 0.8959116339683533,
#    'train_metrics/JaccardIndex': 0.8930553197860718},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472673296928406,
#    'valid_metrics/Accuracy': 0.9427490234375,
#    'valid_metrics/Dice': 0.8472672700881958,
#    'valid_metrics/Precision': 0.8529812097549438,
#    'valid_metrics/Specificity': 0.9662649631500244,
#    'valid_metrics/Recall': 0.8416293859481812,
#    'valid_metrics/JaccardIndex': 0.8334745764732361}},
#  {'tr_loss': 0.005657459101729485,
#   'vl_loss': 0.00931068869401129,
#   'tr_metrics': {'train_metrics/F1Score': 0.909743070602417,
#    'train_metrics/Accuracy': 0.9611427783966064,
#    'train_metrics/Dice': 0.909743070602417,
#    'train_metrics/Precision': 0.9240068197250366,
#    'train_metrics/Specificity': 0.9793891310691833,
#    'train_metrics/Recall': 0.8959130048751831,
#    'train_metrics/JaccardIndex': 0.893055260181427},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472711443901062,
#    'valid_metrics/Accuracy': 0.9427502155303955,
#    'valid_metrics/Dice': 0.8472711443901062,
#    'valid_metrics/Precision': 0.8529819250106812,
#    'valid_metrics/Specificity': 0.9662648439407349,
#    'valid_metrics/Recall': 0.8416363000869751,
#    'valid_metrics/JaccardIndex': 0.8334781527519226}},
#  {'tr_loss': 0.005659309928574838,
#   'vl_loss': 0.009310577424336584,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097440838813782,
#    'train_metrics/Accuracy': 0.9611432552337646,
#    'train_metrics/Dice': 0.9097440838813782,
#    'train_metrics/Precision': 0.9240076541900635,
#    'train_metrics/Specificity': 0.9793893694877625,
#    'train_metrics/Recall': 0.8959141969680786,
#    'train_metrics/JaccardIndex': 0.8930562734603882},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472689390182495,
#    'valid_metrics/Accuracy': 0.942749559879303,
#    'valid_metrics/Dice': 0.8472689986228943,
#    'valid_metrics/Precision': 0.8529813289642334,
#    'valid_metrics/Specificity': 0.9662648439407349,
#    'valid_metrics/Recall': 0.841632604598999,
#    'valid_metrics/JaccardIndex': 0.833476185798645}},
#  {'tr_loss': 0.005646542513091374,
#   'vl_loss': 0.009310507837639813,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097433686256409,
#    'train_metrics/Accuracy': 0.9611431360244751,
#    'train_metrics/Dice': 0.9097434878349304,
#    'train_metrics/Precision': 0.924012303352356,
#    'train_metrics/Specificity': 0.9793908596038818,
#    'train_metrics/Recall': 0.8959084749221802,
#    'train_metrics/JaccardIndex': 0.8930557370185852},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472729921340942,
#    'valid_metrics/Accuracy': 0.942751407623291,
#    'valid_metrics/Dice': 0.8472729921340942,
#    'valid_metrics/Precision': 0.8529906868934631,
#    'valid_metrics/Specificity': 0.9662674069404602,
#    'valid_metrics/Recall': 0.8416314125061035,
#    'valid_metrics/JaccardIndex': 0.8334802389144897}},
#  {'tr_loss': 0.005674755429597597,
#   'vl_loss': 0.009310353216517386,
#   'tr_metrics': {'train_metrics/F1Score': 0.9097434282302856,
#    'train_metrics/Accuracy': 0.9611430764198303,
#    'train_metrics/Dice': 0.9097434282302856,
#    'train_metrics/Precision': 0.9240097403526306,
#    'train_metrics/Specificity': 0.9793900847434998,
#    'train_metrics/Recall': 0.8959109783172607,
#    'train_metrics/JaccardIndex': 0.8930556774139404},
#   'vl_metrics': {'valid_metrics/F1Score': 0.847278356552124,
#    'valid_metrics/Accuracy': 0.942753255367279,
#    'valid_metrics/Dice': 0.847278356552124,
#    'valid_metrics/Precision': 0.8529936075210571,
#    'valid_metrics/Specificity': 0.9662678837776184,
#    'valid_metrics/Recall': 0.8416391611099243,
#    'valid_metrics/JaccardIndex': 0.8334853649139404}}]

# %% [markdown]
# ## Save images

# %%
from PIL import Image
import cv2
def skin_plot(img, gt, pred):
    img = np.array(img)
    gt = np.array(gt)
    pred = np.array(pred)
    edged_test = cv2.Canny(pred, 100, 255)
    contours_test, _ = cv2.findContours(edged_test, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    edged_gt = cv2.Canny(gt, 100, 255)
    contours_gt, _ = cv2.findContours(edged_gt, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    for cnt_test in contours_test:
        cv2.drawContours(img, [cnt_test], -1, (0, 0, 255), 1)
    for cnt_gt in contours_gt:
        cv2.drawContours(img, [cnt_gt], -1, (0,255,0), 1)
    return img

#---------------------------------------------------------------------------------------------


save_imgs_dir = f"{config['model']['save_dir']}/visualized"

if not os.path.isdir(save_imgs_dir):
    os.mkdir(save_imgs_dir)

with torch.no_grad():
    for batch in tqdm(te_dataloader):
        imgs = batch['image']
        msks = batch['mask']
        ids = batch['id']
        
        preds = best_model(imgs.to(device))
        
        txm = imgs.cpu().numpy()
        tbm = torch.argmax(msks, 1).cpu().numpy()
        tpm = torch.argmax(preds, 1).cpu().numpy()
        tid = ids
        
        for idx in range(len(tbm)):
            img = np.moveaxis(txm[idx, :3], 0, -1)*255.
            img = np.ascontiguousarray(img, dtype=np.uint8)
            gt = np.uint8(tbm[idx]*255.)
            pred = np.where(tpm[idx]>0.5, 255, 0)
            pred = np.ascontiguousarray(pred, dtype=np.uint8)
            
            res_img = skin_plot(img, gt, pred)
            
            fid = tid[idx]
            Image.fromarray(img).save(f"{save_imgs_dir}/{fid}_img.png")
            Image.fromarray(res_img).save(f"{save_imgs_dir}/{fid}_img_gt_pred.png")
# Out:
# 100%|██████████| 33/33 [00:19<00:00,  1.68it/s]

# %%
f"{config['model']['save_dir']}/visualized"
# Out:
# '../saved_models/isic2018_missformer/visualized'
