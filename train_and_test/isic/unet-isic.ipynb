# %% [markdown]
# # UNet - ISIC2018
# ---

# %%
# !pip install torchmetrics==0.10.3
# Out:
# Requirement already satisfied: torchmetrics==0.10.3 in /raid/home/labusermodaresi/environments/.py3.8.3/lib/python3.8/site-packages (0.10.3)
# Requirement already satisfied: torch>=1.3.1 in /raid/home/labusermodaresi/environments/.py3.8.3/lib/python3.8/site-packages (from torchmetrics==0.10.3) (1.13.0)
# Requirement already satisfied: typing-extensions in /raid/home/labusermodaresi/environments/.py3.8.3/lib/python3.8/site-packages (from torchmetrics==0.10.3) (4.3.0)
# Requirement already satisfied: packaging in /raid/home/labusermodaresi/.local/lib/python3.8/site-packages (from torchmetrics==0.10.3) (21.3)
# Requirement already satisfied: numpy>=1.17.2 in /raid/home/labusermodaresi/environments/.py3.8.3/lib/python3.8/site-packages (from torchmetrics==0.10.3) (1.22.4)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /raid/home/labusermodaresi/environments/.py3.8.3/lib/python3.8/site-packages (from torch>=1.3.1->torchmetrics==0.10.3) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /raid/home/labusermodaresi/environments/.py3.8.3/lib/python3.8/site-packages (from torch>=1.3.1->torchmetrics==0.10.3) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /raid/home/labusermodaresi/environments/.py3.8.3/lib/python3.8/site-packages (from torch>=1.3.1->torchmetrics==0.10.3) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /raid/home/labusermodaresi/environments/.py3.8.3/lib/python3.8/site-packages (from torch>=1.3.1->torchmetrics==0.10.3) (11.7.99)
# Requirement already satisfied: setuptools in /raid/home/labusermodaresi/environments/.py3.8.3/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.3.1->torchmetrics==0.10.3) (63.4.1)
# Requirement already satisfied: wheel in /raid/home/labusermodaresi/environments/.py3.8.3/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.3.1->torchmetrics==0.10.3) (0.37.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /raid/home/labusermodaresi/environments/.py3.8.3/lib/python3.8/site-packages (from packaging->torchmetrics==0.10.3) (3.0.9)
#
# [notice] A new release of pip available: 22.3 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Import packages & functions

# %%
from __future__ import print_function, division


import os
import sys
sys.path.append('../..')
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import copy
import json
import importlib
import glob
import pandas as pd
from skimage import io, transform
import matplotlib.pyplot as plt
from matplotlib.image import imread
import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchmetrics
from torch.optim import Adam, SGD
from losses import DiceLoss, DiceLossWithLogtis
from torch.nn import BCELoss, CrossEntropyLoss

from utils import (
    show_sbs,
    load_config,
    _print,
)

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# plt.ion()   # interactive mode

# %% [markdown]
# ## Set the seed

# %%
torch.manual_seed(0)
np.random.seed(0)
torch.cuda.manual_seed(0)
import random
random.seed(0)

# %% [markdown]
# ## Load the config

# %%
CONFIG_NAME = "isic/isic2018_unet.yaml"
CONFIG_FILE_PATH = os.path.join("../../configs", CONFIG_NAME)

# %%
config = load_config(CONFIG_FILE_PATH)
_print("Config:", "info_underline")
print(json.dumps(config, indent=2))
print(20*"~-", "\n")
# Out:
# Config:
# {
#   "run": {
#     "mode": "train",
#     "device": "gpu"
#   },
#   "transforms": "none",
#   "dataset": {
#     "class_name": "ISIC2018Dataset",
#     "input_size": 224,
#     "training": {
#       "params": {
#         "data_dir": "/path/to/datasets/ISIC2018"
#       }
#     },
#     "validation": {
#       "params": {
#         "data_dir": "/path/to/datasets/ISIC2018"
#       }
#     },
#     "number_classes": 2
#   },
#   "data_loader": {
#     "train": {
#       "batch_size": 16,
#       "shuffle": true,
#       "num_workers": 8,
#       "pin_memory": true
#     },
#     "validation": {
#       "batch_size": 16,
#       "shuffle": false,
#       "num_workers": 8,
#       "pin_memory": true
#     },
#     "test": {
#       "batch_size": 16,
#       "shuffle": false,
#       "num_workers": 4,
#       "pin_memory": false
#     }
#   },
#   "training": {
#     "optimizer": {
#       "name": "Adam",
#       "params": {
#         "lr": 0.0001
#       }
#     },
#     "criterion": {
#       "name": "DiceLoss",
#       "params": {}
#     },
#     "scheduler": {
#       "factor": 0.5,
#       "patience": 10
#     },
#     "epochs": 100
#   },
#   "model": {
#     "save_dir": "../../saved_models/isic2018_unet",
#     "load_weights": false,
#     "name": "UNet",
#     "params": {
#       "in_channels": 3,
#       "out_channels": 2,
#       "with_bn": false
#     }
#   }
# }
# ~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-

# %% [markdown]
# ## Dataset and Dataloader

# %%
from datasets.isic import ISIC2018DatasetFast
from torch.utils.data import DataLoader, Subset
from torchvision import transforms

# %%
# ------------------- params --------------------
INPUT_SIZE = config['dataset']['input_size']
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<


# ----------------- dataset --------------------
# preparing training dataset
tr_dataset = ISIC2018DatasetFast(mode="tr", one_hot=True)
vl_dataset = ISIC2018DatasetFast(mode="vl", one_hot=True)
te_dataset = ISIC2018DatasetFast(mode="te", one_hot=True)

# We consider 1815 samples for training, 259 samples for validation and 520 samples for testing
# !cat ~/deeplearning/skin/Prepare_ISIC2018.py

print(f"Length of trainig_dataset:\t{len(tr_dataset)}")
print(f"Length of validation_dataset:\t{len(vl_dataset)}")
print(f"Length of test_dataset:\t\t{len(te_dataset)}")


# prepare train dataloader
tr_dataloader = DataLoader(tr_dataset, **config['data_loader']['train'])

# prepare validation dataloader
vl_dataloader = DataLoader(vl_dataset, **config['data_loader']['validation'])

# prepare test dataloader
te_dataloader = DataLoader(te_dataset, **config['data_loader']['test'])

# -------------- test -----------------
# test and visualize the input data
for sample in tr_dataloader:
    img = sample['image']
    msk = sample['mask']
    print("\n Training")
    show_sbs(img[0], msk[0,1])
    break
    
for sample in vl_dataloader:
    img = sample['image']
    msk = sample['mask']
    print("Validation")
    show_sbs(img[0], msk[0,1])
    break
    
for sample in te_dataloader:
    img = sample['image']
    msk = sample['mask']
    print("Test")
    show_sbs(img[0], msk[0,1])
    break
# Out:
# Length of trainig_dataset:	1815
# Length of validation_dataset:	259
# Length of test_dataset:		520
#
#  Training
# Validation
# Test

# %% [markdown]
# ### Device

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Torch device: {device}")
# Out:
# Torch device: cuda

# %% [markdown]
# ## Metrics

# %%
metrics = torchmetrics.MetricCollection(
    [
        torchmetrics.F1Score(),
        torchmetrics.Accuracy(),
        torchmetrics.Dice(),
        torchmetrics.Precision(),
        torchmetrics.Recall(),
        torchmetrics.Specificity(),
        # IoU
        torchmetrics.JaccardIndex(2)
    ],
    prefix='train_metrics/'
)

# train_metrics
train_metrics = metrics.clone(prefix='train_metrics/').to(device)

# valid_metrics
valid_metrics = metrics.clone(prefix='valid_metrics/').to(device)

# test_metrics
test_metrics = metrics.clone(prefix='test_metrics/').to(device)

# %%
def make_serializeable_metrics(computed_metrics):
    res = {}
    for k, v in computed_metrics.items():
        res[k] = float(v.cpu().detach().numpy())
    return res

# %% [markdown]
# ## Define validate function

# %%
def validate(model, criterion, vl_dataloader):
    model.eval()
    with torch.no_grad():
        
        evaluator = valid_metrics.clone().to(device)
        
        losses = []
        cnt = 0.
        for batch, batch_data in enumerate(vl_dataloader):
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            cnt += msks.shape[0]
            
            imgs = imgs.to(device)
            msks = msks.to(device)
            
            preds = model(imgs)
            loss = criterion(preds, msks)
            losses.append(loss.item())
            
            
            preds_ = torch.argmax(preds, 1, keepdim=False).float()
            msks_ = torch.argmax(msks, 1, keepdim=False)
            evaluator.update(preds_, msks_)
        
#             _cml = f"curr_mean-loss:{np.sum(losses)/cnt:0.5f}"
#             _bl = f"batch-loss:{losses[-1]/msks.shape[0]:0.5f}"
#             iterator.set_description(f"Validation) batch:{batch+1:04d} -> {_cml}, {_bl}")
        
        # print the final results
        loss = np.sum(losses)/cnt
        metrics = evaluator.compute()
    
    return evaluator, loss

# %% [markdown]
# ## Define train function

# %%
def train(
    model, 
    device, 
    tr_dataloader,
    vl_dataloader,
    config,
    
    criterion,
    optimizer,
    scheduler,
    
    save_dir='./',
    save_file_id=None,
):
    
    EPOCHS = tr_prms['epochs']
    
    torch.cuda.empty_cache()
    model = model.to(device)

    evaluator = train_metrics.clone().to(device)
    
    epochs_info = []
    best_model = None
    best_result = {}
    best_vl_loss = np.Inf
    for epoch in range(EPOCHS):
        model.train()
        
        evaluator.reset()
        tr_iterator = tqdm(enumerate(tr_dataloader))
        tr_losses = []
        cnt = 0
        for batch, batch_data in tr_iterator:
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            imgs = imgs.to(device)
            msks = msks.to(device)
            
            optimizer.zero_grad()
            preds = model(imgs)
            loss = criterion(preds, msks)
            loss.backward()
            optimizer.step()
            
            # evaluate by metrics
            preds_ = torch.argmax(preds, 1, keepdim=False).float()
            msks_ = torch.argmax(msks, 1, keepdim=False)
            evaluator.update(preds_, msks_)
            
            cnt += imgs.shape[0]
            tr_losses.append(loss.item())
            
            # write details for each training batch
            _cml = f"curr_mean-loss:{np.sum(tr_losses)/cnt:0.5f}"
            _bl = f"mean_batch-loss:{tr_losses[-1]/imgs.shape[0]:0.5f}"
            tr_iterator.set_description(f"Training) ep:{epoch:03d}, batch:{batch+1:04d} -> {_cml}, {_bl}")
            
        tr_loss = np.sum(tr_losses)/cnt
        
        # validate model
        vl_metrics, vl_loss = validate(model, criterion, vl_dataloader)
        if vl_loss < best_vl_loss:
            # find a better model
            best_model = model
            best_vl_loss = vl_loss
            best_result = {
                'tr_loss': tr_loss,
                'vl_loss': vl_loss,
                'tr_metrics': make_serializeable_metrics(evaluator.compute()),
                'vl_metrics': make_serializeable_metrics(vl_metrics.compute())
            }
        
        # write the final results
        epoch_info = {
            'tr_loss': tr_loss,
            'vl_loss': vl_loss,
            'tr_metrics': make_serializeable_metrics(evaluator.compute()),
            'vl_metrics': make_serializeable_metrics(vl_metrics.compute())
        }
        epochs_info.append(epoch_info)
#         epoch_tqdm.set_description(f"Epoch:{epoch+1}/{EPOCHS} -> tr_loss:{tr_loss}, vl_loss:{vl_loss}")
        evaluator.reset()
    
        scheduler.step(vl_loss)
  
    # save final results
    res = {
        'id': save_file_id,
        'config': config,
        'epochs_info': epochs_info,
        'best_result': best_result
    }
    fn = f"{save_file_id+'_' if save_file_id else ''}result.json"
    fp = os.path.join(config['model']['save_dir'],fn)
    with open(fp, "w") as write_file:
        json.dump(res, write_file, indent=4)

    # save model's state_dict
    fn = "last_model_state_dict.pt"
    fp = os.path.join(config['model']['save_dir'],fn)
    torch.save(model.state_dict(), fp)
    
    # save the best model's state_dict
    fn = "best_model_state_dict.pt"
    fp = os.path.join(config['model']['save_dir'], fn)
    torch.save(best_model.state_dict(), fp)
    
    return best_model, model, res

# %% [markdown]
# ## Define test function

# %%
def test(model, te_dataloader):
    model.eval()
    with torch.no_grad():
        evaluator = test_metrics.clone().to(device)            
        for batch_data in tqdm(te_dataloader):
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            imgs = imgs.to(device)
            msks = msks.to(device)
            
            preds = model(imgs)
            
            # evaluate by metrics
            preds_ = torch.argmax(preds, 1, keepdim=False).float()
            msks_ = torch.argmax(msks, 1, keepdim=False)
            evaluator.update(preds_, msks_)
            
    return evaluator

# %% [markdown]
# ## Load and prepare model

# %%
from models.unet import UNet as Net


model = Net(**config['model']['params'])
torch.cuda.empty_cache()
model = model.to(device)
print("Number of parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))

os.makedirs(config['model']['save_dir'], exist_ok=True)
model_path = f"{config['model']['save_dir']}/model_state_dict.pt"

if config['model']['load_weights']:
    model.load_state_dict(torch.load(model_path))
    print("Loaded pre-trained weights...")
    
    
# criterion_dice = DiceLoss()
criterion_dice = DiceLossWithLogtis()
# criterion_ce  = BCELoss()
criterion_ce  = CrossEntropyLoss()


def criterion(preds, masks):
    c_dice = criterion_dice(preds, masks)
    c_ce = criterion_ce(preds, masks)
    return 0.5*c_dice + 0.5*c_ce

tr_prms = config['training']
optimizer = globals()[tr_prms['optimizer']['name']](model.parameters(), **tr_prms['optimizer']['params'])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', **tr_prms['scheduler'])
# Out:
# Number of parameters: 1946914

# %% [markdown]
# ## Start traning

# %%
best_model, model, res = train(
    model, 
    device, 
    tr_dataloader,
    vl_dataloader,
    config,
    
    criterion,
    optimizer,
    scheduler,

    save_dir = config['model']['save_dir'],
    save_file_id = None,
)
# Out:
# Training) ep:000, batch:0114 -> curr_mean-loss:0.03081, mean_batch-loss:0.03933: : 114it [00:09, 12.16it/s]
# Training) ep:001, batch:0114 -> curr_mean-loss:0.02182, mean_batch-loss:0.05685: : 114it [00:08, 13.86it/s]
# Training) ep:002, batch:0114 -> curr_mean-loss:0.01545, mean_batch-loss:0.02481: : 114it [00:08, 13.78it/s]
# Training) ep:003, batch:0114 -> curr_mean-loss:0.01410, mean_batch-loss:0.01734: : 114it [00:08, 13.81it/s]
# Training) ep:004, batch:0114 -> curr_mean-loss:0.01284, mean_batch-loss:0.02524: : 114it [00:08, 13.75it/s]
# Training) ep:005, batch:0114 -> curr_mean-loss:0.01229, mean_batch-loss:0.02333: : 114it [00:08, 13.80it/s]
# Training) ep:006, batch:0114 -> curr_mean-loss:0.01157, mean_batch-loss:0.03414: : 114it [00:08, 13.77it/s]
# Training) ep:007, batch:0114 -> curr_mean-loss:0.01124, mean_batch-loss:0.02176: : 114it [00:08, 13.66it/s]
# Training) ep:008, batch:0114 -> curr_mean-loss:0.01101, mean_batch-loss:0.02401: : 114it [00:08, 13.71it/s]
# Training) ep:009, batch:0114 -> curr_mean-loss:0.01066, mean_batch-loss:0.03968: : 114it [00:08, 13.85it/s]
# Training) ep:010, batch:0114 -> curr_mean-loss:0.01071, mean_batch-loss:0.01596: : 114it [00:08, 13.77it/s]
# Training) ep:011, batch:0114 -> curr_mean-loss:0.01013, mean_batch-loss:0.02609: : 114it [00:08, 13.85it/s]
# Training) ep:012, batch:0114 -> curr_mean-loss:0.01005, mean_batch-loss:0.01310: : 114it [00:08, 13.76it/s]
# Training) ep:013, batch:0114 -> curr_mean-loss:0.00985, mean_batch-loss:0.01523: : 114it [00:08, 13.88it/s]
# Training) ep:014, batch:0114 -> curr_mean-loss:0.01008, mean_batch-loss:0.02186: : 114it [00:08, 13.73it/s]
# Training) ep:015, batch:0114 -> curr_mean-loss:0.00981, mean_batch-loss:0.01859: : 114it [00:08, 13.81it/s]
# Training) ep:016, batch:0114 -> curr_mean-loss:0.00989, mean_batch-loss:0.02076: : 114it [00:08, 13.78it/s]
# Training) ep:017, batch:0114 -> curr_mean-loss:0.00949, mean_batch-loss:0.01208: : 114it [00:08, 13.77it/s]
# Training) ep:018, batch:0114 -> curr_mean-loss:0.00945, mean_batch-loss:0.02525: : 114it [00:08, 13.78it/s]
# Training) ep:019, batch:0114 -> curr_mean-loss:0.00928, mean_batch-loss:0.00943: : 114it [00:08, 13.75it/s]
# Training) ep:020, batch:0114 -> curr_mean-loss:0.00921, mean_batch-loss:0.02788: : 114it [00:08, 13.78it/s]
# Training) ep:021, batch:0114 -> curr_mean-loss:0.00932, mean_batch-loss:0.04999: : 114it [00:08, 13.80it/s]
# Training) ep:022, batch:0114 -> curr_mean-loss:0.00930, mean_batch-loss:0.05279: : 114it [00:08, 13.81it/s]
# Training) ep:023, batch:0114 -> curr_mean-loss:0.00896, mean_batch-loss:0.01082: : 114it [00:08, 13.69it/s]
# Training) ep:024, batch:0114 -> curr_mean-loss:0.00898, mean_batch-loss:0.03334: : 114it [00:08, 13.76it/s]
# Training) ep:025, batch:0114 -> curr_mean-loss:0.00896, mean_batch-loss:0.02699: : 114it [00:08, 13.90it/s]
# Training) ep:026, batch:0114 -> curr_mean-loss:0.00865, mean_batch-loss:0.01410: : 114it [00:08, 13.76it/s]
# Training) ep:027, batch:0114 -> curr_mean-loss:0.00892, mean_batch-loss:0.03442: : 114it [00:08, 13.70it/s]
# Training) ep:028, batch:0114 -> curr_mean-loss:0.00874, mean_batch-loss:0.01321: : 114it [00:08, 13.76it/s]
# Training) ep:029, batch:0114 -> curr_mean-loss:0.00868, mean_batch-loss:0.04680: : 114it [00:08, 13.71it/s]
# Training) ep:030, batch:0114 -> curr_mean-loss:0.00863, mean_batch-loss:0.01825: : 114it [00:08, 13.82it/s]
# Training) ep:031, batch:0114 -> curr_mean-loss:0.00870, mean_batch-loss:0.01343: : 114it [00:08, 13.86it/s]
# Training) ep:032, batch:0114 -> curr_mean-loss:0.00849, mean_batch-loss:0.02450: : 114it [00:08, 13.73it/s]
# Training) ep:033, batch:0114 -> curr_mean-loss:0.00839, mean_batch-loss:0.01030: : 114it [00:08, 13.78it/s]
# Training) ep:034, batch:0114 -> curr_mean-loss:0.00840, mean_batch-loss:0.01100: : 114it [00:08, 13.67it/s]
# Training) ep:035, batch:0114 -> curr_mean-loss:0.00825, mean_batch-loss:0.01031: : 114it [00:08, 13.84it/s]
# Training) ep:036, batch:0114 -> curr_mean-loss:0.00846, mean_batch-loss:0.02219: : 114it [00:08, 13.87it/s]
# Training) ep:037, batch:0114 -> curr_mean-loss:0.00852, mean_batch-loss:0.04353: : 114it [00:08, 13.80it/s]
# Training) ep:038, batch:0114 -> curr_mean-loss:0.00825, mean_batch-loss:0.02102: : 114it [00:08, 13.77it/s]
# Training) ep:039, batch:0114 -> curr_mean-loss:0.00815, mean_batch-loss:0.01463: : 114it [00:08, 13.76it/s]
# Training) ep:040, batch:0114 -> curr_mean-loss:0.00820, mean_batch-loss:0.01516: : 114it [00:08, 13.74it/s]
# Training) ep:041, batch:0114 -> curr_mean-loss:0.00837, mean_batch-loss:0.01601: : 114it [00:08, 13.73it/s]
# Training) ep:042, batch:0114 -> curr_mean-loss:0.00809, mean_batch-loss:0.02051: : 114it [00:08, 13.88it/s]
# Training) ep:043, batch:0114 -> curr_mean-loss:0.00829, mean_batch-loss:0.02081: : 114it [00:08, 13.78it/s]
# Training) ep:044, batch:0114 -> curr_mean-loss:0.00812, mean_batch-loss:0.02074: : 114it [00:08, 13.76it/s]
# Training) ep:045, batch:0114 -> curr_mean-loss:0.00793, mean_batch-loss:0.01052: : 114it [00:08, 13.77it/s]
# Training) ep:046, batch:0114 -> curr_mean-loss:0.00817, mean_batch-loss:0.03210: : 114it [00:08, 13.65it/s]
# Training) ep:047, batch:0114 -> curr_mean-loss:0.00831, mean_batch-loss:0.02940: : 114it [00:08, 13.28it/s]
# Training) ep:048, batch:0114 -> curr_mean-loss:0.00779, mean_batch-loss:0.02515: : 114it [00:08, 13.75it/s]
# Training) ep:049, batch:0114 -> curr_mean-loss:0.00787, mean_batch-loss:0.01241: : 114it [00:08, 13.79it/s]
# Training) ep:050, batch:0114 -> curr_mean-loss:0.00775, mean_batch-loss:0.02193: : 114it [00:08, 13.86it/s]
# Training) ep:051, batch:0114 -> curr_mean-loss:0.00785, mean_batch-loss:0.00846: : 114it [00:08, 13.75it/s]
# Training) ep:052, batch:0114 -> curr_mean-loss:0.00759, mean_batch-loss:0.01419: : 114it [00:08, 13.71it/s]
# Training) ep:053, batch:0114 -> curr_mean-loss:0.00764, mean_batch-loss:0.01976: : 114it [00:08, 13.81it/s]
# Training) ep:054, batch:0114 -> curr_mean-loss:0.00769, mean_batch-loss:0.02018: : 114it [00:08, 13.82it/s]
# Training) ep:055, batch:0114 -> curr_mean-loss:0.00751, mean_batch-loss:0.01075: : 114it [00:08, 13.78it/s]
# Training) ep:056, batch:0114 -> curr_mean-loss:0.00750, mean_batch-loss:0.02036: : 114it [00:08, 13.74it/s]
# Training) ep:057, batch:0114 -> curr_mean-loss:0.00712, mean_batch-loss:0.01584: : 114it [00:08, 13.78it/s]
# Training) ep:058, batch:0114 -> curr_mean-loss:0.00706, mean_batch-loss:0.00744: : 114it [00:08, 13.80it/s]
# Training) ep:059, batch:0114 -> curr_mean-loss:0.00697, mean_batch-loss:0.01249: : 114it [00:08, 13.79it/s]
# Training) ep:060, batch:0114 -> curr_mean-loss:0.00702, mean_batch-loss:0.02008: : 114it [00:08, 13.79it/s]
# Training) ep:061, batch:0114 -> curr_mean-loss:0.00701, mean_batch-loss:0.01522: : 114it [00:08, 13.83it/s]
# Training) ep:062, batch:0114 -> curr_mean-loss:0.00698, mean_batch-loss:0.02162: : 114it [00:08, 13.81it/s]
# Training) ep:063, batch:0114 -> curr_mean-loss:0.00700, mean_batch-loss:0.01592: : 114it [00:08, 13.68it/s]
# Training) ep:064, batch:0114 -> curr_mean-loss:0.00690, mean_batch-loss:0.01198: : 114it [00:08, 13.74it/s]
# Training) ep:065, batch:0114 -> curr_mean-loss:0.00692, mean_batch-loss:0.02088: : 114it [00:08, 13.19it/s]
# Training) ep:066, batch:0114 -> curr_mean-loss:0.00686, mean_batch-loss:0.01170: : 114it [00:08, 13.71it/s]
# Training) ep:067, batch:0114 -> curr_mean-loss:0.00677, mean_batch-loss:0.01743: : 114it [00:08, 13.67it/s]
# Training) ep:068, batch:0114 -> curr_mean-loss:0.00679, mean_batch-loss:0.01412: : 114it [00:08, 13.66it/s]
# Training) ep:069, batch:0114 -> curr_mean-loss:0.00680, mean_batch-loss:0.01060: : 114it [00:08, 13.77it/s]
# Training) ep:070, batch:0114 -> curr_mean-loss:0.00675, mean_batch-loss:0.01542: : 114it [00:08, 13.77it/s]
# Training) ep:071, batch:0114 -> curr_mean-loss:0.00666, mean_batch-loss:0.00965: : 114it [00:08, 13.77it/s]
# Training) ep:072, batch:0114 -> curr_mean-loss:0.00678, mean_batch-loss:0.02630: : 114it [00:08, 13.78it/s]
# Training) ep:073, batch:0114 -> curr_mean-loss:0.00655, mean_batch-loss:0.01703: : 114it [00:08, 13.69it/s]
# Training) ep:074, batch:0114 -> curr_mean-loss:0.00657, mean_batch-loss:0.01759: : 114it [00:08, 13.19it/s]
# Training) ep:075, batch:0114 -> curr_mean-loss:0.00645, mean_batch-loss:0.00832: : 114it [00:08, 13.84it/s]
# Training) ep:076, batch:0114 -> curr_mean-loss:0.00640, mean_batch-loss:0.00652: : 114it [00:08, 13.81it/s]
# Training) ep:077, batch:0114 -> curr_mean-loss:0.00627, mean_batch-loss:0.02837: : 114it [00:08, 13.72it/s]
# Training) ep:078, batch:0114 -> curr_mean-loss:0.00617, mean_batch-loss:0.01268: : 114it [00:08, 13.75it/s]
# Training) ep:079, batch:0114 -> curr_mean-loss:0.00611, mean_batch-loss:0.01041: : 114it [00:08, 13.77it/s]
# Training) ep:080, batch:0114 -> curr_mean-loss:0.00608, mean_batch-loss:0.01710: : 114it [00:08, 13.71it/s]
# Training) ep:081, batch:0114 -> curr_mean-loss:0.00607, mean_batch-loss:0.02249: : 114it [00:08, 13.84it/s]
# Training) ep:082, batch:0114 -> curr_mean-loss:0.00606, mean_batch-loss:0.01125: : 114it [00:08, 13.79it/s]
# Training) ep:083, batch:0114 -> curr_mean-loss:0.00601, mean_batch-loss:0.00667: : 114it [00:08, 13.88it/s]
# Training) ep:084, batch:0114 -> curr_mean-loss:0.00602, mean_batch-loss:0.02725: : 114it [00:08, 13.80it/s]
# Training) ep:085, batch:0114 -> curr_mean-loss:0.00611, mean_batch-loss:0.00842: : 114it [00:08, 13.72it/s]
# Training) ep:086, batch:0114 -> curr_mean-loss:0.00595, mean_batch-loss:0.01463: : 114it [00:08, 13.75it/s]
# Training) ep:087, batch:0114 -> curr_mean-loss:0.00596, mean_batch-loss:0.02226: : 114it [00:08, 13.69it/s]
# Training) ep:088, batch:0114 -> curr_mean-loss:0.00581, mean_batch-loss:0.00944: : 114it [00:08, 13.80it/s]
# Training) ep:089, batch:0114 -> curr_mean-loss:0.00573, mean_batch-loss:0.00959: : 114it [00:08, 13.82it/s]
# Training) ep:090, batch:0114 -> curr_mean-loss:0.00575, mean_batch-loss:0.01784: : 114it [00:08, 13.79it/s]
# Training) ep:091, batch:0114 -> curr_mean-loss:0.00566, mean_batch-loss:0.00957: : 114it [00:08, 13.28it/s]
# Training) ep:092, batch:0114 -> curr_mean-loss:0.00562, mean_batch-loss:0.00740: : 114it [00:08, 13.76it/s]
# Training) ep:093, batch:0114 -> curr_mean-loss:0.00563, mean_batch-loss:0.00980: : 114it [00:08, 13.70it/s]
# Training) ep:094, batch:0114 -> curr_mean-loss:0.00565, mean_batch-loss:0.01863: : 114it [00:08, 13.76it/s]
# Training) ep:095, batch:0114 -> curr_mean-loss:0.00561, mean_batch-loss:0.00886: : 114it [00:08, 13.75it/s]
# Training) ep:096, batch:0114 -> curr_mean-loss:0.00562, mean_batch-loss:0.01290: : 114it [00:08, 13.84it/s]
# Training) ep:097, batch:0114 -> curr_mean-loss:0.00560, mean_batch-loss:0.01106: : 114it [00:08, 13.81it/s]
# Training) ep:098, batch:0114 -> curr_mean-loss:0.00555, mean_batch-loss:0.00964: : 114it [00:08, 13.79it/s]
# Training) ep:099, batch:0114 -> curr_mean-loss:0.00547, mean_batch-loss:0.01270: : 114it [00:08, 13.82it/s]

# %%
te_metrics = test(best_model, te_dataloader)
te_metrics.compute()
# Out:
# 100%|██████████| 33/33 [00:01<00:00, 21.93it/s]
# {'test_metrics/F1Score': tensor(0.8647, device='cuda:0'),
#  'test_metrics/Accuracy': tensor(0.9419, device='cuda:0'),
#  'test_metrics/Dice': tensor(0.8647, device='cuda:0'),
#  'test_metrics/Precision': tensor(0.8764, device='cuda:0'),
#  'test_metrics/Recall': tensor(0.8532, device='cuda:0'),
#  'test_metrics/Specificity': tensor(0.9665, device='cuda:0'),
#  'test_metrics/JaccardIndex': tensor(0.8451, device='cuda:0')}

# %%
f"{config['model']['save_dir']}"
# Out:
# '../../saved_models/isic2018_unet'

# %% [markdown]
# # Test the best inferred model
# ----

# %% [markdown]
# ## Load the best model

# %%
best_model = Net(**config['model']['params'])
torch.cuda.empty_cache()
best_model = best_model.to(device)

fn = "best_model_state_dict.pt"
os.makedirs(config['model']['save_dir'], exist_ok=True)
model_path = f"{config['model']['save_dir']}/{fn}"

best_model.load_state_dict(torch.load(model_path))
print("Loaded best model weights...")
# Out:
# Loaded best model weights...

# %% [markdown]
# ## Evaluation

# %%
te_metrics = test(best_model, te_dataloader)
te_metrics.compute()
# Out:
# 100%|██████████| 33/33 [00:01<00:00, 21.84it/s]
# {'test_metrics/F1Score': tensor(0.8647, device='cuda:0'),
#  'test_metrics/Accuracy': tensor(0.9419, device='cuda:0'),
#  'test_metrics/Dice': tensor(0.8647, device='cuda:0'),
#  'test_metrics/Precision': tensor(0.8764, device='cuda:0'),
#  'test_metrics/Recall': tensor(0.8532, device='cuda:0'),
#  'test_metrics/Specificity': tensor(0.9665, device='cuda:0'),
#  'test_metrics/JaccardIndex': tensor(0.8451, device='cuda:0')}

# %% [markdown]
# ## Plot graphs

# %%
result_file_path = f"{config['model']['save_dir']}/result.json"
with open(result_file_path, 'r') as f:
    results = json.loads(''.join(f.readlines()))
epochs_info = results['epochs_info']

tr_losses = [d['tr_loss'] for d in epochs_info]
vl_losses = [d['vl_loss'] for d in epochs_info]
tr_dice = [d['tr_metrics']['train_metrics/Dice'] for d in epochs_info]
vl_dice = [d['vl_metrics']['valid_metrics/Dice'] for d in epochs_info]
tr_js = [d['tr_metrics']['train_metrics/JaccardIndex'] for d in epochs_info]
vl_js = [d['vl_metrics']['valid_metrics/JaccardIndex'] for d in epochs_info]
tr_acc = [d['tr_metrics']['train_metrics/Accuracy'] for d in epochs_info]
vl_acc = [d['vl_metrics']['valid_metrics/Accuracy'] for d in epochs_info]


_, axs = plt.subplots(1, 4, figsize=[16,3])

axs[0].set_title("Loss")
axs[0].plot(tr_losses, 'r-', label="train loss")
axs[0].plot(vl_losses, 'b-', label="validatiton loss")
axs[0].legend()

axs[1].set_title("Dice score")
axs[1].plot(tr_dice, 'r-', label="train dice")
axs[1].plot(vl_dice, 'b-', label="validation dice")
axs[1].legend()

axs[2].set_title("Jaccard Similarity")
axs[2].plot(tr_js, 'r-', label="train JaccardIndex")
axs[2].plot(vl_js, 'b-', label="validatiton JaccardIndex")
axs[2].legend()

axs[3].set_title("Accuracy")
axs[3].plot(tr_acc, 'r-', label="train Accuracy")
axs[3].plot(vl_acc, 'b-', label="validation Accuracy")
axs[3].legend()

plt.show()

# %%
epochs_info
# Out:
# [{'tr_loss': 0.03080544790288962,
#   'vl_loss': 0.026620057098653786,
#   'tr_metrics': {'train_metrics/F1Score': 0.1894146353006363,
#    'train_metrics/Accuracy': 0.709731936454773,
#    'train_metrics/Dice': 0.1894146203994751,
#    'train_metrics/Precision': 0.23030272126197815,
#    'train_metrics/Recall': 0.16085611283779144,
#    'train_metrics/Specificity': 0.8563724160194397,
#    'train_metrics/JaccardIndex': 0.40207862854003906},
#   'vl_metrics': {'valid_metrics/F1Score': 0.40790417790412903,
#    'valid_metrics/Accuracy': 0.8228244781494141,
#    'valid_metrics/Dice': 0.40790417790412903,
#    'valid_metrics/Precision': 0.8712656497955322,
#    'valid_metrics/Recall': 0.26628628373146057,
#    'valid_metrics/Specificity': 0.9883013963699341,
#    'valid_metrics/JaccardIndex': 0.5337573289871216}},
#  {'tr_loss': 0.0218214010157861,
#   'vl_loss': 0.019737233181257505,
#   'tr_metrics': {'train_metrics/F1Score': 0.6243214011192322,
#    'train_metrics/Accuracy': 0.8673936724662781,
#    'train_metrics/Dice': 0.6243213415145874,
#    'train_metrics/Precision': 0.7751854658126831,
#    'train_metrics/Recall': 0.5226122736930847,
#    'train_metrics/Specificity': 0.9595072269439697,
#    'train_metrics/JaccardIndex': 0.6524004936218262},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7031920552253723,
#    'valid_metrics/Accuracy': 0.8812494277954102,
#    'valid_metrics/Dice': 0.7031920552253723,
#    'valid_metrics/Precision': 0.8230950832366943,
#    'valid_metrics/Recall': 0.6137805581092834,
#    'valid_metrics/Specificity': 0.9607766270637512,
#    'valid_metrics/JaccardIndex': 0.702029287815094}},
#  {'tr_loss': 0.015451378484074406,
#   'vl_loss': 0.015665106216452757,
#   'tr_metrics': {'train_metrics/F1Score': 0.7497043013572693,
#    'train_metrics/Accuracy': 0.9039105772972107,
#    'train_metrics/Dice': 0.7497043609619141,
#    'train_metrics/Precision': 0.8315120935440063,
#    'train_metrics/Recall': 0.682551920413971,
#    'train_metrics/Specificity': 0.9630499482154846,
#    'train_metrics/JaccardIndex': 0.7436898946762085},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7642626166343689,
#    'valid_metrics/Accuracy': 0.905440092086792,
#    'valid_metrics/Dice': 0.7642626166343689,
#    'valid_metrics/Precision': 0.8915044069290161,
#    'valid_metrics/Recall': 0.6688059568405151,
#    'valid_metrics/Specificity': 0.9757991433143616,
#    'valid_metrics/JaccardIndex': 0.753394365310669}},
#  {'tr_loss': 0.014096900631901974,
#   'vl_loss': 0.014050996441638607,
#   'tr_metrics': {'train_metrics/F1Score': 0.7715958952903748,
#    'train_metrics/Accuracy': 0.9100154638290405,
#    'train_metrics/Dice': 0.7715958952903748,
#    'train_metrics/Precision': 0.8299560546875,
#    'train_metrics/Recall': 0.7209039330482483,
#    'train_metrics/Specificity': 0.9605394601821899,
#    'train_metrics/JaccardIndex': 0.7610077857971191},
#   'vl_metrics': {'valid_metrics/F1Score': 0.796029806137085,
#    'valid_metrics/Accuracy': 0.9116002917289734,
#    'valid_metrics/Dice': 0.7960298657417297,
#    'valid_metrics/Precision': 0.8447170257568359,
#    'valid_metrics/Recall': 0.7526492476463318,
#    'valid_metrics/Specificity': 0.9588615894317627,
#    'valid_metrics/JaccardIndex': 0.7771717309951782}},
#  {'tr_loss': 0.012835375500776222,
#   'vl_loss': 0.014143656349550343,
#   'tr_metrics': {'train_metrics/F1Score': 0.7880205512046814,
#    'train_metrics/Accuracy': 0.9152140617370605,
#    'train_metrics/Dice': 0.7880205512046814,
#    'train_metrics/Precision': 0.8332284092903137,
#    'train_metrics/Recall': 0.7474658489227295,
#    'train_metrics/Specificity': 0.9600305557250977,
#    'train_metrics/JaccardIndex': 0.7747728824615479},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7955787777900696,
#    'valid_metrics/Accuracy': 0.9127136468887329,
#    'valid_metrics/Dice': 0.7955787777900696,
#    'valid_metrics/Precision': 0.8586896657943726,
#    'valid_metrics/Recall': 0.7411095499992371,
#    'valid_metrics/Specificity': 0.9637371301651001,
#    'valid_metrics/JaccardIndex': 0.7777014970779419}},
#  {'tr_loss': 0.012293448921077508,
#   'vl_loss': 0.012704153261129461,
#   'tr_metrics': {'train_metrics/F1Score': 0.7950964570045471,
#    'train_metrics/Accuracy': 0.9181920289993286,
#    'train_metrics/Dice': 0.7950965166091919,
#    'train_metrics/Precision': 0.8424066305160522,
#    'train_metrics/Recall': 0.7528177499771118,
#    'train_metrics/Specificity': 0.9623742699623108,
#    'train_metrics/JaccardIndex': 0.7813207507133484},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8052433729171753,
#    'valid_metrics/Accuracy': 0.9167811274528503,
#    'valid_metrics/Dice': 0.8052433729171753,
#    'valid_metrics/Precision': 0.8684043884277344,
#    'valid_metrics/Recall': 0.7506471276283264,
#    'valid_metrics/Specificity': 0.9661781191825867,
#    'valid_metrics/JaccardIndex': 0.7867352366447449}},
#  {'tr_loss': 0.01156646550194291,
#   'vl_loss': 0.012667404696287797,
#   'tr_metrics': {'train_metrics/F1Score': 0.8069908022880554,
#    'train_metrics/Accuracy': 0.9223059415817261,
#    'train_metrics/Dice': 0.8069908022880554,
#    'train_metrics/Precision': 0.8472619652748108,
#    'train_metrics/Recall': 0.7703742384910583,
#    'train_metrics/Specificity': 0.9628968834877014,
#    'train_metrics/JaccardIndex': 0.7918362617492676},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8219974040985107,
#    'valid_metrics/Accuracy': 0.9190852642059326,
#    'valid_metrics/Dice': 0.8219974040985107,
#    'valid_metrics/Precision': 0.828935444355011,
#    'valid_metrics/Recall': 0.8151745200157166,
#    'valid_metrics/Specificity': 0.9499813318252563,
#    'valid_metrics/JaccardIndex': 0.799142062664032}},
#  {'tr_loss': 0.011239771926698606,
#   'vl_loss': 0.012540579359964055,
#   'tr_metrics': {'train_metrics/F1Score': 0.8112555742263794,
#    'train_metrics/Accuracy': 0.9244359731674194,
#    'train_metrics/Dice': 0.8112555146217346,
#    'train_metrics/Precision': 0.8568928837776184,
#    'train_metrics/Recall': 0.770233690738678,
#    'train_metrics/Specificity': 0.9656333923339844,
#    'train_metrics/JaccardIndex': 0.7961165904998779},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8192293047904968,
#    'valid_metrics/Accuracy': 0.9209380745887756,
#    'valid_metrics/Dice': 0.819229245185852,
#    'valid_metrics/Precision': 0.8605794906616211,
#    'valid_metrics/Recall': 0.7816705703735352,
#    'valid_metrics/Specificity': 0.9623467922210693,
#    'valid_metrics/JaccardIndex': 0.7987459301948547}},
#  {'tr_loss': 0.011014717977401639,
#   'vl_loss': 0.012340936709094691,
#   'tr_metrics': {'train_metrics/F1Score': 0.8154917359352112,
#    'train_metrics/Accuracy': 0.926142156124115,
#    'train_metrics/Dice': 0.815491795539856,
#    'train_metrics/Precision': 0.8615007996559143,
#    'train_metrics/Recall': 0.7741478681564331,
#    'train_metrics/Specificity': 0.9667497873306274,
#    'train_metrics/JaccardIndex': 0.8001000881195068},
#   'vl_metrics': {'valid_metrics/F1Score': 0.817342221736908,
#    'valid_metrics/Accuracy': 0.9204321503639221,
#    'valid_metrics/Dice': 0.817342221736908,
#    'valid_metrics/Precision': 0.8624082803726196,
#    'valid_metrics/Recall': 0.776752233505249,
#    'valid_metrics/Specificity': 0.9631528258323669,
#    'valid_metrics/JaccardIndex': 0.7971528768539429}},
#  {'tr_loss': 0.010655513578209996,
#   'vl_loss': 0.011398393445033364,
#   'tr_metrics': {'train_metrics/F1Score': 0.8212170600891113,
#    'train_metrics/Accuracy': 0.9280201196670532,
#    'train_metrics/Dice': 0.8212170600891113,
#    'train_metrics/Precision': 0.8620331883430481,
#    'train_metrics/Recall': 0.7840913534164429,
#    'train_metrics/Specificity': 0.966472864151001,
#    'train_metrics/JaccardIndex': 0.805214524269104},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8323757648468018,
#    'valid_metrics/Accuracy': 0.9252226948738098,
#    'valid_metrics/Dice': 0.8323757648468018,
#    'valid_metrics/Precision': 0.8559261560440063,
#    'valid_metrics/Recall': 0.8100866079330444,
#    'valid_metrics/Specificity': 0.9594563841819763,
#    'valid_metrics/JaccardIndex': 0.810526967048645}},
#  {'tr_loss': 0.010711162736429,
#   'vl_loss': 0.011714972613170801,
#   'tr_metrics': {'train_metrics/F1Score': 0.8216704726219177,
#    'train_metrics/Accuracy': 0.9281801581382751,
#    'train_metrics/Dice': 0.8216705322265625,
#    'train_metrics/Precision': 0.8622120022773743,
#    'train_metrics/Recall': 0.7847703695297241,
#    'train_metrics/Specificity': 0.9664943218231201,
#    'train_metrics/JaccardIndex': 0.8056294918060303},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8315442204475403,
#    'valid_metrics/Accuracy': 0.9260910749435425,
#    'valid_metrics/Dice': 0.8315442204475403,
#    'valid_metrics/Precision': 0.8704935312271118,
#    'valid_metrics/Recall': 0.7959311604499817,
#    'valid_metrics/Specificity': 0.9647918343544006,
#    'valid_metrics/JaccardIndex': 0.810630738735199}},
#  {'tr_loss': 0.010128958913248762,
#   'vl_loss': 0.01198786896973503,
#   'tr_metrics': {'train_metrics/F1Score': 0.8290261626243591,
#    'train_metrics/Accuracy': 0.9310466647148132,
#    'train_metrics/Dice': 0.8290261626243591,
#    'train_metrics/Precision': 0.8686034083366394,
#    'train_metrics/Recall': 0.7928983569145203,
#    'train_metrics/Specificity': 0.9679551124572754,
#    'train_metrics/JaccardIndex': 0.8125928640365601},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8323546051979065,
#    'valid_metrics/Accuracy': 0.9247347116470337,
#    'valid_metrics/Dice': 0.8323546051979065,
#    'valid_metrics/Precision': 0.8501933217048645,
#    'valid_metrics/Recall': 0.8152490854263306,
#    'valid_metrics/Specificity': 0.957288384437561,
#    'valid_metrics/JaccardIndex': 0.8101446628570557}},
#  {'tr_loss': 0.01005477799364358,
#   'vl_loss': 0.012031056821116149,
#   'tr_metrics': {'train_metrics/F1Score': 0.8311761021614075,
#    'train_metrics/Accuracy': 0.9315454363822937,
#    'train_metrics/Dice': 0.8311761021614075,
#    'train_metrics/Precision': 0.8657532930374146,
#    'train_metrics/Recall': 0.7992547750473022,
#    'train_metrics/Specificity': 0.9668889045715332,
#    'train_metrics/JaccardIndex': 0.8143969774246216},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8354299664497375,
#    'valid_metrics/Accuracy': 0.9267861247062683,
#    'valid_metrics/Dice': 0.8354300260543823,
#    'valid_metrics/Precision': 0.8615652918815613,
#    'valid_metrics/Recall': 0.8108336329460144,
#    'valid_metrics/Specificity': 0.961262583732605,
#    'valid_metrics/JaccardIndex': 0.8137235641479492}},
#  {'tr_loss': 0.009849673993988142,
#   'vl_loss': 0.010684782818937854,
#   'tr_metrics': {'train_metrics/F1Score': 0.8348773121833801,
#    'train_metrics/Accuracy': 0.9332265853881836,
#    'train_metrics/Dice': 0.8348773121833801,
#    'train_metrics/Precision': 0.8721615076065063,
#    'train_metrics/Recall': 0.8006502389907837,
#    'train_metrics/Specificity': 0.9686464667320251,
#    'train_metrics/JaccardIndex': 0.8181115388870239},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8324523568153381,
#    'valid_metrics/Accuracy': 0.9282419085502625,
#    'valid_metrics/Dice': 0.8324523568153381,
#    'valid_metrics/Precision': 0.895358681678772,
#    'valid_metrics/Recall': 0.7778051495552063,
#    'valid_metrics/Specificity': 0.9729716777801514,
#    'valid_metrics/JaccardIndex': 0.8128336668014526}},
#  {'tr_loss': 0.010075156099211743,
#   'vl_loss': 0.011633546224662237,
#   'tr_metrics': {'train_metrics/F1Score': 0.8324499130249023,
#    'train_metrics/Accuracy': 0.932044267654419,
#    'train_metrics/Dice': 0.8324499130249023,
#    'train_metrics/Precision': 0.8668369650840759,
#    'train_metrics/Recall': 0.8006870150566101,
#    'train_metrics/Specificity': 0.9671384692192078,
#    'train_metrics/JaccardIndex': 0.8156155347824097},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8160923719406128,
#    'valid_metrics/Accuracy': 0.9236999154090881,
#    'valid_metrics/Dice': 0.8160923719406128,
#    'valid_metrics/Precision': 0.9116626977920532,
#    'valid_metrics/Recall': 0.7386582493782043,
#    'valid_metrics/Specificity': 0.9787188172340393,
#    'valid_metrics/JaccardIndex': 0.7987357974052429}},
#  {'tr_loss': 0.009807805331121135,
#   'vl_loss': 0.010619656287104927,
#   'tr_metrics': {'train_metrics/F1Score': 0.8365156650543213,
#    'train_metrics/Accuracy': 0.9336451888084412,
#    'train_metrics/Dice': 0.8365156650543213,
#    'train_metrics/Precision': 0.8703869581222534,
#    'train_metrics/Recall': 0.8051818609237671,
#    'train_metrics/Specificity': 0.9679661393165588,
#    'train_metrics/JaccardIndex': 0.819525957107544},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8337559700012207,
#    'valid_metrics/Accuracy': 0.9280809760093689,
#    'valid_metrics/Dice': 0.8337559103965759,
#    'valid_metrics/Precision': 0.8865543007850647,
#    'valid_metrics/Recall': 0.786892831325531,
#    'valid_metrics/Specificity': 0.9700607657432556,
#    'valid_metrics/JaccardIndex': 0.8135818243026733}},
#  {'tr_loss': 0.009888775860146715,
#   'vl_loss': 0.01073021036087316,
#   'tr_metrics': {'train_metrics/F1Score': 0.8349146246910095,
#    'train_metrics/Accuracy': 0.9330393075942993,
#    'train_metrics/Dice': 0.8349146246910095,
#    'train_metrics/Precision': 0.8693374991416931,
#    'train_metrics/Recall': 0.8031139969825745,
#    'train_metrics/Specificity': 0.9677508473396301,
#    'train_metrics/JaccardIndex': 0.8180012106895447},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8410525918006897,
#    'valid_metrics/Accuracy': 0.930719256401062,
#    'valid_metrics/Dice': 0.8410525918006897,
#    'valid_metrics/Precision': 0.8868375420570374,
#    'valid_metrics/Recall': 0.799763023853302,
#    'valid_metrics/Specificity': 0.969656765460968,
#    'valid_metrics/JaccardIndex': 0.8204370737075806}},
#  {'tr_loss': 0.009486328997231055,
#   'vl_loss': 0.011009056509461643,
#   'tr_metrics': {'train_metrics/F1Score': 0.8416936993598938,
#    'train_metrics/Accuracy': 0.9358162879943848,
#    'train_metrics/Dice': 0.841693639755249,
#    'train_metrics/Precision': 0.8768001198768616,
#    'train_metrics/Recall': 0.8092902898788452,
#    'train_metrics/Specificity': 0.9696195721626282,
#    'train_metrics/JaccardIndex': 0.8246352672576904},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8374848961830139,
#    'valid_metrics/Accuracy': 0.9288073778152466,
#    'valid_metrics/Dice': 0.8374848961830139,
#    'valid_metrics/Precision': 0.8781947493553162,
#    'valid_metrics/Recall': 0.800382137298584,
#    'valid_metrics/Specificity': 0.9669923186302185,
#    'valid_metrics/JaccardIndex': 0.8166109919548035}},
#  {'tr_loss': 0.00944873514090031,
#   'vl_loss': 0.009860066373375852,
#   'tr_metrics': {'train_metrics/F1Score': 0.8431723117828369,
#    'train_metrics/Accuracy': 0.9361734390258789,
#    'train_metrics/Dice': 0.8431722521781921,
#    'train_metrics/Precision': 0.8747420310974121,
#    'train_metrics/Recall': 0.8138018846511841,
#    'train_metrics/Specificity': 0.9688668847084045,
#    'train_metrics/JaccardIndex': 0.8259099721908569},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8461229205131531,
#    'valid_metrics/Accuracy': 0.9319363236427307,
#    'valid_metrics/Dice': 0.8461229205131531,
#    'valid_metrics/Precision': 0.8779815435409546,
#    'valid_metrics/Recall': 0.8164953589439392,
#    'valid_metrics/Specificity': 0.9662606716156006,
#    'valid_metrics/JaccardIndex': 0.8247771263122559}},
#  {'tr_loss': 0.009275307553530397,
#   'vl_loss': 0.010326156572485522,
#   'tr_metrics': {'train_metrics/F1Score': 0.8449789881706238,
#    'train_metrics/Accuracy': 0.9369121193885803,
#    'train_metrics/Dice': 0.8449789881706238,
#    'train_metrics/Precision': 0.8766680955886841,
#    'train_metrics/Recall': 0.8155009150505066,
#    'train_metrics/Specificity': 0.9693490862846375,
#    'train_metrics/JaccardIndex': 0.8276914358139038},
#   'vl_metrics': {'valid_metrics/F1Score': 0.851292073726654,
#    'valid_metrics/Accuracy': 0.9320570826530457,
#    'valid_metrics/Dice': 0.851292073726654,
#    'valid_metrics/Precision': 0.8540711402893066,
#    'valid_metrics/Recall': 0.8485310673713684,
#    'valid_metrics/Specificity': 0.9568920731544495,
#    'valid_metrics/JaccardIndex': 0.8283703923225403}},
#  {'tr_loss': 0.009209627598606194,
#   'vl_loss': 0.010334676555915228,
#   'tr_metrics': {'train_metrics/F1Score': 0.8476507067680359,
#    'train_metrics/Accuracy': 0.9378005266189575,
#    'train_metrics/Dice': 0.8476507067680359,
#    'train_metrics/Precision': 0.8764262795448303,
#    'train_metrics/Recall': 0.8207046389579773,
#    'train_metrics/Specificity': 0.9690845012664795,
#    'train_metrics/JaccardIndex': 0.8301853537559509},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8358901143074036,
#    'valid_metrics/Accuracy': 0.9313071966171265,
#    'valid_metrics/Dice': 0.8358901739120483,
#    'valid_metrics/Precision': 0.9237133264541626,
#    'valid_metrics/Recall': 0.7633169293403625,
#    'valid_metrics/Specificity': 0.9812561869621277,
#    'valid_metrics/JaccardIndex': 0.8173964023590088}},
#  {'tr_loss': 0.009316529210441368,
#   'vl_loss': 0.011465955511253312,
#   'tr_metrics': {'train_metrics/F1Score': 0.8469780683517456,
#    'train_metrics/Accuracy': 0.938031017780304,
#    'train_metrics/Dice': 0.8469780683517456,
#    'train_metrics/Precision': 0.8834207653999329,
#    'train_metrics/Recall': 0.8134228587150574,
#    'train_metrics/Specificity': 0.9713220000267029,
#    'train_metrics/JaccardIndex': 0.829887866973877},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8381887078285217,
#    'valid_metrics/Accuracy': 0.9219943284988403,
#    'valid_metrics/Dice': 0.8381887078285217,
#    'valid_metrics/Precision': 0.7989078760147095,
#    'valid_metrics/Recall': 0.8815320730209351,
#    'valid_metrics/Specificity': 0.9340251088142395,
#    'valid_metrics/JaccardIndex': 0.8118470907211304}},
#  {'tr_loss': 0.0092962578595834,
#   'vl_loss': 0.010446028848642548,
#   'tr_metrics': {'train_metrics/F1Score': 0.8459298014640808,
#    'train_metrics/Accuracy': 0.937139630317688,
#    'train_metrics/Dice': 0.8459298014640808,
#    'train_metrics/Precision': 0.8752681016921997,
#    'train_metrics/Recall': 0.8184945583343506,
#    'train_metrics/Specificity': 0.9688376188278198,
#    'train_metrics/JaccardIndex': 0.8285132646560669},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8494206070899963,
#    'valid_metrics/Accuracy': 0.9291250109672546,
#    'valid_metrics/Dice': 0.8494206666946411,
#    'valid_metrics/Precision': 0.8277767300605774,
#    'valid_metrics/Recall': 0.8722268342971802,
#    'valid_metrics/Specificity': 0.9460426568984985,
#    'valid_metrics/JaccardIndex': 0.8248358368873596}},
#  {'tr_loss': 0.008964654608288415,
#   'vl_loss': 0.010655523698532444,
#   'tr_metrics': {'train_metrics/F1Score': 0.850719690322876,
#    'train_metrics/Accuracy': 0.9389370679855347,
#    'train_metrics/Dice': 0.850719690322876,
#    'train_metrics/Precision': 0.8778126239776611,
#    'train_metrics/Recall': 0.8252491354942322,
#    'train_metrics/Specificity': 0.9693105816841125,
#    'train_metrics/JaccardIndex': 0.8331470489501953},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8299343585968018,
#    'valid_metrics/Accuracy': 0.9289970993995667,
#    'valid_metrics/Dice': 0.8299343585968018,
#    'valid_metrics/Precision': 0.919999361038208,
#    'valid_metrics/Recall': 0.7559311389923096,
#    'valid_metrics/Specificity': 0.980455219745636,
#    'valid_metrics/JaccardIndex': 0.8117119073867798}},
#  {'tr_loss': 0.008979166715762503,
#   'vl_loss': 0.011209442262253707,
#   'tr_metrics': {'train_metrics/F1Score': 0.8495393991470337,
#    'train_metrics/Accuracy': 0.9387995600700378,
#    'train_metrics/Dice': 0.8495393991470337,
#    'train_metrics/Precision': 0.8818864226341248,
#    'train_metrics/Recall': 0.819481372833252,
#    'train_metrics/Specificity': 0.9706772565841675,
#    'train_metrics/JaccardIndex': 0.8322255611419678},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8459530472755432,
#    'valid_metrics/Accuracy': 0.927291750907898,
#    'valid_metrics/Dice': 0.8459529876708984,
#    'valid_metrics/Precision': 0.8222395181655884,
#    'valid_metrics/Recall': 0.8710748553276062,
#    'valid_metrics/Specificity': 0.9440068602561951,
#    'valid_metrics/JaccardIndex': 0.8210936784744263}},
#  {'tr_loss': 0.008960144098632591,
#   'vl_loss': 0.009805227798844856,
#   'tr_metrics': {'train_metrics/F1Score': 0.851550281047821,
#    'train_metrics/Accuracy': 0.9393560886383057,
#    'train_metrics/Dice': 0.8515502214431763,
#    'train_metrics/Precision': 0.8798924088478088,
#    'train_metrics/Recall': 0.8249770402908325,
#    'train_metrics/Specificity': 0.9699141979217529,
#    'train_metrics/JaccardIndex': 0.8340324759483337},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8562061190605164,
#    'valid_metrics/Accuracy': 0.9353295564651489,
#    'valid_metrics/Dice': 0.8562060594558716,
#    'valid_metrics/Precision': 0.8729597330093384,
#    'valid_metrics/Recall': 0.8400833010673523,
#    'valid_metrics/Specificity': 0.9636493921279907,
#    'valid_metrics/JaccardIndex': 0.8342379331588745}},
#  {'tr_loss': 0.008651366476841867,
#   'vl_loss': 0.010118851560423274,
#   'tr_metrics': {'train_metrics/F1Score': 0.8554102778434753,
#    'train_metrics/Accuracy': 0.9408113956451416,
#    'train_metrics/Dice': 0.8554102182388306,
#    'train_metrics/Precision': 0.8819496035575867,
#    'train_metrics/Recall': 0.830421507358551,
#    'train_metrics/Specificity': 0.9703037142753601,
#    'train_metrics/JaccardIndex': 0.8377999067306519},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8463712334632874,
#    'valid_metrics/Accuracy': 0.9342514276504517,
#    'valid_metrics/Dice': 0.8463712334632874,
#    'valid_metrics/Precision': 0.9110993146896362,
#    'valid_metrics/Recall': 0.7902301549911499,
#    'valid_metrics/Specificity': 0.977073609828949,
#    'valid_metrics/JaccardIndex': 0.8266849517822266}},
#  {'tr_loss': 0.008920704076687495,
#   'vl_loss': 0.009372187339661204,
#   'tr_metrics': {'train_metrics/F1Score': 0.8525313138961792,
#    'train_metrics/Accuracy': 0.9398326277732849,
#    'train_metrics/Dice': 0.8525313138961792,
#    'train_metrics/Precision': 0.882091760635376,
#    'train_metrics/Recall': 0.8248878717422485,
#    'train_metrics/Specificity': 0.9705419540405273,
#    'train_metrics/JaccardIndex': 0.8350661993026733},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8566005825996399,
#    'valid_metrics/Accuracy': 0.9358117580413818,
#    'valid_metrics/Dice': 0.8566005825996399,
#    'valid_metrics/Precision': 0.8776918053627014,
#    'valid_metrics/Recall': 0.8364992141723633,
#    'valid_metrics/Specificity': 0.9653405547142029,
#    'valid_metrics/JaccardIndex': 0.8348785638809204}},
#  {'tr_loss': 0.008737404365349078,
#   'vl_loss': 0.009975739628882022,
#   'tr_metrics': {'train_metrics/F1Score': 0.854123592376709,
#    'train_metrics/Accuracy': 0.9404051899909973,
#    'train_metrics/Dice': 0.8541236519813538,
#    'train_metrics/Precision': 0.8825173377990723,
#    'train_metrics/Recall': 0.8274999856948853,
#    'train_metrics/Specificity': 0.9705695509910583,
#    'train_metrics/JaccardIndex': 0.8365997076034546},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8568475842475891,
#    'valid_metrics/Accuracy': 0.9349861741065979,
#    'valid_metrics/Dice': 0.8568475842475891,
#    'valid_metrics/Precision': 0.8648777604103088,
#    'valid_metrics/Recall': 0.8489651679992676,
#    'valid_metrics/Specificity': 0.9605629444122314,
#    'valid_metrics/JaccardIndex': 0.8344141840934753}},
#  {'tr_loss': 0.008682845413849045,
#   'vl_loss': 0.00969607920950444,
#   'tr_metrics': {'train_metrics/F1Score': 0.8559566736221313,
#    'train_metrics/Accuracy': 0.9410579204559326,
#    'train_metrics/Dice': 0.8559566736221313,
#    'train_metrics/Precision': 0.8828762173652649,
#    'train_metrics/Recall': 0.8306301236152649,
#    'train_metrics/Specificity': 0.9705604314804077,
#    'train_metrics/JaccardIndex': 0.8383647203445435},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8493872880935669,
#    'valid_metrics/Accuracy': 0.9355046153068542,
#    'valid_metrics/Dice': 0.8493872284889221,
#    'valid_metrics/Precision': 0.9137322902679443,
#    'valid_metrics/Recall': 0.7935084104537964,
#    'valid_metrics/Specificity': 0.9777247309684753,
#    'valid_metrics/JaccardIndex': 0.829686164855957}},
#  {'tr_loss': 0.008625236580522921,
#   'vl_loss': 0.010008050179159319,
#   'tr_metrics': {'train_metrics/F1Score': 0.8564652800559998,
#    'train_metrics/Accuracy': 0.9414693713188171,
#    'train_metrics/Dice': 0.8564652800559998,
#    'train_metrics/Precision': 0.8866753578186035,
#    'train_metrics/Recall': 0.8282460570335388,
#    'train_metrics/Specificity': 0.9717187285423279,
#    'train_metrics/JaccardIndex': 0.839024543762207},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8552996516227722,
#    'valid_metrics/Accuracy': 0.9327890276908875,
#    'valid_metrics/Dice': 0.8552996516227722,
#    'valid_metrics/Precision': 0.8441968560218811,
#    'valid_metrics/Recall': 0.8666983842849731,
#    'valid_metrics/Specificity': 0.9524399042129517,
#    'valid_metrics/JaccardIndex': 0.8316556811332703}},
#  {'tr_loss': 0.008704345634325148,
#   'vl_loss': 0.0094399410497728,
#   'tr_metrics': {'train_metrics/F1Score': 0.8555200695991516,
#    'train_metrics/Accuracy': 0.9408929347991943,
#    'train_metrics/Dice': 0.8555200695991516,
#    'train_metrics/Precision': 0.8826431632041931,
#    'train_metrics/Recall': 0.8300142288208008,
#    'train_metrics/Specificity': 0.9705159068107605,
#    'train_metrics/JaccardIndex': 0.8379369378089905},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8590043783187866,
#    'valid_metrics/Accuracy': 0.9365845322608948,
#    'valid_metrics/Dice': 0.8590044379234314,
#    'valid_metrics/Precision': 0.8757613301277161,
#    'valid_metrics/Recall': 0.8428767323493958,
#    'valid_metrics/Specificity': 0.9644469022750854,
#    'valid_metrics/JaccardIndex': 0.8371281027793884}},
#  {'tr_loss': 0.008486048815664182,
#   'vl_loss': 0.009355484691365806,
#   'tr_metrics': {'train_metrics/F1Score': 0.8589765429496765,
#    'train_metrics/Accuracy': 0.9422059655189514,
#    'train_metrics/Dice': 0.8589765429496765,
#    'train_metrics/Precision': 0.8845643997192383,
#    'train_metrics/Recall': 0.8348274230957031,
#    'train_metrics/Specificity': 0.9708938002586365,
#    'train_metrics/JaccardIndex': 0.8413364291191101},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8562353849411011,
#    'valid_metrics/Accuracy': 0.936806857585907,
#    'valid_metrics/Dice': 0.8562354445457458,
#    'valid_metrics/Precision': 0.894524872303009,
#    'valid_metrics/Recall': 0.8210893869400024,
#    'valid_metrics/Specificity': 0.9712134003639221,
#    'valid_metrics/JaccardIndex': 0.8353849649429321}},
#  {'tr_loss': 0.008391477179921362,
#   'vl_loss': 0.009549143519180622,
#   'tr_metrics': {'train_metrics/F1Score': 0.8596046566963196,
#    'train_metrics/Accuracy': 0.9424779415130615,
#    'train_metrics/Dice': 0.85960453748703,
#    'train_metrics/Precision': 0.8854485154151917,
#    'train_metrics/Recall': 0.8352265357971191,
#    'train_metrics/Specificity': 0.9711318016052246,
#    'train_metrics/JaccardIndex': 0.8419805765151978},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8565822243690491,
#    'valid_metrics/Accuracy': 0.9336202144622803,
#    'valid_metrics/Dice': 0.8565822243690491,
#    'valid_metrics/Precision': 0.8483940958976746,
#    'valid_metrics/Recall': 0.8649299740791321,
#    'valid_metrics/Specificity': 0.9540440440177917,
#    'valid_metrics/JaccardIndex': 0.8331751823425293}},
#  {'tr_loss': 0.008403001951448845,
#   'vl_loss': 0.009541191246979025,
#   'tr_metrics': {'train_metrics/F1Score': 0.8607257008552551,
#    'train_metrics/Accuracy': 0.9429625272750854,
#    'train_metrics/Dice': 0.8607257008552551,
#    'train_metrics/Precision': 0.8870205879211426,
#    'train_metrics/Recall': 0.8359448909759521,
#    'train_metrics/Specificity': 0.9715539813041687,
#    'train_metrics/JaccardIndex': 0.8431311845779419},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8561078906059265,
#    'valid_metrics/Accuracy': 0.9367621541023254,
#    'valid_metrics/Dice': 0.8561078906059265,
#    'valid_metrics/Precision': 0.8945668339729309,
#    'valid_metrics/Recall': 0.8208194375038147,
#    'valid_metrics/Specificity': 0.9712356328964233,
#    'valid_metrics/JaccardIndex': 0.8352628946304321}},
#  {'tr_loss': 0.008245195752168819,
#   'vl_loss': 0.010842468431327334,
#   'tr_metrics': {'train_metrics/F1Score': 0.8626415133476257,
#    'train_metrics/Accuracy': 0.9436950087547302,
#    'train_metrics/Dice': 0.8626415133476257,
#    'train_metrics/Precision': 0.8881220817565918,
#    'train_metrics/Recall': 0.8385822772979736,
#    'train_metrics/Specificity': 0.9717774987220764,
#    'train_metrics/JaccardIndex': 0.8450312614440918},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8175665140151978,
#    'valid_metrics/Accuracy': 0.9263842105865479,
#    'valid_metrics/Dice': 0.8175665140151978,
#    'valid_metrics/Precision': 0.9461896419525146,
#    'valid_metrics/Recall': 0.7197281122207642,
#    'valid_metrics/Specificity': 0.9878298044204712,
#    'valid_metrics/JaccardIndex': 0.8016347885131836}},
#  {'tr_loss': 0.008457418098101603,
#   'vl_loss': 0.00942563107345095,
#   'tr_metrics': {'train_metrics/F1Score': 0.8595024347305298,
#    'train_metrics/Accuracy': 0.9425778985023499,
#    'train_metrics/Dice': 0.859502375125885,
#    'train_metrics/Precision': 0.8876678943634033,
#    'train_metrics/Recall': 0.8330693244934082,
#    'train_metrics/Specificity': 0.9718347191810608,
#    'train_metrics/JaccardIndex': 0.8419818878173828},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8517208695411682,
#    'valid_metrics/Accuracy': 0.936087429523468,
#    'valid_metrics/Dice': 0.851720929145813,
#    'valid_metrics/Precision': 0.9094182252883911,
#    'valid_metrics/Recall': 0.8009079098701477,
#    'valid_metrics/Specificity': 0.976280689239502,
#    'valid_metrics/JaccardIndex': 0.8317275047302246}},
#  {'tr_loss': 0.008520621781753114,
#   'vl_loss': 0.009306596886927556,
#   'tr_metrics': {'train_metrics/F1Score': 0.8597708344459534,
#    'train_metrics/Accuracy': 0.9426496624946594,
#    'train_metrics/Dice': 0.8597707748413086,
#    'train_metrics/Precision': 0.8873200416564941,
#    'train_metrics/Recall': 0.8338807225227356,
#    'train_metrics/Specificity': 0.9717089533805847,
#    'train_metrics/JaccardIndex': 0.8422245979309082},
#   'vl_metrics': {'valid_metrics/F1Score': 0.857670247554779,
#    'valid_metrics/Accuracy': 0.9372620582580566,
#    'valid_metrics/Dice': 0.857670247554779,
#    'valid_metrics/Precision': 0.8933021426200867,
#    'valid_metrics/Recall': 0.8247718811035156,
#    'valid_metrics/Specificity': 0.9707090854644775,
#    'valid_metrics/JaccardIndex': 0.8367233276367188}},
#  {'tr_loss': 0.008254795186939974,
#   'vl_loss': 0.0096654265428602,
#   'tr_metrics': {'train_metrics/F1Score': 0.862612247467041,
#    'train_metrics/Accuracy': 0.9438844919204712,
#    'train_metrics/Dice': 0.8626121878623962,
#    'train_metrics/Precision': 0.8914825320243835,
#    'train_metrics/Recall': 0.8355530500411987,
#    'train_metrics/Specificity': 0.9728268980979919,
#    'train_metrics/JaccardIndex': 0.8451500535011292},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8602240681648254,
#    'valid_metrics/Accuracy': 0.9354388117790222,
#    'valid_metrics/Dice': 0.8602240085601807,
#    'valid_metrics/Precision': 0.8537268042564392,
#    'valid_metrics/Recall': 0.8668209314346313,
#    'valid_metrics/Specificity': 0.9558411836624146,
#    'valid_metrics/JaccardIndex': 0.8370819091796875}},
#  {'tr_loss': 0.008148431285353731,
#   'vl_loss': 0.009871948093290955,
#   'tr_metrics': {'train_metrics/F1Score': 0.864184558391571,
#    'train_metrics/Accuracy': 0.9442959427833557,
#    'train_metrics/Dice': 0.864184558391571,
#    'train_metrics/Precision': 0.8891775012016296,
#    'train_metrics/Recall': 0.8405581712722778,
#    'train_metrics/Specificity': 0.9720110297203064,
#    'train_metrics/JaccardIndex': 0.846573531627655},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8595314025878906,
#    'valid_metrics/Accuracy': 0.9349145293235779,
#    'valid_metrics/Dice': 0.8595313429832458,
#    'valid_metrics/Precision': 0.8504090309143066,
#    'valid_metrics/Recall': 0.8688515424728394,
#    'valid_metrics/Specificity': 0.9545571804046631,
#    'valid_metrics/JaccardIndex': 0.8361983299255371}},
#  {'tr_loss': 0.008202237518858319,
#   'vl_loss': 0.009601671493191516,
#   'tr_metrics': {'train_metrics/F1Score': 0.8638468980789185,
#    'train_metrics/Accuracy': 0.9443124532699585,
#    'train_metrics/Dice': 0.8638468980789185,
#    'train_metrics/Precision': 0.891454815864563,
#    'train_metrics/Recall': 0.8378976583480835,
#    'train_metrics/Specificity': 0.9727428555488586,
#    'train_metrics/JaccardIndex': 0.8463450074195862},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8580502271652222,
#    'valid_metrics/Accuracy': 0.9367613792419434,
#    'valid_metrics/Dice': 0.8580502271652222,
#    'valid_metrics/Precision': 0.883586049079895,
#    'valid_metrics/Recall': 0.8339488506317139,
#    'valid_metrics/Specificity': 0.9673308730125427,
#    'valid_metrics/JaccardIndex': 0.8366044759750366}},
#  {'tr_loss': 0.008370132557534646,
#   'vl_loss': 0.009455010036013761,
#   'tr_metrics': {'train_metrics/F1Score': 0.860359251499176,
#    'train_metrics/Accuracy': 0.943026065826416,
#    'train_metrics/Dice': 0.860359251499176,
#    'train_metrics/Precision': 0.8901840448379517,
#    'train_metrics/Recall': 0.8324682712554932,
#    'train_metrics/Specificity': 0.9725632667541504,
#    'train_metrics/JaccardIndex': 0.8429182767868042},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8619509935379028,
#    'valid_metrics/Accuracy': 0.9374240636825562,
#    'valid_metrics/Dice': 0.8619510531425476,
#    'valid_metrics/Precision': 0.871734082698822,
#    'valid_metrics/Recall': 0.8523851037025452,
#    'valid_metrics/Specificity': 0.9627088904380798,
#    'valid_metrics/JaccardIndex': 0.8398125171661377}},
#  {'tr_loss': 0.008093743683057054,
#   'vl_loss': 0.00946155486765055,
#   'tr_metrics': {'train_metrics/F1Score': 0.8644805550575256,
#    'train_metrics/Accuracy': 0.9444815516471863,
#    'train_metrics/Dice': 0.8644806146621704,
#    'train_metrics/Precision': 0.8905709385871887,
#    'train_metrics/Recall': 0.8398754000663757,
#    'train_metrics/Specificity': 0.9724286794662476,
#    'train_metrics/JaccardIndex': 0.8469218015670776},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8514888882637024,
#    'valid_metrics/Accuracy': 0.9362359046936035,
#    'valid_metrics/Dice': 0.8514888882637024,
#    'valid_metrics/Precision': 0.9132108092308044,
#    'valid_metrics/Recall': 0.7975820302963257,
#    'valid_metrics/Specificity': 0.9774621725082397,
#    'valid_metrics/JaccardIndex': 0.8316788673400879}},
#  {'tr_loss': 0.008293659718240259,
#   'vl_loss': 0.009427354804107122,
#   'tr_metrics': {'train_metrics/F1Score': 0.862397313117981,
#    'train_metrics/Accuracy': 0.943735659122467,
#    'train_metrics/Dice': 0.8623972535133362,
#    'train_metrics/Precision': 0.8902309536933899,
#    'train_metrics/Recall': 0.8362512588500977,
#    'train_metrics/Specificity': 0.9724518656730652,
#    'train_metrics/JaccardIndex': 0.8448875546455383},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8585458397865295,
#    'valid_metrics/Accuracy': 0.93719482421875,
#    'valid_metrics/Dice': 0.8585458993911743,
#    'valid_metrics/Precision': 0.8872792720794678,
#    'valid_metrics/Recall': 0.8316150903701782,
#    'valid_metrics/Specificity': 0.9685871005058289,
#    'valid_metrics/JaccardIndex': 0.8372783660888672}},
#  {'tr_loss': 0.008120467708787315,
#   'vl_loss': 0.009930471454578017,
#   'tr_metrics': {'train_metrics/F1Score': 0.8648397326469421,
#    'train_metrics/Accuracy': 0.9446700811386108,
#    'train_metrics/Dice': 0.8648397326469421,
#    'train_metrics/Precision': 0.8916491866111755,
#    'train_metrics/Recall': 0.839595377445221,
#    'train_metrics/Specificity': 0.9727423787117004,
#    'train_metrics/JaccardIndex': 0.8473173379898071},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8552553653717041,
#    'valid_metrics/Accuracy': 0.9354580044746399,
#    'valid_metrics/Dice': 0.8552553653717041,
#    'valid_metrics/Precision': 0.879866361618042,
#    'valid_metrics/Recall': 0.831983745098114,
#    'valid_metrics/Specificity': 0.9662242531776428,
#    'valid_metrics/JaccardIndex': 0.8336830735206604}},
#  {'tr_loss': 0.007925383061088477,
#   'vl_loss': 0.00886306756366634,
#   'tr_metrics': {'train_metrics/F1Score': 0.8679749965667725,
#    'train_metrics/Accuracy': 0.9459518194198608,
#    'train_metrics/Dice': 0.8679750561714172,
#    'train_metrics/Precision': 0.894850492477417,
#    'train_metrics/Recall': 0.8426668047904968,
#    'train_metrics/Specificity': 0.9735459685325623,
#    'train_metrics/JaccardIndex': 0.8505100607872009},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8592778444290161,
#    'valid_metrics/Accuracy': 0.9372718334197998,
#    'valid_metrics/Dice': 0.8592777848243713,
#    'valid_metrics/Precision': 0.8843064308166504,
#    'valid_metrics/Recall': 0.8356269598007202,
#    'valid_metrics/Specificity': 0.9674941897392273,
#    'valid_metrics/JaccardIndex': 0.8378439545631409}},
#  {'tr_loss': 0.008166095407130633,
#   'vl_loss': 0.009441025842801024,
#   'tr_metrics': {'train_metrics/F1Score': 0.8655637502670288,
#    'train_metrics/Accuracy': 0.9448949098587036,
#    'train_metrics/Dice': 0.8655637502670288,
#    'train_metrics/Precision': 0.891165018081665,
#    'train_metrics/Recall': 0.841392457485199,
#    'train_metrics/Specificity': 0.9725471138954163,
#    'train_metrics/JaccardIndex': 0.8480008244514465},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8577755093574524,
#    'valid_metrics/Accuracy': 0.9364421963691711,
#    'valid_metrics/Dice': 0.8577755093574524,
#    'valid_metrics/Precision': 0.8804148435592651,
#    'valid_metrics/Recall': 0.8362712264060974,
#    'valid_metrics/Specificity': 0.9662262201309204,
#    'valid_metrics/JaccardIndex': 0.8361706733703613}},
#  {'tr_loss': 0.008308612581947946,
#   'vl_loss': 0.010025677821350835,
#   'tr_metrics': {'train_metrics/F1Score': 0.8625108599662781,
#    'train_metrics/Accuracy': 0.9437593221664429,
#    'train_metrics/Dice': 0.8625108599662781,
#    'train_metrics/Precision': 0.8899641036987305,
#    'train_metrics/Recall': 0.8367006778717041,
#    'train_metrics/Specificity': 0.97236168384552,
#    'train_metrics/JaccardIndex': 0.8449857831001282},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8549175262451172,
#    'valid_metrics/Accuracy': 0.9301536679267883,
#    'valid_metrics/Dice': 0.8549174666404724,
#    'valid_metrics/Precision': 0.8158556818962097,
#    'valid_metrics/Recall': 0.8979077935218811,
#    'valid_metrics/Specificity': 0.9397413730621338,
#    'valid_metrics/JaccardIndex': 0.8293273448944092}},
#  {'tr_loss': 0.007786479013517868,
#   'vl_loss': 0.009060145172373208,
#   'tr_metrics': {'train_metrics/F1Score': 0.8706206679344177,
#    'train_metrics/Accuracy': 0.9469529986381531,
#    'train_metrics/Dice': 0.870620608329773,
#    'train_metrics/Precision': 0.8961102366447449,
#    'train_metrics/Recall': 0.8465410470962524,
#    'train_metrics/Specificity': 0.9737796187400818,
#    'train_metrics/JaccardIndex': 0.8531560897827148},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8642075657844543,
#    'valid_metrics/Accuracy': 0.9384591579437256,
#    'valid_metrics/Dice': 0.8642076253890991,
#    'valid_metrics/Precision': 0.8741941452026367,
#    'valid_metrics/Recall': 0.8544465899467468,
#    'valid_metrics/Specificity': 0.9634388089179993,
#    'valid_metrics/JaccardIndex': 0.8421790599822998}},
#  {'tr_loss': 0.00786982945092125,
#   'vl_loss': 0.008967795484774822,
#   'tr_metrics': {'train_metrics/F1Score': 0.868650496006012,
#    'train_metrics/Accuracy': 0.9460886120796204,
#    'train_metrics/Dice': 0.868650496006012,
#    'train_metrics/Precision': 0.8930884599685669,
#    'train_metrics/Recall': 0.8455142974853516,
#    'train_metrics/Specificity': 0.9729585647583008,
#    'train_metrics/JaccardIndex': 0.8510967493057251},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8639875650405884,
#    'valid_metrics/Accuracy': 0.9390800595283508,
#    'valid_metrics/Dice': 0.8639875650405884,
#    'valid_metrics/Precision': 0.884678304195404,
#    'valid_metrics/Recall': 0.8442425727844238,
#    'valid_metrics/Specificity': 0.9672783613204956,
#    'valid_metrics/JaccardIndex': 0.8425044417381287}},
#  {'tr_loss': 0.007749742285936004,
#   'vl_loss': 0.009545844062645003,
#   'tr_metrics': {'train_metrics/F1Score': 0.8713703155517578,
#    'train_metrics/Accuracy': 0.9472393989562988,
#    'train_metrics/Dice': 0.8713703155517578,
#    'train_metrics/Precision': 0.8965032696723938,
#    'train_metrics/Recall': 0.8476081490516663,
#    'train_metrics/Specificity': 0.9738574028015137,
#    'train_metrics/JaccardIndex': 0.8539097309112549},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8554166555404663,
#    'valid_metrics/Accuracy': 0.9360127449035645,
#    'valid_metrics/Dice': 0.8554166555404663,
#    'valid_metrics/Precision': 0.887111246585846,
#    'valid_metrics/Recall': 0.8259087204933167,
#    'valid_metrics/Specificity': 0.9687502384185791,
#    'valid_metrics/JaccardIndex': 0.8342167139053345}},
#  {'tr_loss': 0.00785185039536027,
#   'vl_loss': 0.009298986046930998,
#   'tr_metrics': {'train_metrics/F1Score': 0.8688439130783081,
#    'train_metrics/Accuracy': 0.9463079571723938,
#    'train_metrics/Dice': 0.8688438534736633,
#    'train_metrics/Precision': 0.8957539796829224,
#    'train_metrics/Recall': 0.843503475189209,
#    'train_metrics/Specificity': 0.973773717880249,
#    'train_metrics/JaccardIndex': 0.8513981103897095},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8506581783294678,
#    'valid_metrics/Accuracy': 0.9370140433311462,
#    'valid_metrics/Dice': 0.850658118724823,
#    'valid_metrics/Precision': 0.931537389755249,
#    'valid_metrics/Recall': 0.782701313495636,
#    'valid_metrics/Specificity': 0.9828962683677673,
#    'valid_metrics/JaccardIndex': 0.8316859006881714}},
#  {'tr_loss': 0.007593754912949791,
#   'vl_loss': 0.008877041861127243,
#   'tr_metrics': {'train_metrics/F1Score': 0.8740271925926208,
#    'train_metrics/Accuracy': 0.9483141899108887,
#    'train_metrics/Dice': 0.8740273118019104,
#    'train_metrics/Precision': 0.8989607095718384,
#    'train_metrics/Recall': 0.8504396080970764,
#    'train_metrics/Specificity': 0.9744628667831421,
#    'train_metrics/JaccardIndex': 0.8566319942474365},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8585023283958435,
#    'valid_metrics/Accuracy': 0.9387466311454773,
#    'valid_metrics/Dice': 0.8585023283958435,
#    'valid_metrics/Precision': 0.9121986627578735,
#    'valid_metrics/Recall': 0.8107762336730957,
#    'valid_metrics/Specificity': 0.9767963886260986,
#    'valid_metrics/JaccardIndex': 0.8384255170822144}},
#  {'tr_loss': 0.007644134579282818,
#   'vl_loss': 0.009443214788860337,
#   'tr_metrics': {'train_metrics/F1Score': 0.8723623752593994,
#    'train_metrics/Accuracy': 0.9476901292800903,
#    'train_metrics/Dice': 0.8723623752593994,
#    'train_metrics/Precision': 0.8983201384544373,
#    'train_metrics/Recall': 0.8478626608848572,
#    'train_metrics/Specificity': 0.9743605852127075,
#    'train_metrics/JaccardIndex': 0.8549615740776062},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8551620841026306,
#    'valid_metrics/Accuracy': 0.9363936185836792,
#    'valid_metrics/Dice': 0.8551620841026306,
#    'valid_metrics/Precision': 0.8943007588386536,
#    'valid_metrics/Recall': 0.8193055391311646,
#    'valid_metrics/Specificity': 0.9712076783180237,
#    'valid_metrics/JaccardIndex': 0.8343304395675659}},
#  {'tr_loss': 0.007686734675704283,
#   'vl_loss': 0.009133134828341053,
#   'tr_metrics': {'train_metrics/F1Score': 0.870927095413208,
#    'train_metrics/Accuracy': 0.9470163583755493,
#    'train_metrics/Dice': 0.870927095413208,
#    'train_metrics/Precision': 0.8953104019165039,
#    'train_metrics/Recall': 0.8478366732597351,
#    'train_metrics/Specificity': 0.973513662815094,
#    'train_metrics/JaccardIndex': 0.8534241914749146},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8656308650970459,
#    'valid_metrics/Accuracy': 0.9388387799263,
#    'valid_metrics/Dice': 0.8656309247016907,
#    'valid_metrics/Precision': 0.8717626333236694,
#    'valid_metrics/Recall': 0.8595848679542542,
#    'valid_metrics/Specificity': 0.9624035358428955,
#    'valid_metrics/JaccardIndex': 0.8434640765190125}},
#  {'tr_loss': 0.007512231271703709,
#   'vl_loss': 0.0093727873846831,
#   'tr_metrics': {'train_metrics/F1Score': 0.8746646642684937,
#    'train_metrics/Accuracy': 0.9484712481498718,
#    'train_metrics/Dice': 0.8746645450592041,
#    'train_metrics/Precision': 0.8976939916610718,
#    'train_metrics/Recall': 0.8527871966362,
#    'train_metrics/Specificity': 0.9740347266197205,
#    'train_metrics/JaccardIndex': 0.8572115898132324},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8575699329376221,
#    'valid_metrics/Accuracy': 0.937417209148407,
#    'valid_metrics/Dice': 0.8575699925422668,
#    'valid_metrics/Precision': 0.8962897658348083,
#    'valid_metrics/Recall': 0.8220570087432861,
#    'valid_metrics/Specificity': 0.9717175364494324,
#    'valid_metrics/JaccardIndex': 0.8367717266082764}},
#  {'tr_loss': 0.007501530712957881,
#   'vl_loss': 0.009586511978081294,
#   'tr_metrics': {'train_metrics/F1Score': 0.8756141662597656,
#    'train_metrics/Accuracy': 0.9489485025405884,
#    'train_metrics/Dice': 0.8756141662597656,
#    'train_metrics/Precision': 0.9002794623374939,
#    'train_metrics/Recall': 0.852264404296875,
#    'train_metrics/Specificity': 0.9747791290283203,
#    'train_metrics/JaccardIndex': 0.8582571744918823},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8604456186294556,
#    'valid_metrics/Accuracy': 0.9367017149925232,
#    'valid_metrics/Dice': 0.8604456782341003,
#    'valid_metrics/Precision': 0.8696501851081848,
#    'valid_metrics/Recall': 0.8514339327812195,
#    'valid_metrics/Specificity': 0.9620546102523804,
#    'valid_metrics/JaccardIndex': 0.8382135629653931}},
#  {'tr_loss': 0.007117793228754327,
#   'vl_loss': 0.008744536708450686,
#   'tr_metrics': {'train_metrics/F1Score': 0.8814181685447693,
#    'train_metrics/Accuracy': 0.9512758851051331,
#    'train_metrics/Dice': 0.8814181685447693,
#    'train_metrics/Precision': 0.9051727652549744,
#    'train_metrics/Recall': 0.858878493309021,
#    'train_metrics/Specificity': 0.9759612679481506,
#    'train_metrics/JaccardIndex': 0.8642400503158569},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8655470609664917,
#    'valid_metrics/Accuracy': 0.939240574836731,
#    'valid_metrics/Dice': 0.8655471205711365,
#    'valid_metrics/Precision': 0.8781273365020752,
#    'valid_metrics/Recall': 0.8533222079277039,
#    'valid_metrics/Specificity': 0.964786946773529,
#    'valid_metrics/JaccardIndex': 0.8437166213989258}},
#  {'tr_loss': 0.007063552119433059,
#   'vl_loss': 0.008829427156669293,
#   'tr_metrics': {'train_metrics/F1Score': 0.881488561630249,
#    'train_metrics/Accuracy': 0.9512605667114258,
#    'train_metrics/Dice': 0.881488561630249,
#    'train_metrics/Precision': 0.9043814539909363,
#    'train_metrics/Recall': 0.859726071357727,
#    'train_metrics/Specificity': 0.9757154583930969,
#    'train_metrics/JaccardIndex': 0.8642804622650146},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8647451996803284,
#    'valid_metrics/Accuracy': 0.940295398235321,
#    'valid_metrics/Dice': 0.8647451400756836,
#    'valid_metrics/Precision': 0.8992807269096375,
#    'valid_metrics/Recall': 0.8327640295028687,
#    'valid_metrics/Specificity': 0.9722679853439331,
#    'valid_metrics/JaccardIndex': 0.8439656496047974}},
#  {'tr_loss': 0.00696927402425075,
#   'vl_loss': 0.009228369875534161,
#   'tr_metrics': {'train_metrics/F1Score': 0.8838785290718079,
#    'train_metrics/Accuracy': 0.9521870613098145,
#    'train_metrics/Dice': 0.8838785886764526,
#    'train_metrics/Precision': 0.9057085514068604,
#    'train_metrics/Recall': 0.8630761504173279,
#    'train_metrics/Specificity': 0.9759944081306458,
#    'train_metrics/JaccardIndex': 0.8667354583740234},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8639485836029053,
#    'valid_metrics/Accuracy': 0.9390961527824402,
#    'valid_metrics/Dice': 0.8639485836029053,
#    'valid_metrics/Precision': 0.885149359703064,
#    'valid_metrics/Recall': 0.8437396287918091,
#    'valid_metrics/Specificity': 0.9674487709999084,
#    'valid_metrics/JaccardIndex': 0.8424896001815796}},
#  {'tr_loss': 0.007020031256452408,
#   'vl_loss': 0.009708643017128168,
#   'tr_metrics': {'train_metrics/F1Score': 0.8829689621925354,
#    'train_metrics/Accuracy': 0.9519056081771851,
#    'train_metrics/Dice': 0.8829690217971802,
#    'train_metrics/Precision': 0.9066169261932373,
#    'train_metrics/Recall': 0.8605234026908875,
#    'train_metrics/Specificity': 0.9763197898864746,
#    'train_metrics/JaccardIndex': 0.8658531904220581},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8628551959991455,
#    'valid_metrics/Accuracy': 0.9384825825691223,
#    'valid_metrics/Dice': 0.8628551959991455,
#    'valid_metrics/Precision': 0.8821614980697632,
#    'valid_metrics/Recall': 0.8443758487701416,
#    'valid_metrics/Specificity': 0.966463565826416,
#    'valid_metrics/JaccardIndex': 0.8412560224533081}},
# ...
#    'valid_metrics/Dice': 0.869759202003479,
#    'valid_metrics/Precision': 0.8853192329406738,
#    'valid_metrics/Recall': 0.8547366857528687,
#    'valid_metrics/Specificity': 0.9670795798301697,
#    'valid_metrics/JaccardIndex': 0.8482869267463684}},
#  {'tr_loss': 0.006080910733826561,
#   'vl_loss': 0.009113891762195866,
#   'tr_metrics': {'train_metrics/F1Score': 0.8990979790687561,
#    'train_metrics/Accuracy': 0.9583147168159485,
#    'train_metrics/Dice': 0.8990978598594666,
#    'train_metrics/Precision': 0.9180934429168701,
#    'train_metrics/Recall': 0.8808726072311401,
#    'train_metrics/Specificity': 0.9790045619010925,
#    'train_metrics/JaccardIndex': 0.8827495574951172},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8674140572547913,
#    'valid_metrics/Accuracy': 0.9415673613548279,
#    'valid_metrics/Dice': 0.8674140572547913,
#    'valid_metrics/Precision': 0.9036237001419067,
#    'valid_metrics/Recall': 0.8339945077896118,
#    'valid_metrics/Specificity': 0.9735522866249084,
#    'valid_metrics/JaccardIndex': 0.846814751625061}},
#  {'tr_loss': 0.006071494090737719,
#   'vl_loss': 0.00895097664769552,
#   'tr_metrics': {'train_metrics/F1Score': 0.8991862535476685,
#    'train_metrics/Accuracy': 0.9583612680435181,
#    'train_metrics/Dice': 0.8991862535476685,
#    'train_metrics/Precision': 0.9184136390686035,
#    'train_metrics/Recall': 0.880747377872467,
#    'train_metrics/Specificity': 0.9790969491004944,
#    'train_metrics/JaccardIndex': 0.8828518390655518},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8687214851379395,
#    'valid_metrics/Accuracy': 0.941262423992157,
#    'valid_metrics/Dice': 0.8687214851379395,
#    'valid_metrics/Precision': 0.8905110955238342,
#    'valid_metrics/Recall': 0.8479727506637573,
#    'valid_metrics/Specificity': 0.969000518321991,
#    'valid_metrics/JaccardIndex': 0.8475023508071899}},
#  {'tr_loss': 0.006060036756200896,
#   'vl_loss': 0.00907273544537975,
#   'tr_metrics': {'train_metrics/F1Score': 0.8996915817260742,
#    'train_metrics/Accuracy': 0.9585627913475037,
#    'train_metrics/Dice': 0.8996915817260742,
#    'train_metrics/Precision': 0.9187631607055664,
#    'train_metrics/Recall': 0.881395697593689,
#    'train_metrics/Specificity': 0.9791791439056396,
#    'train_metrics/JaccardIndex': 0.8833885192871094},
#   'vl_metrics': {'valid_metrics/F1Score': 0.870181143283844,
#    'valid_metrics/Accuracy': 0.9408948421478271,
#    'valid_metrics/Dice': 0.870181143283844,
#    'valid_metrics/Precision': 0.8761188983917236,
#    'valid_metrics/Recall': 0.8643233180046082,
#    'valid_metrics/Specificity': 0.9636620283126831,
#    'valid_metrics/JaccardIndex': 0.8482447862625122}},
#  {'tr_loss': 0.006007453294332363,
#   'vl_loss': 0.009161364330288066,
#   'tr_metrics': {'train_metrics/F1Score': 0.9001508355140686,
#    'train_metrics/Accuracy': 0.9586890339851379,
#    'train_metrics/Dice': 0.9001508355140686,
#    'train_metrics/Precision': 0.9177632331848145,
#    'train_metrics/Recall': 0.8832016587257385,
#    'train_metrics/Specificity': 0.97885662317276,
#    'train_metrics/JaccardIndex': 0.883833646774292},
#   'vl_metrics': {'valid_metrics/F1Score': 0.869917631149292,
#    'valid_metrics/Accuracy': 0.9411680698394775,
#    'valid_metrics/Dice': 0.869917631149292,
#    'valid_metrics/Precision': 0.8818281888961792,
#    'valid_metrics/Recall': 0.8583244681358337,
#    'valid_metrics/Specificity': 0.9658001661300659,
#    'valid_metrics/JaccardIndex': 0.8482716083526611}},
#  {'tr_loss': 0.006019341151330097,
#   'vl_loss': 0.009423994937458553,
#   'tr_metrics': {'train_metrics/F1Score': 0.9011053442955017,
#    'train_metrics/Accuracy': 0.9591052532196045,
#    'train_metrics/Dice': 0.9011052846908569,
#    'train_metrics/Precision': 0.9192343950271606,
#    'train_metrics/Recall': 0.8836774826049805,
#    'train_metrics/Specificity': 0.9792569279670715,
#    'train_metrics/JaccardIndex': 0.884876012802124},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8701397180557251,
#    'valid_metrics/Accuracy': 0.9409878253936768,
#    'valid_metrics/Dice': 0.8701396584510803,
#    'valid_metrics/Precision': 0.8777633905410767,
#    'valid_metrics/Recall': 0.8626472353935242,
#    'valid_metrics/Specificity': 0.9642809629440308,
#    'valid_metrics/JaccardIndex': 0.8482878804206848}},
#  {'tr_loss': 0.006112109582368336,
#   'vl_loss': 0.009070730203597242,
#   'tr_metrics': {'train_metrics/F1Score': 0.8987996578216553,
#    'train_metrics/Accuracy': 0.9581434726715088,
#    'train_metrics/Dice': 0.8987996578216553,
#    'train_metrics/Precision': 0.916692852973938,
#    'train_metrics/Recall': 0.8815916180610657,
#    'train_metrics/Specificity': 0.978595495223999,
#    'train_metrics/JaccardIndex': 0.8823935985565186},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8665313124656677,
#    'valid_metrics/Accuracy': 0.9413111209869385,
#    'valid_metrics/Dice': 0.8665313124656677,
#    'valid_metrics/Precision': 0.904922604560852,
#    'valid_metrics/Recall': 0.8312649130821228,
#    'valid_metrics/Specificity': 0.9740314483642578,
#    'valid_metrics/JaccardIndex': 0.8459967970848083}},
#  {'tr_loss': 0.005954909772091332,
#   'vl_loss': 0.009238397378949124,
#   'tr_metrics': {'train_metrics/F1Score': 0.9010926485061646,
#    'train_metrics/Accuracy': 0.9591781497001648,
#    'train_metrics/Dice': 0.9010925889015198,
#    'train_metrics/Precision': 0.9210559725761414,
#    'train_metrics/Recall': 0.881976306438446,
#    'train_metrics/Specificity': 0.9798038005828857,
#    'train_metrics/JaccardIndex': 0.8849213123321533},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8683781623840332,
#    'valid_metrics/Accuracy': 0.9419348239898682,
#    'valid_metrics/Dice': 0.8683781623840332,
#    'valid_metrics/Precision': 0.9036588668823242,
#    'valid_metrics/Recall': 0.8357487916946411,
#    'valid_metrics/Specificity': 0.9735073447227478,
#    'valid_metrics/JaccardIndex': 0.8477762937545776}},
#  {'tr_loss': 0.005958933769096684,
#   'vl_loss': 0.00951619736821495,
#   'tr_metrics': {'train_metrics/F1Score': 0.9019549489021301,
#    'train_metrics/Accuracy': 0.959410548210144,
#    'train_metrics/Dice': 0.9019548892974854,
#    'train_metrics/Precision': 0.9190182685852051,
#    'train_metrics/Recall': 0.8855136632919312,
#    'train_metrics/Specificity': 0.9791532754898071,
#    'train_metrics/JaccardIndex': 0.8857558965682983},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8576369881629944,
#    'valid_metrics/Accuracy': 0.9395419955253601,
#    'valid_metrics/Dice': 0.8576369285583496,
#    'valid_metrics/Precision': 0.9315615296363831,
#    'valid_metrics/Recall': 0.7945824265480042,
#    'valid_metrics/Specificity': 0.982643187046051,
#    'valid_metrics/JaccardIndex': 0.8384187817573547}},
#  {'tr_loss': 0.005813114792519036,
#   'vl_loss': 0.009236506542413852,
#   'tr_metrics': {'train_metrics/F1Score': 0.9038956165313721,
#    'train_metrics/Accuracy': 0.9603185653686523,
#    'train_metrics/Dice': 0.9038956165313721,
#    'train_metrics/Precision': 0.9235202670097351,
#    'train_metrics/Recall': 0.8850876092910767,
#    'train_metrics/Specificity': 0.9804177284240723,
#    'train_metrics/JaccardIndex': 0.8879293203353882},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8704116940498352,
#    'valid_metrics/Accuracy': 0.9418513178825378,
#    'valid_metrics/Dice': 0.8704116344451904,
#    'valid_metrics/Precision': 0.8895553946495056,
#    'valid_metrics/Recall': 0.8520745635032654,
#    'valid_metrics/Specificity': 0.9685449004173279,
#    'valid_metrics/JaccardIndex': 0.8491482734680176}},
#  {'tr_loss': 0.005733359986839216,
#   'vl_loss': 0.00928189867251628,
#   'tr_metrics': {'train_metrics/F1Score': 0.905423104763031,
#    'train_metrics/Accuracy': 0.9608315825462341,
#    'train_metrics/Dice': 0.9054230451583862,
#    'train_metrics/Precision': 0.9221903085708618,
#    'train_metrics/Recall': 0.8892547488212585,
#    'train_metrics/Specificity': 0.9799544215202332,
#    'train_metrics/JaccardIndex': 0.8894916772842407},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8677709102630615,
#    'valid_metrics/Accuracy': 0.9416746497154236,
#    'valid_metrics/Dice': 0.8677709102630615,
#    'valid_metrics/Precision': 0.9031562209129333,
#    'valid_metrics/Recall': 0.8350538015365601,
#    'valid_metrics/Specificity': 0.973376452922821,
#    'valid_metrics/JaccardIndex': 0.8471485376358032}},
#  {'tr_loss': 0.005748564076735625,
#   'vl_loss': 0.009193952652018042,
#   'tr_metrics': {'train_metrics/F1Score': 0.9056404829025269,
#    'train_metrics/Accuracy': 0.9609484672546387,
#    'train_metrics/Dice': 0.9056404829025269,
#    'train_metrics/Precision': 0.9230728149414062,
#    'train_metrics/Recall': 0.8888543248176575,
#    'train_metrics/Specificity': 0.9802096486091614,
#    'train_metrics/JaccardIndex': 0.8897476196289062},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8684224486351013,
#    'valid_metrics/Accuracy': 0.9418150782585144,
#    'valid_metrics/Dice': 0.8684224486351013,
#    'valid_metrics/Precision': 0.9013720154762268,
#    'valid_metrics/Recall': 0.8377968668937683,
#    'valid_metrics/Specificity': 0.9727430939674377,
#    'valid_metrics/JaccardIndex': 0.8477159738540649}},
#  {'tr_loss': 0.005664201850487181,
#   'vl_loss': 0.009263642908983708,
#   'tr_metrics': {'train_metrics/F1Score': 0.9063657522201538,
#    'train_metrics/Accuracy': 0.9612607955932617,
#    'train_metrics/Dice': 0.906365692615509,
#    'train_metrics/Precision': 0.9241108894348145,
#    'train_metrics/Recall': 0.8892892599105835,
#    'train_metrics/Specificity': 0.9804890751838684,
#    'train_metrics/JaccardIndex': 0.8905431032180786},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8691648244857788,
#    'valid_metrics/Accuracy': 0.9415870904922485,
#    'valid_metrics/Dice': 0.8691648244857788,
#    'valid_metrics/Precision': 0.8929929137229919,
#    'valid_metrics/Recall': 0.8465753197669983,
#    'valid_metrics/Specificity': 0.9698371291160583,
#    'valid_metrics/JaccardIndex': 0.8480647802352905}},
#  {'tr_loss': 0.005617849933132324,
#   'vl_loss': 0.009337877847513177,
#   'tr_metrics': {'train_metrics/F1Score': 0.9072494506835938,
#    'train_metrics/Accuracy': 0.9615367650985718,
#    'train_metrics/Dice': 0.9072494506835938,
#    'train_metrics/Precision': 0.922777533531189,
#    'train_metrics/Recall': 0.892235279083252,
#    'train_metrics/Specificity': 0.9800516963005066,
#    'train_metrics/JaccardIndex': 0.8914341926574707},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8673116564750671,
#    'valid_metrics/Accuracy': 0.9413490891456604,
#    'valid_metrics/Dice': 0.8673116564750671,
#    'valid_metrics/Precision': 0.9006354212760925,
#    'valid_metrics/Recall': 0.8363659381866455,
#    'valid_metrics/Specificity': 0.9725639820098877,
#    'valid_metrics/JaccardIndex': 0.8465756177902222}},
#  {'tr_loss': 0.005625050935699263,
#   'vl_loss': 0.009365363413302595,
#   'tr_metrics': {'train_metrics/F1Score': 0.9066869616508484,
#    'train_metrics/Accuracy': 0.9613921642303467,
#    'train_metrics/Dice': 0.9066869020462036,
#    'train_metrics/Precision': 0.9244027137756348,
#    'train_metrics/Recall': 0.8896374702453613,
#    'train_metrics/Specificity': 0.9805626273155212,
#    'train_metrics/JaccardIndex': 0.8908904194831848},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8669496178627014,
#    'valid_metrics/Accuracy': 0.9414365887641907,
#    'valid_metrics/Dice': 0.8669495582580566,
#    'valid_metrics/Precision': 0.9043759703636169,
#    'valid_metrics/Recall': 0.832497775554657,
#    'valid_metrics/Specificity': 0.973827600479126,
#    'valid_metrics/JaccardIndex': 0.8463873267173767}},
#  {'tr_loss': 0.005651213267700074,
#   'vl_loss': 0.009223936377344904,
#   'tr_metrics': {'train_metrics/F1Score': 0.9069309830665588,
#    'train_metrics/Accuracy': 0.9614742994308472,
#    'train_metrics/Dice': 0.9069308638572693,
#    'train_metrics/Precision': 0.9241793155670166,
#    'train_metrics/Recall': 0.8903146982192993,
#    'train_metrics/Specificity': 0.9804856181144714,
#    'train_metrics/JaccardIndex': 0.8911409974098206},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8693882822990417,
#    'valid_metrics/Accuracy': 0.9412442445755005,
#    'valid_metrics/Dice': 0.8693882822990417,
#    'valid_metrics/Precision': 0.8861817121505737,
#    'valid_metrics/Recall': 0.8532194495201111,
#    'valid_metrics/Specificity': 0.9674168825149536,
#    'valid_metrics/JaccardIndex': 0.8479578495025635}},
#  {'tr_loss': 0.0056119740399283155,
#   'vl_loss': 0.009540082376205784,
#   'tr_metrics': {'train_metrics/F1Score': 0.9073764085769653,
#    'train_metrics/Accuracy': 0.9615923166275024,
#    'train_metrics/Dice': 0.9073764085769653,
#    'train_metrics/Precision': 0.9229780435562134,
#    'train_metrics/Recall': 0.892293393611908,
#    'train_metrics/Specificity': 0.9801065921783447,
#    'train_metrics/JaccardIndex': 0.8915744423866272},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8649822473526001,
#    'valid_metrics/Accuracy': 0.9408031105995178,
#    'valid_metrics/Dice': 0.8649822473526001,
#    'valid_metrics/Precision': 0.906190037727356,
#    'valid_metrics/Recall': 0.827359139919281,
#    'valid_metrics/Specificity': 0.9745336771011353,
#    'valid_metrics/JaccardIndex': 0.844519317150116}},
#  {'tr_loss': 0.00562322650607624,
#   'vl_loss': 0.009372601033868017,
#   'tr_metrics': {'train_metrics/F1Score': 0.9072513580322266,
#    'train_metrics/Accuracy': 0.9615713953971863,
#    'train_metrics/Dice': 0.9072513580322266,
#    'train_metrics/Precision': 0.9236199855804443,
#    'train_metrics/Recall': 0.8914527893066406,
#    'train_metrics/Specificity': 0.9803045988082886,
#    'train_metrics/JaccardIndex': 0.891461968421936},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8673915266990662,
#    'valid_metrics/Accuracy': 0.9413461685180664,
#    'valid_metrics/Dice': 0.8673915266990662,
#    'valid_metrics/Precision': 0.9000867009162903,
#    'valid_metrics/Recall': 0.8369883894920349,
#    'valid_metrics/Specificity': 0.9723750948905945,
#    'valid_metrics/JaccardIndex': 0.8466297388076782}},
#  {'tr_loss': 0.0055973177113808874,
#   'vl_loss': 0.009269918081382987,
#   'tr_metrics': {'train_metrics/F1Score': 0.9076910614967346,
#    'train_metrics/Accuracy': 0.9618183970451355,
#    'train_metrics/Dice': 0.9076911211013794,
#    'train_metrics/Precision': 0.9256948232650757,
#    'train_metrics/Recall': 0.8903743028640747,
#    'train_metrics/Specificity': 0.9809057116508484,
#    'train_metrics/JaccardIndex': 0.8919890522956848},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8695856332778931,
#    'valid_metrics/Accuracy': 0.9415953159332275,
#    'valid_metrics/Dice': 0.8695855736732483,
#    'valid_metrics/Precision': 0.8905365467071533,
#    'valid_metrics/Recall': 0.8495977520942688,
#    'valid_metrics/Specificity': 0.9689491987228394,
#    'valid_metrics/JaccardIndex': 0.8483678102493286}},
#  {'tr_loss': 0.005551314821913222,
#   'vl_loss': 0.009466701464073078,
#   'tr_metrics': {'train_metrics/F1Score': 0.908641517162323,
#    'train_metrics/Accuracy': 0.9621565937995911,
#    'train_metrics/Dice': 0.9086414575576782,
#    'train_metrics/Precision': 0.925271213054657,
#    'train_metrics/Recall': 0.8925989866256714,
#    'train_metrics/Specificity': 0.9807400703430176,
#    'train_metrics/JaccardIndex': 0.8929810523986816},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8690770268440247,
#    'valid_metrics/Accuracy': 0.9412895441055298,
#    'valid_metrics/Dice': 0.8690770268440247,
#    'valid_metrics/Precision': 0.8887771368026733,
#    'valid_metrics/Recall': 0.8502312898635864,
#    'valid_metrics/Specificity': 0.9683640599250793,
#    'valid_metrics/JaccardIndex': 0.8477736711502075}},
#  {'tr_loss': 0.005465258530677186,
#   'vl_loss': 0.009421768709729538,
#   'tr_metrics': {'train_metrics/F1Score': 0.9099214673042297,
#    'train_metrics/Accuracy': 0.9626871943473816,
#    'train_metrics/Dice': 0.9099214673042297,
#    'train_metrics/Precision': 0.9265836477279663,
#    'train_metrics/Recall': 0.8938480019569397,
#    'train_metrics/Specificity': 0.9810786843299866,
#    'train_metrics/JaccardIndex': 0.894376277923584},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8700276613235474,
#    'valid_metrics/Accuracy': 0.9414895176887512,
#    'valid_metrics/Dice': 0.8700276613235474,
#    'valid_metrics/Precision': 0.8861665725708008,
#    'valid_metrics/Recall': 0.8544660806655884,
#    'valid_metrics/Specificity': 0.9673643708229065,
#    'valid_metrics/JaccardIndex': 0.8485978245735168}}]

# %% [markdown]
# ## Save images

# %%
from PIL import Image
import cv2
def skin_plot(img, gt, pred):
    img = np.array(img)
    gt = np.array(gt)
    pred = np.array(pred)
    edged_test = cv2.Canny(pred, 100, 255)
    contours_test, _ = cv2.findContours(edged_test, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    edged_gt = cv2.Canny(gt, 100, 255)
    contours_gt, _ = cv2.findContours(edged_gt, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    for cnt_test in contours_test:
        cv2.drawContours(img, [cnt_test], -1, (0, 0, 255), 1)
    for cnt_gt in contours_gt:
        cv2.drawContours(img, [cnt_gt], -1, (0,255,0), 1)
    return img

#---------------------------------------------------------------------------------------------


save_imgs_dir = f"{config['model']['save_dir']}/visualized"

if not os.path.isdir(save_imgs_dir):
    os.mkdir(save_imgs_dir)

with torch.no_grad():
    for batch in tqdm(te_dataloader):
        imgs = batch['image']
        msks = batch['mask']
        ids = batch['id']
        
        preds = best_model(imgs.to(device))
        
        txm = imgs.cpu().numpy()
        tbm = torch.argmax(msks, 1).cpu().numpy()
        tpm = torch.argmax(preds, 1).cpu().numpy()
        tid = ids
        
        for idx in range(len(tbm)):
            img = np.moveaxis(txm[idx, :3], 0, -1)*255.
            img = np.ascontiguousarray(img*255., dtype=np.uint8)
            gt = np.uint8(tbm[idx]*255.)
            pred = np.where(tpm[idx]>0.5, 255, 0)
            pred = np.ascontiguousarray(pred, dtype=np.uint8)
            
            res_img = skin_plot(img, gt, pred)
            
            fid = tid[idx]
            Image.fromarray(img).save(f"{save_imgs_dir}/{fid}_img.png")
            Image.fromarray(gt).save(f"{save_imgs_dir}/{fid}_gt.png")
            Image.fromarray(res_img).save(f"{save_imgs_dir}/{fid}_img_gt_pred.png")
# Out:
# 100%|██████████| 33/33 [00:21<00:00,  1.56it/s]

# %%
f"{config['model']['save_dir']}/visualized"
# Out:
# '../../saved_models/isic2018_unet/visualized'
